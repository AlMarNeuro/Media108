# %% [markdown]
# # Настройка хранилища, библиотек и глобальных переменных

# %% [markdown]
# - Инициализация

# %%
# Подключение google-диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# - Загрузка библиотек

# %%
#
# Загрузка библиотек
#
import os # Работа с файловой системой

import time # Работа с системным временем

import pickle as pkl # Сериализация данных

import pandas as pd # Датафреймы
# Параметры отображения датафреймов
pd.options.display.max_rows     = 99
pd.options.display.max_colwidth = 999

import numpy as np

import regex as re

import librosa # Для параметризации аудио
import librosa.display # Для отображения аудио сигналов

import matplotlib.pyplot as plt # Для отрисовки графиков
plt.style.use('dark_background')

from google.colab import files # Для загрузки файлов
#import IPython.display as ipd # Для проигрывания аудио
#from IPython.display import Audio
#import seaborn as sns

###
# Подготовка данных
#import sklearn # Для нормирования
#from sklearn.preprocessing import LabelEncoder, StandardScaler # Масштабирование, нормировка данных
#from sklearn.model_selection import train_test_split # Разбиение на обучающую и проверочную выборку

from sklearn.utils import shuffle # Синхронно перемешать 2 набора данных (XTrain и YTrain)

# Функции-утилиты для работы с категориальными данными
# from keras.api._v2.keras import utils
# from keras.api._v2.keras.utils import to_categorical

# Рисование схемы модели
from keras.api._v2.keras.utils import plot_model

# Класс для конструирования последовательной модели нейронной сети
from keras.api._v2.keras.models import Sequential, Model
from keras.api._v2.keras.models import load_model


# Основные слои
from keras.api._v2.keras.layers import Dense, Dropout, SpatialDropout1D, BatchNormalization, Embedding, Flatten, Activation, Input, concatenate
from keras.api._v2.keras.layers import SimpleRNN, GRU, LSTM, Bidirectional, Conv1D, Conv2D, MaxPooling1D, GlobalMaxPooling1D

# Оптимизаторы
from keras.api._v2.keras.optimizers import Adam, Adadelta, SGD, Adagrad, RMSprop

# Токенизатор для преобразования текстов в последовательности
#from keras.api._v2.keras.preprocessing.text import Tokenizer

# %matplotlib inline

# %% [markdown]
# - Переменные глобальные

# %%
#
# Глобальные переменные
#

ACCOUNT = 'mar'
#ACCOUNT = 'adi'

if ACCOUNT == 'mar':
  VM_CNT = '/content'
  VM_CNT_DRV = VM_CNT + '/drive'
  MY_CNT = '/content/drive/MyDrive/УИИ(marphida)/Стажировка_Media108'

  WAV_PATH = VM_CNT_DRV + '/MyDrive/УИИ(marphida)/Стажировка_Media108/Audio/'
  WAV_FILE = '2023-07-16_19-33-07.854622_from_79254254955_to_0111642_session_3091299879_talk.wav'
  WAV_DATA = WAV_PATH + WAV_FILE

  WAV_PRIMA = MY_CNT + '/Audio/Записи звонков_primavera/'
  WAV_PAVEL = MY_CNT + '/Audio/Записи звонков_павелецкая сити'
  WAV_HEADL = MY_CNT + '/Audio/Записи звонков_хедлайнер'
  WAV_ZV_INFO = MY_CNT + '/Audio/Информация о звонках'

  DF_HL = MY_CNT + '/РГ/Headliner_df.pkl'
  DF_PAVEL_ST = MY_CNT + '/РГ/Paveletskaya_city_df.pkl'
  DF_PAVEL_HL = MY_CNT + '/РГ/Paveletskaya_df.pkl'
  DF_PRIMA = MY_CNT + '/РГ/Primavera_df.pkl'
  DF_TOTAL = MY_CNT + '/РГ/total_df.pkl'
  DF_TOTAL_MATCH = MY_CNT + '/РГ/total_match_df.pkl'
  DF_TOTAL_NOT_MATCH = MY_CNT + '/РГ/total_not_match_df.pkl'

  CSV_HL = MY_CNT + '/РП/Headliner_with_audio.csv'
  CSV_PST = MY_CNT + '/РП/Павелецкая_ЖК_«Павелецкая_сити»_with_audio.csv'
  CSV_PTB = MY_CNT + '/РП/Paveleckaya_with_audio.csv'
  CSV_PRM = MY_CNT + '/РП/Primavera_with_audio.csv'

  DUMP = '/content/drive/MyDrive/УИИ(marphida)/Стажировка_Media108/DataDump'
elif ACCOUNT == 'adi':
  VM_CNT = '/content'
  VM_CNT_DRV = VM_CNT + '/drive'
  MY_CNT = '/content/drive/MyDrive/st108'

  WAV_PATH = VM_CNT_DRV + '/MyDrive/st108/Audio/'

  WAV_PRIMA = MY_CNT + '/Audio/Записи звонков_primavera/'
  WAV_PAVEL = MY_CNT + '/Audio/Записи звонков_павелецкая сити'
  WAV_HEADL = MY_CNT + '/Audio/Записи звонков_хедлайнер'
  WAV_ZV_INFO = MY_CNT + '/Audio/Информация о звонках'

  CSV_HL = MY_CNT + '/Audio/Headliner_with_audio.csv'
  CSV_PST = MY_CNT + '/Audio/Павелецкая_ЖК_«Павелецкая_сити»_with_audio.csv'
  CSV_PTB = MY_CNT + '/Audio/Paveleckaya_with_audio.csv'
  CSV_PRM = MY_CNT + '/Audio/Primavera_with_audio.csv'

  DUMP = MY_CNT + '/Dump'

#=========================================================================
  #csv_list_ = [CSV_HL, CSV_PST, CSV_PTB, CSV_PRM]
#=========================================================================

# Параметры предобработки аудиосигнала и подготовки обучающих выборок
#
SR = 8000 # Sample Rate - Частота дискетизации исходного звукового материала (звонки клиентов)
#
LEN_MEAN_AU = 10       # Шаг усреднения аудио
LEN_CONV1D_AU = 1000  # Размер окна одномерной свёртки аудио
STEP_CONV1D_AU = 100  # Шаг сдвига по свёртке аудио
#
# Параметры one-hot-encoding обработки
#
AU_OHE_CLASSES = 100
#

# %% [markdown]
# - Класс для измерение времени исполнения модулей

# %%
# Контекстный менеджер для измерения времени операций
# Операция обертывается менеджером с помощью оператора with
class timex:
    def __enter__(self):
        # Фиксация времени старта процесса
        self.t = time.time()
        return self

    def __exit__(self, type, value, traceback):
        # Вывод времени работы
        print('Время обработки: {:.2f} с'.format(time.time() - self.t))

# %% [markdown]
# # Свёрточная модель на необработанном аудио

# %% [markdown]
# ## Предобработка датасетов обучения

# %% [markdown]
# - **Функция формирования предвыборок обучения**

# %%
##### Функция формирования датафрейма соответствия аудиофайлов и соответствующих им признаков целевой/нецелевой
#####
##### get_tags_vs_audio (path_csv)
#####
##### Входные параметры:
##### path_csv - адрес датафрейма csv содержащим столбец целевых тегов
#####
##### Возвращаемые данные:
##### df_tags_audio_ - датафрейм со столбцами:
#####      'Tags' - wелевой/нецелевой(1/0)
#####      'Audio' -  соответствующе тегам имена аудиофайлов

def get_tags_vs_audio (path_csv, name_who):
  df_csv_ = pd.read_csv(path_csv)
  df_csv_ = df_csv_.fillna('')
  print(f'Размерность исходного csv-файла: {df_csv_.shape}')
  # Копирование наименований аудиофайлов всех целевых тегов
  df_tags_audio_ = df_csv_[df_csv_['Теги'].str.contains('Целевой')][['Теги', 'Аудиофайл']].copy()
  if name_who=='Headliner':
    df_tags_audio_ = pd.concat( [df_tags_audio_, df_csv_[df_csv_['Теги'].str.contains('целевой')][['Теги', 'Аудиофайл']].copy()] )

##  df_tags_audio_ = df_csv_[df_csv_['Теги'].str.contains(r'Целевой|целевой', case=False, regex=True)][['Теги', 'Аудиофайл']].copy()
##  df_tags_audio_ = pd.concat( [df_tags_audio_, df_csv_[df_csv_['Теги'].str.contains('Целевой')][['Теги', 'Аудиофайл']].copy()] )
  # Копирование наименований аудиофайлов всех нецелевых тегов
  df_tags_audio_ = pd.concat( [df_tags_audio_, df_csv_[df_csv_['Теги'].str.contains('Нецелевой')][['Теги', 'Аудиофайл']].copy()] )
  if name_who=='Headliner':
    df_tags_audio_ = pd.concat( [df_tags_audio_, df_csv_[df_csv_['Теги'].str.contains('нецелевой')][['Теги', 'Аудиофайл']].copy()] )

##  df_tags_audio_ = pd.concat( [df_tags_audio_, df_csv_[df_csv_['Теги'].str.contains(r'Нецелевой|нецелевой', case=False, regex=True)][['Теги', 'Аудиофайл']].copy()] )
  # Переименование имён столбцов
  df_tags_audio_.rename(columns = {'Теги':'Tags', 'Аудиофайл':'AudioFile'}, inplace=True )
  print(f'Отфильтровано для обучения записей: {df_tags_audio_.shape}')
  # Избавление от ошибки фильтрации по NaN
  df_tags_audio_ = df_tags_audio_.fillna('')
  # Все нецелевые = 0
  #df_tags_audio_ = df_tags_audio_.astype({'Tags': str}) # Избавление от ошибки нестроковых данных
  df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('Нецелевой', na=False), 'Tags'] = 0
  if name_who=='Headliner':
    df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('нецелевой', na=False), 'Tags'] = 0

##  df_tags_audio_.loc[df_tags_audio_.Tags.str.contains(r'Нецелевой|нецелевой', case=False, regex=True, na=False), 'Tags'] = 0
  #df_tags_audio_.loc[df_tags_audio_.Tags.str.contains(r'\bНецелевой', case=False, regex=True, na=False), 'Tags'] = 0
  #df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('нецелевой', na=False), 'Tags'] = 0
  # Все целевые = 1
###  df_tags_audio_ = df_tags_audio_.astype({'Tags': str}) # Избавление от ошибки нестроковых данных
  df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('Целевой', na=False), 'Tags'] = 1
  if name_who=='Headliner':
    df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('целевой', na=False), 'Tags'] = 1

##  df_tags_audio_.loc[df_tags_audio_.Tags.str.contains(r'Целевой|целевой', case=False, regex=True, na=False), 'Tags'] = 1
  #df_tags_audio_.loc[df_tags_audio_.Tags.str.contains(r'\bЦелевой', case=False, regex=True, na=False), 'Tags'] = 1
  #df_tags_audio_.loc[df_tags_audio_.Tags.str.contains('целевой', na=False), 'Tags'] = 1
  # Изменение типа столбца 'Tags'
  df_tags_audio_ = df_tags_audio_.astype({'Tags': int})
  # Удаление записей без аудиофайлов
  df_tags_audio_ = df_tags_audio_[df_tags_audio_.AudioFile != '']
  # Сброс старых индексов
  df_tags_audio_.reset_index(drop=True, inplace=True)
  print(f"Баланс целевые/нецелевые:\n\
          Целевые: {len(df_tags_audio_[df_tags_audio_.Tags==1])}\n\
          Нецелевые: {len(df_tags_audio_[df_tags_audio_.Tags==0])}")
  return df_tags_audio_

# %% [markdown]
# - **Функция получения датафреймов с необработанными аудио + тегами**

# %%
#####
##### Получение всех тегов с полными путями к аудио
#####
def get_pre_train():
  name_list_ = ['Headliner','Paveletskaya_city', 'Paveletskaya_turbo', 'Primavera']
  csv_list_ = [CSV_HL, CSV_PST, CSV_PTB, CSV_PRM]
###  audio_list_ = [WAV_HEADL, WAV_PAVEL, WAV_PAVEL, WAV_PRIMA]
  proj_len_ = len(name_list_)
  df_tags_audio_full_ = pd.DataFrame()
  for i in range(proj_len_):
    # df_csv_ = pd.read_csv(csv_list_[i])
    print(f'\n         Обработка {name_list_[i]}...\n')
    # print(f'{name_list_[i]} shape = {df_csv_.shape}')
    df_tags_audio_ = get_tags_vs_audio(csv_list_[i], name_list_[i])
###    df_tags_audio_['AudioFile'] = str(audio_list_[i])+"/"+df_tags_audio_['AudioFile']
    df_tags_audio_['DataNumber'] = i
    df_tags_audio_full_ = pd.concat([df_tags_audio_full_, df_tags_audio_], ignore_index = True)
  # Переиндексация
  df_tags_audio_full_.reset_index(drop=True, inplace=True)
  return df_tags_audio_full_

# %% [markdown]
# ## ► Модуль создания датафрейма - исходника для формирование выборок обученеия

# %%
#
# df_pre_train - датафрейм-исходник для генерации обучающих выборок
#
with timex():

  df_pre_train = get_pre_train()

  print('=======================')
  print(f'\nРазмерность сводных данных: {df_pre_train.shape}')
  print(f"Сводный баланс целевые/нецелевые:\n\
          Целевые: {len(df_pre_train[df_pre_train.Tags==1])}\n\
          Нецелевые: {len(df_pre_train[df_pre_train.Tags==0])}")
# Out:
#          Обработка Headliner...
#
# Размерность исходного csv-файла: (2045, 73)
# Отфильтровано для обучения записей: (1097, 2)
# Баланс целевые/нецелевые:
#           Целевые: 859
#           Нецелевые: 238
#
#          Обработка Paveletskaya_city...
#
# Размерность исходного csv-файла: (1000, 76)
# Отфильтровано для обучения записей: (527, 2)
# Баланс целевые/нецелевые:
#           Целевые: 290
#           Нецелевые: 237
#
#          Обработка Paveletskaya_turbo...
#
# Размерность исходного csv-файла: (1784, 76)
# Отфильтровано для обучения записей: (1290, 2)
# Баланс целевые/нецелевые:
#           Целевые: 290
#           Нецелевые: 1000
#
#          Обработка Primavera...
#
# Размерность исходного csv-файла: (1517, 75)
# Отфильтровано для обучения записей: (1310, 2)
# Баланс целевые/нецелевые:
#           Целевые: 648
#           Нецелевые: 662
# =======================
#
# Размерность сводных данных: (4224, 3)
# Сводный баланс целевые/нецелевые:
#           Целевые: 2087
#           Нецелевые: 2137
# Время обработки: 0.54 с

# %%
#
# Равномерное перемешивание Целевых и Нецелевых в датафрейме для формирование датасетов обучения
#

dft_0 = df_pre_train[df_pre_train.Tags==0]
dft_1 = df_pre_train[df_pre_train.Tags==1]

df_p_t_new = pd.DataFrame(columns = df_pre_train.columns)

flag_0_1 = True
i0, i1 = 0, 0

for ii in range(min(len(dft_0), len(dft_1)) * 2):
  if flag_0_1 == True:
    df_p_t_new.loc[len(df_p_t_new.index)] = dft_0.iloc[i0]
#    df_p_t_new = pd.concat( [df_p_t_new, dft_0.iloc[i0]], axis = 0, ignore_index = True)
    i0 += 1
    flag_0_1 = False
  else:
    df_p_t_new.loc[len(df_p_t_new.index)] = dft_1.iloc[i1]
#    df_p_t_new = pd.concat( [df_p_t_new, dft_1.iloc[i1]], axis = 0, ignore_index = True)
    i1 += 1
    flag_0_1 = True

df_pre_train = df_p_t_new.copy()

del dft_0, dft_1, df_p_t_new, ii, flag_0_1, i0, i1

df_pre_train
# Out:
#      Tags  \
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
# ...   ...
# 4169    1
# 4170    0
# 4171    1
# 4172    0
# 4173    1
#
#                                                                                    AudioFile  \
# 0         2023-07-19_15-35-00.597395_from_74951397391_to_0188880_session_3097826533_talk.mp3
# 1     2023-05-22_10-16-39.852630_from_79175582996_to_74957898990_session_2955352133_talk.mp3
# 2     2023-07-19_14-06-31.860077_from_79916000360_to_74957898990_session_3104061795_talk.mp3
# 3     2023-07-19_17-12-58.258412_from_79991345109_to_74959339902_session_3099072526_talk.mp3
# 4         2023-07-19_11-40-46.765315_from_79636236173_to_0188880_session_3097851001_talk.mp3
# ...                                                                                      ...
# 4169      2023-05-02_14-23-41.246677_from_79099221244_to_0197872_session_2917197011_talk.mp3
# 4170      2023-05-12_08-43-24.365428_from_73452427822_to_0197879_session_2945566020_talk.mp3
# 4171      2023-05-02_11-45-20.432052_from_79037581605_to_0111652_session_2916596803_talk.mp3
# 4172      2023-05-12_08-42-59.625280_from_73452427822_to_0197879_session_2945563440_talk.mp3
# 4173      2023-05-01_10-25-48.968195_from_79605015550_to_0197879_session_2906114070_talk.mp3
#
#      DataNumber
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 4169          3
# 4170          3
# 4171          3
# 4172          3
# 4173          3
#
# [4174 rows x 3 columns]

# %% [markdown]
# ## ► Схема построения свёрточной НС
# - Первый слой - свертка, с ядром CONV_SIZE_1 и смещением на каждом шаге свертки CONV_STRIDE_1
# - Далее набор из нескольких одинаковых блоков классифицирующих сверточных сетей -  свертка (с ядром  CONV_SIZE) + пулинг (длина пуллинга PULL_SIZE)
# - Финальные слои - Conv1D, Flattern и бинарный классификатор на слое Dense.

# %% [markdown]
# # Функции создания модели обучеия

# %% [markdown]
# ## Функция создания модели

# %%
#Создаем модель
def create_model(
      sections, # Список с количеством фильтров в классифицирующих секциях
      filter_length,  # Размер ядра свёрточных фильтров
      pooling_length, # Размер пулингов
      outActivation   # Активация на последнем слое
    ):

    #Вход
    input_raw = Input(shape=(X_train1.shape[1], X_train1.shape[2]))

    #Входной сверточный слой
    x = Conv1D(128, filter_length, padding="same", strides=strider, activation="relu")(input_raw)
    x = BatchNormalization()(x)

    #Классифицирующие секции - свертка + пулинг
    for s in sections:
        x = Conv1D(s, filter_length, padding="same", activation="relu")(x)
        x = MaxPooling1D(pool_size = pooling_length)(x)
        x = BatchNormalization()(x)

    #Последняя свертка + подготовка к Dense
    x = Conv1D(512, 1, padding="same", activation="relu")(x)
    x = Flatten()(x)
    x = Dropout(0.5)(x)

    #Dense
    x = Dense(2, activation = outActivation)(x)

    #Возвращаем модель
    return Model([input_raw], x)

# %% [markdown]
# ## ► Функция создания и компиляции модели

# %%
def create_compile_model():

  model_au_ = create_model(SECTIONS, CONV_SIZE, PULL_SIZE, 'softmax') # 'sigmoid'

  # Компиляция модели
  model_au_.compile(
      optimizer=Adam(learning_rate=1e-2),
      loss='categorical_crossentropy',
  #    loss='binary_crossentropy',
      metrics=['accuracy'])

  # Вывод сводки
  model_au_.summary()

  # Вывод схемы модели
  display(plot_model(model_au_, dpi=60, show_shapes=True))

  return model_au_

# %% [markdown]
# ## Функция обучения модели

# %%
def trainModel(model, X_train1, Y_train1, X_train1V, Y_train1V, batch_size, epochs):

  history = model.fit(X_train1,
                      Y_train1,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_data=(X_train1V, Y_train1V),
                      verbose = 1)#,
                      #callbacks=[GarbageCollectorCallback()],)

  # Вывод графиков точности и ошибки
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
  fig.suptitle('График процесса обучения модели')
  ax1.plot(history.history['accuracy'],
              label='Доля верных ответов на обучающем наборе')
  ax1.plot(history.history['val_accuracy'],
              label='Доля верных ответов на проверочном наборе')
  ax1.xaxis.get_major_locator().set_params(integer=True)
  ax1.set_xlabel('Эпоха обучения')
  ax1.set_ylabel('Доля верных ответов')
  ax1.legend()

  ax2.plot(history.history['loss'],
              label='Ошибка на обучающем наборе')
  ax2.plot(history.history['val_loss'],
              label='Ошибка на проверочном наборе')
  ax2.xaxis.get_major_locator().set_params(integer=True)
  ax2.set_xlabel('Эпоха обучения')
  ax2.set_ylabel('Ошибка')
  ax2.legend()
  plt.show()

# %% [markdown]
# # **Параметры модели**

# %%
#
# Параметры свёрточной модели
#
CONV_SIZE_1 = 3 # Ядро свёртки на 1-м шаге
CONV_STRIDE_1 = 7 # Смещение ядра свёртки на 1-м шаге
CONV_SIZE = 3 # Ядро свёртки на 2-м и последующих свёрточных слоях (размер фильтра свёртки)
CONV_STRIDE = 3 # Смещение ядра свёртки на 2-м и последующих свёрточных слоях
PULL_SIZE = 3 # Размер пуллинга на 2-м и последующих свёрточных слоях

CUTTING_PART_TRAIN = 2 # На какую часть нарезки сдвигать ядро свёртки на обучении
CUTTING_PART_PREDICT = 7  # На какую часть нарезки сдвигать ядро свёртки на тестировании

# PART_TO_TRAIN = 10 # ~ 1 / PART_TO_TRAIN на валидацию и тестирование, остальое - на обучение

# Количество фильтров (параметр filters в Conv1D ) в сверточных слоях
# в каждом из классифицирующих блоков
SECTIONS = [128, 128, 256, 256, 256, 256, 256, 512, 512]

# Блоки аудиофайлов для циклов обучения
'''
#    [0, 200],
#    [200, 400],
#    [400, 600],
#    [600, 800],
#    [800, 1000],
#    [1000, 1200],
#    [1200, 1300],
#    [1300, 1400],
#    [1400, 1500],
#    [1500, 1600],
#    [1600, 1650],
    [1650, 1700],
    [1700, 1750],
    [1750, 1800],
    [1800, 1850],
    [1850, 1900],
    [1900, 1950],
    [1950, 2000],
    [2000, 2050],
    [2050, 2100],
    [2100, 2150],
    [2150, 2200],
    [2200, 2250],
    [2250, 2300],
    [2300, 2350],
    [2350, 2400],
    [2400, 2450],
    [2450, 2500],
    [2500, 2550],
    [2550, 2600],
    [2600, 2650],
    [2650, 2700],
    [2700, 2750],
    [2750, 2800],
    [2800, 2850],
    [2850, 2900],
    [2900, 2950],
    [2950, 3000],
    [3000, 3050],
    [3050, 3100],
    [3100, 3150],
    [3150, 3200],
    [3200, 3250],
    [3250, 3300],
    [3300, 3350],
    [3350, 3400],
    [3400, 3450],
    [3440, 3500],
    [3500, 3550],
    [3550, 3600],
    [3600, 3650],
    [3650, 3700],
    [3700, 3750],
    [3750, 3800],
    [3800, 3850],
    [3850, 3900],
    [3900, 3950],
'''

TR_BLOCKS = [
    [3950, 4000],
    [4000, 4050],
    [4050, 4100],
    [4100, 4174]
]

'''
TR_BLOCKS = [
    [1600, 1650],
    [1600, 1700],
    [1700, 1800],
    [1800, 1900],
    [1900, 2000],
    [2000, 2100],
    [2100, 2200],
    [2200, 2300],
    [2300, 2400],
    [2400, 2500],
    [2500, 2600],
    [2600, 2700],
    [2700, 2800],
    [2800, 2900],
    [2900, 3000],
    [3000, 3100],
    [3100, 3200],
    [3200, 3300],
    [3300, 3400],
    [3400, 3500],
    [3500, 3600],
    [3600, 3700],
    [3700, 3800],
    [3800, 3900],
    [3900, 4000],
    [4000, 4174]
]
'''
TR_BLOCKS_TEST = [
    [3000, 4174]
]

# %% [markdown]
# # Группа модулей циклического обучения: модули располагаются в порядке увеличения номеров отправляемых на обучение файлов
#   - формирование блоков датасетов обучения, приемлемых для конфигурации ВМ Colaboratory, на подмножествах аудиофайлов
#   - сохранение датасетов тестирования
#   - циклический запуск обучения с сохранением/востановлением модели обучения

# %% [markdown]
# ---

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [0_200] - 1-й из 21
# [0-200]=> Headliner: № 1 -> Длина записи: 627311; Маркер выборки: 0; Число нарезок: 4
# [0-200]=> Headliner: № 2 -> Длина записи: 1038575; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 3 -> Длина записи: 85871; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 4 -> Длина записи: 3149039; Маркер выборки: 1; Число нарезок: 22
# [0-200]=> Headliner: № 5 -> Длина записи: 507503; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 6 -> Длина записи: 3586223; Маркер выборки: 1; Число нарезок: 26
# [0-200]=> Headliner: № 7 -> Длина записи: 331247; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 8 -> Длина записи: 423407; Маркер выборки: 1; Число нарезок: 3
# [0-200]=> Headliner: № 9 -> Длина записи: 530543; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 10 -> Длина записи: 3575279; Маркер выборки: 1; Число нарезок: 25
# [0-200]=> Headliner: № 11 -> Длина записи: 297839; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 12 -> Длина записи: 1376111; Маркер выборки: 1; Число нарезок: 9
# [0-200]=> Headliner: № 13 -> Длина записи: 1434863; Маркер выборки: 0; Число нарезок: 10
# [0-200]=> Headliner: № 14 -> Длина записи: 2518319; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 15 -> Длина записи: 206831; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 16 -> Длина записи: 2601263; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 17 -> Длина записи: 194735; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 18 -> Длина записи: 587567; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 19 -> Длина записи: 255791; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 20 -> Длина записи: 1139951; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 21 -> Длина записи: 238511; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 22 -> Длина записи: 5652911; Маркер выборки: 1; Число нарезок: 41
# [0-200]=> Headliner: № 23 -> Длина записи: 688943; Маркер выборки: 0; Число нарезок: 5
# [0-200]=> Headliner: № 24 -> Длина записи: 2473967; Маркер выборки: 1; Число нарезок: 17
# [0-200]=> Headliner: № 25 -> Длина записи: 766127; Маркер выборки: 0; Число нарезок: 5
# [0-200]=> Headliner: № 26 -> Длина записи: 1841519; Маркер выборки: 1; Число нарезок: 13
# [0-200]=> Headliner: № 27 -> Длина записи: 192431; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 28 -> Длина записи: 2147951; Маркер выборки: 1; Число нарезок: 15
# [0-200]=> Headliner: № 29 -> Длина записи: 223535; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 30 -> Длина записи: 1830575; Маркер выборки: 1; Число нарезок: 13
# [0-200]=> Headliner: № 31 -> Длина записи: 489071; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 32 -> Длина записи: 816239; Маркер выборки: 1; Число нарезок: 5
# [0-200]=> Headliner: № 33 -> Длина записи: 106031; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 34 -> Длина записи: 1957871; Маркер выборки: 1; Число нарезок: 14
# [0-200]=> Headliner: № 35 -> Длина записи: 412463; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 36 -> Длина записи: 1921007; Маркер выборки: 1; Число нарезок: 13
# [0-200]=> Headliner: № 37 -> Длина записи: 550703; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 38 -> Длина записи: 4868975; Маркер выборки: 1; Число нарезок: 35
# [0-200]=> Headliner: № 39 -> Длина записи: 182063; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 40 -> Длина записи: 931439; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 41 -> Длина записи: 198191; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 42 -> Длина записи: 833519; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 43 -> Длина записи: 309935; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 44 -> Длина записи: 648047; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 45 -> Длина записи: 347951; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 46 -> Длина записи: 1080623; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 47 -> Длина записи: 849647; Маркер выборки: 0; Число нарезок: 6
# [0-200]=> Headliner: № 48 -> Длина записи: 3536111; Маркер выборки: 1; Число нарезок: 25
# [0-200]=> Headliner: № 49 -> Длина записи: 281711; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 50 -> Длина записи: 310511; Маркер выборки: 1; Число нарезок: 2
# [0-200]=> Headliner: № 51 -> Длина записи: 444719; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 52 -> Длина записи: 1148015; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 53 -> Длина записи: 446447; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 54 -> Длина записи: 972335; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 55 -> Длина записи: 499439; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 56 -> Длина записи: 2657711; Маркер выборки: 1; Число нарезок: 19
# [0-200]=> Headliner: № 57 -> Длина записи: 447023; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 58 -> Длина записи: 2480303; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 59 -> Длина записи: 926831; Маркер выборки: 0; Число нарезок: 6
# [0-200]=> Headliner: № 60 -> Длина записи: 631343; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 61 -> Длина записи: 346799; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 62 -> Длина записи: 2361071; Маркер выборки: 1; Число нарезок: 17
# [0-200]=> Headliner: № 63 -> Длина записи: 555887; Маркер выборки: 0; Число нарезок: 4
# [0-200]=> Headliner: № 64 -> Длина записи: 2215919; Маркер выборки: 1; Число нарезок: 16
# [0-200]=> Headliner: № 65 -> Длина записи: 1020143; Маркер выборки: 0; Число нарезок: 7
# [0-200]=> Headliner: № 66 -> Длина записи: 464303; Маркер выборки: 1; Число нарезок: 3
# [0-200]=> Headliner: № 67 -> Длина записи: 330671; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 68 -> Длина записи: 1089839; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 69 -> Длина записи: 412463; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 70 -> Длина записи: 1757423; Маркер выборки: 1; Число нарезок: 12
# [0-200]=> Headliner: № 71 -> Длина записи: 433775; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 72 -> Длина записи: 1031663; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 73 -> Длина записи: 470639; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 74 -> Длина записи: 1278191; Маркер выборки: 1; Число нарезок: 9
# [0-200]=> Headliner: № 75 -> Длина записи: 288623; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 76 -> Длина записи: 677423; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 77 -> Длина записи: 197615; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 78 -> Длина записи: 4387439; Маркер выборки: 1; Число нарезок: 31
# [0-200]=> Headliner: № 79 -> Длина записи: 239087; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 80 -> Длина записи: 731567; Маркер выборки: 1; Число нарезок: 5
# [0-200]=> Headliner: № 81 -> Длина записи: 1143407; Маркер выборки: 0; Число нарезок: 8
# [0-200]=> Headliner: № 82 -> Длина записи: 2681903; Маркер выборки: 1; Число нарезок: 19
# [0-200]=> Headliner: № 83 -> Длина записи: 81263; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 84 -> Длина записи: 797231; Маркер выборки: 1; Число нарезок: 5
# [0-200]=> Headliner: № 85 -> Длина записи: 351407; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 86 -> Длина записи: 517295; Маркер выборки: 1; Число нарезок: 3
# [0-200]=> Headliner: № 87 -> Длина записи: 617519; Маркер выборки: 0; Число нарезок: 4
# [0-200]=> Headliner: № 88 -> Длина записи: 2928431; Маркер выборки: 1; Число нарезок: 21
# [0-200]=> Headliner: № 89 -> Длина записи: 1923311; Маркер выборки: 0; Число нарезок: 13
# [0-200]=> Headliner: № 90 -> Длина записи: 5147183; Маркер выборки: 1; Число нарезок: 37
# [0-200]=> Headliner: № 91 -> Длина записи: 429743; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 92 -> Длина записи: 2872559; Маркер выборки: 1; Число нарезок: 20
# [0-200]=> Headliner: № 93 -> Длина записи: 1024175; Маркер выборки: 0; Число нарезок: 7
# [0-200]=> Headliner: № 94 -> Длина записи: 2153135; Маркер выборки: 1; Число нарезок: 15
# [0-200]=> Headliner: № 95 -> Длина записи: 202799; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 96 -> Длина записи: 3074159; Маркер выборки: 1; Число нарезок: 22
# [0-200]=> Headliner: № 97 -> Длина записи: 297839; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 98 -> Длина записи: 1139951; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 99 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 100 -> Длина записи: 610607; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 101 -> Длина записи: 125039; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 102 -> Длина записи: 1164143; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 103 -> Длина записи: 131375; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 104 -> Длина записи: 1109999; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 105 -> Длина записи: 346223; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 106 -> Длина записи: 2030447; Маркер выборки: 1; Число нарезок: 14
# [0-200]=> Headliner: № 107 -> Длина записи: 485039; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 108 -> Длина записи: 1622639; Маркер выборки: 1; Число нарезок: 11
# [0-200]=> Headliner: № 109 -> Длина записи: 255791; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 110 -> Длина записи: 5233583; Маркер выборки: 1; Число нарезок: 37
# [0-200]=> Headliner: № 111 -> Длина записи: 202223; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 112 -> Длина записи: 4213487; Маркер выборки: 1; Число нарезок: 30
# [0-200]=> Headliner: № 113 -> Длина записи: 103151; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 114 -> Длина записи: 906095; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 115 -> Длина записи: 719471; Маркер выборки: 0; Число нарезок: 5
# [0-200]=> Headliner: № 116 -> Длина записи: 1243055; Маркер выборки: 1; Число нарезок: 9
# [0-200]=> Headliner: № 117 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 118 -> Длина записи: 3438767; Маркер выборки: 1; Число нарезок: 24
# [0-200]=> Headliner: № 119 -> Длина записи: 187247; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 120 -> Длина записи: 2592623; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 121 -> Длина записи: 157871; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 122 -> Длина записи: 933167; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 123 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 124 -> Длина записи: 2960111; Маркер выборки: 1; Число нарезок: 21
# [0-200]=> Headliner: № 125 -> Длина записи: 126191; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 126 -> Длина записи: 360623; Маркер выборки: 1; Число нарезок: 2
# [0-200]=> Headliner: № 127 -> Длина записи: 430319; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 128 -> Длина записи: 2616239; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 129 -> Длина записи: 471215; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 130 -> Длина записи: 1535663; Маркер выборки: 1; Число нарезок: 11
# [0-200]=> Headliner: № 131 -> Длина записи: 1430255; Маркер выборки: 0; Число нарезок: 10
# [0-200]=> Headliner: № 132 -> Длина записи: 1399727; Маркер выборки: 1; Число нарезок: 10
# [0-200]=> Headliner: № 133 -> Длина записи: 214895; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 134 -> Длина записи: 968879; Маркер выборки: 1; Число нарезок: 7
# [0-200]=> Headliner: № 135 -> Длина записи: 491375; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 136 -> Длина записи: 10028783; Маркер выборки: 1; Число нарезок: 72
# [0-200]=> Headliner: № 137 -> Длина записи: 224111; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 138 -> Длина записи: 737903; Маркер выборки: 1; Число нарезок: 5
# [0-200]=> Headliner: № 139 -> Длина записи: 1700399; Маркер выборки: 0; Число нарезок: 12
# [0-200]=> Headliner: № 140 -> Длина записи: 3075311; Маркер выборки: 1; Число нарезок: 22
# [0-200]=> Headliner: № 141 -> Длина записи: 245423; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 142 -> Длина записи: 5769263; Маркер выборки: 1; Число нарезок: 41
# [0-200]=> Headliner: № 143 -> Длина записи: 330671; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 144 -> Длина записи: 551855; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 145 -> Длина записи: 326639; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 146 -> Длина записи: 3794159; Маркер выборки: 1; Число нарезок: 27
# [0-200]=> Headliner: № 147 -> Длина записи: 93935; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 148 -> Длина записи: 1497647; Маркер выборки: 1; Число нарезок: 10
# [0-200]=> Headliner: № 149 -> Длина записи: 80111; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 150 -> Длина записи: 3601199; Маркер выборки: 1; Число нарезок: 26
# [0-200]=> Headliner: № 151 -> Длина записи: 687791; Маркер выборки: 0; Число нарезок: 4
# [0-200]=> Headliner: № 152 -> Длина записи: 604271; Маркер выборки: 1; Число нарезок: 4
# [0-200]=> Headliner: № 153 -> Длина записи: 85871; Маркер выборки: 0; Число нарезок: 0
# [0-200]=> Headliner: № 154 -> Длина записи: 1668719; Маркер выборки: 1; Число нарезок: 12
# [0-200]=> Headliner: № 155 -> Длина записи: 460271; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 156 -> Длина записи: 284591; Маркер выборки: 1; Число нарезок: 2
# [0-200]=> Headliner: № 157 -> Длина записи: 542639; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 158 -> Длина записи: 303023; Маркер выборки: 1; Число нарезок: 2
# [0-200]=> Headliner: № 159 -> Длина записи: 254639; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 160 -> Длина записи: 2030447; Маркер выборки: 1; Число нарезок: 14
# [0-200]=> Headliner: № 161 -> Длина записи: 453359; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 162 -> Длина записи: 2438255; Маркер выборки: 1; Число нарезок: 17
# [0-200]=> Headliner: № 163 -> Длина записи: 256367; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 164 -> Длина записи: 2113967; Маркер выборки: 1; Число нарезок: 15
# [0-200]=> Headliner: № 165 -> Длина записи: 329519; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 166 -> Длина записи: 1699247; Маркер выборки: 1; Число нарезок: 12
# [0-200]=> Headliner: № 167 -> Длина записи: 352559; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 168 -> Длина записи: 777647; Маркер выборки: 1; Число нарезок: 5
# [0-200]=> Headliner: № 169 -> Длина записи: 325487; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 170 -> Длина записи: 960239; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 171 -> Длина записи: 153839; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 172 -> Длина записи: 1501679; Маркер выборки: 1; Число нарезок: 10
# [0-200]=> Headliner: № 173 -> Длина записи: 620399; Маркер выборки: 0; Число нарезок: 4
# [0-200]=> Headliner: № 174 -> Длина записи: 949871; Маркер выборки: 1; Число нарезок: 6
# [0-200]=> Headliner: № 175 -> Длина записи: 456239; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 176 -> Длина записи: 1135343; Маркер выборки: 1; Число нарезок: 8
# [0-200]=> Headliner: № 177 -> Длина записи: 305327; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 178 -> Длина записи: 2511983; Маркер выборки: 1; Число нарезок: 18
# [0-200]=> Headliner: № 179 -> Длина записи: 895151; Маркер выборки: 0; Число нарезок: 6
# [0-200]=> Headliner: № 180 -> Длина записи: 3756719; Маркер выборки: 1; Число нарезок: 27
# [0-200]=> Headliner: № 181 -> Длина записи: 2261999; Маркер выборки: 0; Число нарезок: 16
# [0-200]=> Headliner: № 182 -> Длина записи: 2989487; Маркер выборки: 1; Число нарезок: 21
# [0-200]=> Headliner: № 183 -> Длина записи: 338159; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 184 -> Длина записи: 1365167; Маркер выборки: 1; Число нарезок: 9
# [0-200]=> Headliner: № 185 -> Длина записи: 281135; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 186 -> Длина записи: 2653103; Маркер выборки: 1; Число нарезок: 19
# [0-200]=> Headliner: № 187 -> Длина записи: 186095; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 188 -> Длина записи: 1865711; Маркер выборки: 1; Число нарезок: 13
# [0-200]=> Headliner: № 189 -> Длина записи: 163631; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 190 -> Длина записи: 6219119; Маркер выборки: 1; Число нарезок: 45
# [0-200]=> Headliner: № 191 -> Длина записи: 865199; Маркер выборки: 0; Число нарезок: 6
# [0-200]=> Headliner: № 192 -> Длина записи: 2986031; Маркер выборки: 1; Число нарезок: 21
# [0-200]=> Headliner: № 193 -> Длина записи: 506927; Маркер выборки: 0; Число нарезок: 3
# [0-200]=> Headliner: № 194 -> Длина записи: 6783023; Маркер выборки: 1; Число нарезок: 49
# [0-200]=> Headliner: № 195 -> Длина записи: 380207; Маркер выборки: 0; Число нарезок: 2
# [0-200]=> Headliner: № 196 -> Длина записи: 2812079; Маркер выборки: 1; Число нарезок: 20
# [0-200]=> Headliner: № 197 -> Длина записи: 145199; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 198 -> Длина записи: 1714223; Маркер выборки: 1; Число нарезок: 12
# [0-200]=> Headliner: № 199 -> Длина записи: 247151; Маркер выборки: 0; Число нарезок: 1
# [0-200]=> Headliner: № 200 -> Длина записи: 1190639; Маркер выборки: 1; Число нарезок: 8
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 137781, 1)]       0
#
#  conv1d (Conv1D)             (None, 19683, 128)        512
#
#  batch_normalization (Batch  (None, 19683, 128)        512
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 19683, 128)        49280
#
#  max_pooling1d (MaxPooling1  (None, 6561, 128)         0
#  D)
#
#  batch_normalization_1 (Bat  (None, 6561, 128)         512
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 6561, 128)         49280
#
#  max_pooling1d_1 (MaxPoolin  (None, 2187, 128)         0
#  g1D)
#
#  batch_normalization_2 (Bat  (None, 2187, 128)         512
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 2187, 256)         98560
#
#  max_pooling1d_2 (MaxPoolin  (None, 729, 256)          0
#  g1D)
#
#  batch_normalization_3 (Bat  (None, 729, 256)          1024
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 729, 256)          196864
#
#  max_pooling1d_3 (MaxPoolin  (None, 243, 256)          0
#  g1D)
#
#  batch_normalization_4 (Bat  (None, 243, 256)          1024
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 243, 256)          196864
#
#  max_pooling1d_4 (MaxPoolin  (None, 81, 256)           0
#  g1D)
#
#  batch_normalization_5 (Bat  (None, 81, 256)           1024
#  chNormalization)
#
#  conv1d_6 (Conv1D)           (None, 81, 256)           196864
#
#  max_pooling1d_5 (MaxPoolin  (None, 27, 256)           0
#  g1D)
#
#  batch_normalization_6 (Bat  (None, 27, 256)           1024
#  chNormalization)
#
#  conv1d_7 (Conv1D)           (None, 27, 256)           196864
#
#  max_pooling1d_6 (MaxPoolin  (None, 9, 256)            0
#  g1D)
#
#  batch_normalization_7 (Bat  (None, 9, 256)            1024
#  chNormalization)
#
#  conv1d_8 (Conv1D)           (None, 9, 512)            393728
#
#  max_pooling1d_7 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  batch_normalization_8 (Bat  (None, 3, 512)            2048
#  chNormalization)
#
#  conv1d_9 (Conv1D)           (None, 3, 512)            786944
#
#  max_pooling1d_8 (MaxPoolin  (None, 1, 512)            0
#  g1D)
#
#  batch_normalization_9 (Bat  (None, 1, 512)            2048
#  chNormalization)
#
#  conv1d_10 (Conv1D)          (None, 1, 512)            262656
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 2)                 1026
#
# =================================================================
# Total params: 2440194 (9.31 MB)
# Trainable params: 2434818 (9.29 MB)
# Non-trainable params: 5376 (21.00 KB)
# _________________________________________________________________
# XTrain1.shape:  (3210, 137781, 1)
# YTrain1.shape:  (3210, 2)
# XTrain1V.shape:  (287, 137781, 1)
# YTrain1V.shape:  (287, 2)
# Обучающая выборка X_Train1 - Целевых: 2734; Нецелевых: 476
# Валидационная выборка X_Train1V - Целевых: 268; Нецелевых: 19
# Epoch 1/20
# 26/26 [==============================] - 55s 1s/step - loss: 1.4228 - accuracy: 0.7601 - val_loss: 26.8218 - val_accuracy: 0.9338
# Epoch 2/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.7043 - accuracy: 0.8178 - val_loss: 0.2656 - val_accuracy: 0.9338
# Epoch 3/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.5859 - accuracy: 0.8221 - val_loss: 0.4318 - val_accuracy: 0.9338
# Epoch 4/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.4385 - accuracy: 0.8402 - val_loss: 3.2148 - val_accuracy: 0.9338
# Epoch 5/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.4343 - accuracy: 0.8449 - val_loss: 0.4714 - val_accuracy: 0.9338
# Epoch 6/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.4348 - accuracy: 0.8421 - val_loss: 0.4689 - val_accuracy: 0.9268
# Epoch 7/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.4114 - accuracy: 0.8467 - val_loss: 2.9897 - val_accuracy: 0.9338
# Epoch 8/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3846 - accuracy: 0.8517 - val_loss: 0.3348 - val_accuracy: 0.9338
# Epoch 9/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3643 - accuracy: 0.8517 - val_loss: 0.2797 - val_accuracy: 0.9338
# Epoch 10/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3458 - accuracy: 0.8517 - val_loss: 0.2901 - val_accuracy: 0.9338
# Epoch 11/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.3363 - accuracy: 0.8517 - val_loss: 0.2597 - val_accuracy: 0.9338
# Epoch 12/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.3265 - accuracy: 0.8517 - val_loss: 0.2743 - val_accuracy: 0.9338
# Epoch 13/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.3181 - accuracy: 0.8517 - val_loss: 0.2487 - val_accuracy: 0.9338
# Epoch 14/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.3273 - accuracy: 0.8517 - val_loss: 0.2858 - val_accuracy: 0.9338
# Epoch 15/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3183 - accuracy: 0.8520 - val_loss: 0.7277 - val_accuracy: 0.9338
# Epoch 16/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3585 - accuracy: 0.8461 - val_loss: 0.2719 - val_accuracy: 0.9338
# Epoch 17/20
# 26/26 [==============================] - 28s 1s/step - loss: 0.3319 - accuracy: 0.8520 - val_loss: 0.3553 - val_accuracy: 0.9338
# Epoch 18/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3094 - accuracy: 0.8517 - val_loss: 0.3044 - val_accuracy: 0.9338
# Epoch 19/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.3090 - accuracy: 0.8517 - val_loss: 0.6659 - val_accuracy: 0.9338
# Epoch 20/20
# 26/26 [==============================] - 29s 1s/step - loss: 0.2878 - accuracy: 0.8492 - val_loss: 0.2971 - val_accuracy: 0.9338
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [0_200] - 1-й из 21
#
# Запущен блок [200_400] - 2-й из 21
# [200-400]=> Headliner: № 201 -> Длина записи: 240815; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 202 -> Длина записи: 2676143; Маркер выборки: 1; Число нарезок: 19
# [200-400]=> Headliner: № 203 -> Длина записи: 245999; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 204 -> Длина записи: 2593775; Маркер выборки: 1; Число нарезок: 18
# [200-400]=> Headliner: № 205 -> Длина записи: 192431; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 206 -> Длина записи: 6835439; Маркер выборки: 1; Число нарезок: 49
# [200-400]=> Headliner: № 207 -> Длина записи: 512687; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 208 -> Длина записи: 2294831; Маркер выборки: 1; Число нарезок: 16
# [200-400]=> Headliner: № 209 -> Длина записи: 88751; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 210 -> Длина записи: 779375; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 211 -> Длина записи: 243119; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 212 -> Длина записи: 3459503; Маркер выборки: 1; Число нарезок: 25
# [200-400]=> Headliner: № 213 -> Длина записи: 310511; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 214 -> Длина записи: 1438319; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 215 -> Длина записи: 268463; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 216 -> Длина записи: 4523375; Маркер выборки: 1; Число нарезок: 32
# [200-400]=> Headliner: № 217 -> Длина записи: 302447; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 218 -> Длина записи: 3773423; Маркер выборки: 1; Число нарезок: 27
# [200-400]=> Headliner: № 219 -> Длина записи: 101423; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 220 -> Длина записи: 566255; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 221 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 222 -> Длина записи: 428015; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 223 -> Длина записи: 272495; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 224 -> Длина записи: 2243567; Маркер выборки: 1; Число нарезок: 16
# [200-400]=> Headliner: № 225 -> Длина записи: 267311; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 226 -> Длина записи: 3090863; Маркер выборки: 1; Число нарезок: 22
# [200-400]=> Headliner: № 227 -> Длина записи: 492527; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 228 -> Длина записи: 1877231; Маркер выборки: 1; Число нарезок: 13
# [200-400]=> Headliner: № 229 -> Длина записи: 219503; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 230 -> Длина записи: 1339823; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 231 -> Длина записи: 419951; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 232 -> Длина записи: 1142831; Маркер выборки: 1; Число нарезок: 8
# [200-400]=> Headliner: № 233 -> Длина записи: 1255151; Маркер выборки: 0; Число нарезок: 9
# [200-400]=> Headliner: № 234 -> Длина записи: 1787951; Маркер выборки: 1; Число нарезок: 12
# [200-400]=> Headliner: № 235 -> Длина записи: 280559; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 236 -> Длина записи: 1685423; Маркер выборки: 1; Число нарезок: 12
# [200-400]=> Headliner: № 237 -> Длина записи: 121007; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 238 -> Длина записи: 487343; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 239 -> Длина записи: 627311; Маркер выборки: 0; Число нарезок: 4
# [200-400]=> Headliner: № 240 -> Длина записи: 8729903; Маркер выборки: 1; Число нарезок: 63
# [200-400]=> Headliner: № 241 -> Длина записи: 85871; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 242 -> Длина записи: 604847; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 243 -> Длина записи: 507503; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 244 -> Длина записи: 2559791; Маркер выборки: 1; Число нарезок: 18
# [200-400]=> Headliner: № 245 -> Длина записи: 331247; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 246 -> Длина записи: 625007; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 247 -> Длина записи: 530543; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 248 -> Длина записи: 2153711; Маркер выборки: 1; Число нарезок: 15
# [200-400]=> Headliner: № 249 -> Длина записи: 297839; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 250 -> Длина записи: 2688815; Маркер выборки: 1; Число нарезок: 19
# [200-400]=> Headliner: № 251 -> Длина записи: 1434863; Маркер выборки: 0; Число нарезок: 10
# [200-400]=> Headliner: № 252 -> Длина записи: 4101167; Маркер выборки: 1; Число нарезок: 29
# [200-400]=> Headliner: № 253 -> Длина записи: 206831; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 254 -> Длина записи: 1455023; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 255 -> Длина записи: 194735; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 256 -> Длина записи: 974639; Маркер выборки: 1; Число нарезок: 7
# [200-400]=> Headliner: № 257 -> Длина записи: 255791; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 258 -> Длина записи: 945839; Маркер выборки: 1; Число нарезок: 6
# [200-400]=> Headliner: № 259 -> Длина записи: 238511; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 260 -> Длина записи: 4655855; Маркер выборки: 1; Число нарезок: 33
# [200-400]=> Headliner: № 261 -> Длина записи: 688943; Маркер выборки: 0; Число нарезок: 5
# [200-400]=> Headliner: № 262 -> Длина записи: 1823087; Маркер выборки: 1; Число нарезок: 13
# [200-400]=> Headliner: № 263 -> Длина записи: 766127; Маркер выборки: 0; Число нарезок: 5
# [200-400]=> Headliner: № 264 -> Длина записи: 908399; Маркер выборки: 1; Число нарезок: 6
# [200-400]=> Headliner: № 265 -> Длина записи: 192431; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 266 -> Длина записи: 1443503; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 267 -> Длина записи: 223535; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 268 -> Длина записи: 4457135; Маркер выборки: 1; Число нарезок: 32
# [200-400]=> Headliner: № 269 -> Длина записи: 489071; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 270 -> Длина записи: 1762031; Маркер выборки: 1; Число нарезок: 12
# [200-400]=> Headliner: № 271 -> Длина записи: 106031; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 272 -> Длина записи: 744815; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 273 -> Длина записи: 412463; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 274 -> Длина записи: 3386351; Маркер выборки: 1; Число нарезок: 24
# [200-400]=> Headliner: № 275 -> Длина записи: 550703; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 276 -> Длина записи: 1554671; Маркер выборки: 1; Число нарезок: 11
# [200-400]=> Headliner: № 277 -> Длина записи: 182063; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 278 -> Длина записи: 1417007; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 279 -> Длина записи: 198191; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 280 -> Длина записи: 3736559; Маркер выборки: 1; Число нарезок: 27
# [200-400]=> Headliner: № 281 -> Длина записи: 309935; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 282 -> Длина записи: 2654255; Маркер выборки: 1; Число нарезок: 19
# [200-400]=> Headliner: № 283 -> Длина записи: 347951; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 284 -> Длина записи: 2528687; Маркер выборки: 1; Число нарезок: 18
# [200-400]=> Headliner: № 285 -> Длина записи: 849647; Маркер выборки: 0; Число нарезок: 6
# [200-400]=> Headliner: № 286 -> Длина записи: 542639; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 287 -> Длина записи: 281711; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 288 -> Длина записи: 1309295; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 289 -> Длина записи: 444719; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 290 -> Длина записи: 2177327; Маркер выборки: 1; Число нарезок: 15
# [200-400]=> Headliner: № 291 -> Длина записи: 446447; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 292 -> Длина записи: 720047; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 293 -> Длина записи: 499439; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 294 -> Длина записи: 3915695; Маркер выборки: 1; Число нарезок: 28
# [200-400]=> Headliner: № 295 -> Длина записи: 447023; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 296 -> Длина записи: 1054127; Маркер выборки: 1; Число нарезок: 7
# [200-400]=> Headliner: № 297 -> Длина записи: 926831; Маркер выборки: 0; Число нарезок: 6
# [200-400]=> Headliner: № 298 -> Длина записи: 1468847; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 299 -> Длина записи: 346799; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 300 -> Длина записи: 3017711; Маркер выборки: 1; Число нарезок: 21
# [200-400]=> Headliner: № 301 -> Длина записи: 555887; Маркер выборки: 0; Число нарезок: 4
# [200-400]=> Headliner: № 302 -> Длина записи: 2031599; Маркер выборки: 1; Число нарезок: 14
# [200-400]=> Headliner: № 303 -> Длина записи: 1020143; Маркер выборки: 0; Число нарезок: 7
# [200-400]=> Headliner: № 304 -> Длина записи: 998831; Маркер выборки: 1; Число нарезок: 7
# [200-400]=> Headliner: № 305 -> Длина записи: 330671; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 306 -> Длина записи: 203375; Маркер выборки: 1; Число нарезок: 1
# [200-400]=> Headliner: № 307 -> Длина записи: 412463; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 308 -> Длина записи: 893999; Маркер выборки: 1; Число нарезок: 6
# [200-400]=> Headliner: № 309 -> Длина записи: 433775; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 310 -> Длина записи: 2115695; Маркер выборки: 1; Число нарезок: 15
# [200-400]=> Headliner: № 311 -> Длина записи: 470639; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 312 -> Длина записи: 548399; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 313 -> Длина записи: 288623; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 314 -> Длина записи: 509807; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 315 -> Длина записи: 197615; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 316 -> Длина записи: 1540271; Маркер выборки: 1; Число нарезок: 11
# [200-400]=> Headliner: № 317 -> Длина записи: 239087; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 318 -> Длина записи: 1273583; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 319 -> Длина записи: 1143407; Маркер выборки: 0; Число нарезок: 8
# [200-400]=> Headliner: № 320 -> Длина записи: 1853615; Маркер выборки: 1; Число нарезок: 13
# [200-400]=> Headliner: № 321 -> Длина записи: 81263; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 322 -> Длина записи: 1873199; Маркер выборки: 1; Число нарезок: 13
# [200-400]=> Headliner: № 323 -> Длина записи: 351407; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 324 -> Длина записи: 1924463; Маркер выборки: 1; Число нарезок: 13
# [200-400]=> Headliner: № 325 -> Длина записи: 1923311; Маркер выборки: 0; Число нарезок: 13
# [200-400]=> Headliner: № 326 -> Длина записи: 3170351; Маркер выборки: 1; Число нарезок: 23
# [200-400]=> Headliner: № 327 -> Длина записи: 429743; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 328 -> Длина записи: 696431; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 329 -> Длина записи: 1024175; Маркер выборки: 0; Число нарезок: 7
# [200-400]=> Headliner: № 330 -> Длина записи: 4442735; Маркер выборки: 1; Число нарезок: 32
# [200-400]=> Headliner: № 331 -> Длина записи: 202799; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 332 -> Длина записи: 600239; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 333 -> Длина записи: 297839; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 334 -> Длина записи: 1531055; Маркер выборки: 1; Число нарезок: 11
# [200-400]=> Headliner: № 335 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 336 -> Длина записи: 995951; Маркер выборки: 1; Число нарезок: 7
# [200-400]=> Headliner: № 337 -> Длина записи: 125039; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 338 -> Длина записи: 537455; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 339 -> Длина записи: 131375; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 340 -> Длина записи: 2947439; Маркер выборки: 1; Число нарезок: 21
# [200-400]=> Headliner: № 341 -> Длина записи: 346223; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 342 -> Длина записи: 1289711; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 343 -> Длина записи: 485039; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 344 -> Длина записи: 2070767; Маркер выборки: 1; Число нарезок: 15
# [200-400]=> Headliner: № 345 -> Длина записи: 255791; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 346 -> Длина записи: 2178479; Маркер выборки: 1; Число нарезок: 15
# [200-400]=> Headliner: № 347 -> Длина записи: 202223; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 348 -> Длина записи: 4318319; Маркер выборки: 1; Число нарезок: 31
# [200-400]=> Headliner: № 349 -> Длина записи: 103151; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 350 -> Длина записи: 1376687; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 351 -> Длина записи: 719471; Маркер выборки: 0; Число нарезок: 5
# [200-400]=> Headliner: № 352 -> Длина записи: 1360559; Маркер выборки: 1; Число нарезок: 9
# [200-400]=> Headliner: № 353 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 354 -> Длина записи: 3532655; Маркер выборки: 1; Число нарезок: 25
# [200-400]=> Headliner: № 355 -> Длина записи: 187247; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 356 -> Длина записи: 1759727; Маркер выборки: 1; Число нарезок: 12
# [200-400]=> Headliner: № 357 -> Длина записи: 157871; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 358 -> Длина записи: 4724399; Маркер выборки: 1; Число нарезок: 34
# [200-400]=> Headliner: № 359 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 360 -> Длина записи: 1422191; Маркер выборки: 1; Число нарезок: 10
# [200-400]=> Headliner: № 361 -> Длина записи: 126191; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 362 -> Длина записи: 341615; Маркер выборки: 1; Число нарезок: 2
# [200-400]=> Headliner: № 363 -> Длина записи: 430319; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 364 -> Длина записи: 2920367; Маркер выборки: 1; Число нарезок: 21
# [200-400]=> Headliner: № 365 -> Длина записи: 471215; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 366 -> Длина записи: 637103; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 367 -> Длина записи: 1430255; Маркер выборки: 0; Число нарезок: 10
# [200-400]=> Headliner: № 368 -> Длина записи: 448175; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 369 -> Длина записи: 214895; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 370 -> Длина записи: 695279; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 371 -> Длина записи: 491375; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 372 -> Длина записи: 1932527; Маркер выборки: 1; Число нарезок: 14
# [200-400]=> Headliner: № 373 -> Длина записи: 224111; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 374 -> Длина записи: 2026991; Маркер выборки: 1; Число нарезок: 14
# [200-400]=> Headliner: № 375 -> Длина записи: 1700399; Маркер выборки: 0; Число нарезок: 12
# [200-400]=> Headliner: № 376 -> Длина записи: 3593135; Маркер выборки: 1; Число нарезок: 26
# [200-400]=> Headliner: № 377 -> Длина записи: 245423; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 378 -> Длина записи: 2376047; Маркер выборки: 1; Число нарезок: 17
# [200-400]=> Headliner: № 379 -> Длина записи: 330671; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 380 -> Длина записи: 687215; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 381 -> Длина записи: 326639; Маркер выборки: 0; Число нарезок: 2
# [200-400]=> Headliner: № 382 -> Длина записи: 1646255; Маркер выборки: 1; Число нарезок: 11
# [200-400]=> Headliner: № 383 -> Длина записи: 93935; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 384 -> Длина записи: 1939439; Маркер выборки: 1; Число нарезок: 14
# [200-400]=> Headliner: № 385 -> Длина записи: 80111; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 386 -> Длина записи: 1571375; Маркер выборки: 1; Число нарезок: 11
# [200-400]=> Headliner: № 387 -> Длина записи: 687791; Маркер выборки: 0; Число нарезок: 4
# [200-400]=> Headliner: № 388 -> Длина записи: 472943; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 389 -> Длина записи: 85871; Маркер выборки: 0; Число нарезок: 0
# [200-400]=> Headliner: № 390 -> Длина записи: 678575; Маркер выборки: 1; Число нарезок: 4
# [200-400]=> Headliner: № 391 -> Длина записи: 460271; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 392 -> Длина записи: 261551; Маркер выборки: 1; Число нарезок: 1
# [200-400]=> Headliner: № 393 -> Длина записи: 542639; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 394 -> Длина записи: 504623; Маркер выборки: 1; Число нарезок: 3
# [200-400]=> Headliner: № 395 -> Длина записи: 254639; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 396 -> Длина записи: 2729711; Маркер выборки: 1; Число нарезок: 19
# [200-400]=> Headliner: № 397 -> Длина записи: 453359; Маркер выборки: 0; Число нарезок: 3
# [200-400]=> Headliner: № 398 -> Длина записи: 722351; Маркер выборки: 1; Число нарезок: 5
# [200-400]=> Headliner: № 399 -> Длина записи: 256367; Маркер выборки: 0; Число нарезок: 1
# [200-400]=> Headliner: № 400 -> Длина записи: 2226287; Маркер выборки: 1; Число нарезок: 16
#
# XTrain1.shape:  (2943, 137781, 1)
# YTrain1.shape:  (2943, 2)
# XTrain1V.shape:  (256, 137781, 1)
# YTrain1V.shape:  (256, 2)
# Обучающая выборка X_Train1 - Целевых: 5248; Нецелевых: 905
# Валидационная выборка X_Train1V - Целевых: 509; Нецелевых: 34
# Epoch 1/20
# 23/23 [==============================] - 42s 2s/step - loss: 0.3307 - accuracy: 0.8546 - val_loss: 0.3807 - val_accuracy: 0.9414
# Epoch 2/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.3242 - accuracy: 0.8542 - val_loss: 0.3038 - val_accuracy: 0.9414
# Epoch 3/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2922 - accuracy: 0.8536 - val_loss: 2.9353 - val_accuracy: 0.9414
# Epoch 4/20
# 23/23 [==============================] - 27s 1s/step - loss: 0.2822 - accuracy: 0.8539 - val_loss: 0.3356 - val_accuracy: 0.9414
# Epoch 5/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2667 - accuracy: 0.8532 - val_loss: 0.3273 - val_accuracy: 0.9414
# Epoch 6/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2454 - accuracy: 0.8546 - val_loss: 0.2490 - val_accuracy: 0.9414
# Epoch 7/20
# 23/23 [==============================] - 27s 1s/step - loss: 0.2787 - accuracy: 0.8525 - val_loss: 0.2347 - val_accuracy: 0.9414
# Epoch 8/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2750 - accuracy: 0.8539 - val_loss: 0.2421 - val_accuracy: 0.9414
# Epoch 9/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2476 - accuracy: 0.8559 - val_loss: 0.4464 - val_accuracy: 0.9414
# Epoch 10/20
# 23/23 [==============================] - 27s 1s/step - loss: 0.2250 - accuracy: 0.8739 - val_loss: 0.2859 - val_accuracy: 0.9375
# Epoch 11/20
# 23/23 [==============================] - 27s 1s/step - loss: 0.2216 - accuracy: 0.8896 - val_loss: 0.4287 - val_accuracy: 0.9414
# Epoch 12/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2303 - accuracy: 0.8872 - val_loss: 0.3209 - val_accuracy: 0.9414
# Epoch 13/20
# 23/23 [==============================] - 27s 1s/step - loss: 0.2367 - accuracy: 0.8848 - val_loss: 0.5226 - val_accuracy: 0.9414
# Epoch 14/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2186 - accuracy: 0.8933 - val_loss: 1.6902 - val_accuracy: 0.9414
# Epoch 15/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2097 - accuracy: 0.9069 - val_loss: 2.4566 - val_accuracy: 0.9414
# Epoch 16/20
# 23/23 [==============================] - 26s 1s/step - loss: 0.2099 - accuracy: 0.9083 - val_loss: 0.5161 - val_accuracy: 0.7695
# Epoch 17/20
# ...
# [600-800]=> Headliner: № 634 -> Длина записи: 1296047; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 635 -> Длина записи: 87023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 636 -> Длина записи: 3524591; Маркер выборки: 1; Число нарезок: 25
# [600-800]=> Paveletskaya_city: № 637 -> Длина записи: 169391; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 638 -> Длина записи: 591023; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 639 -> Длина записи: 57647; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 640 -> Длина записи: 557039; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 641 -> Длина записи: 168815; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 642 -> Длина записи: 3016559; Маркер выборки: 1; Число нарезок: 21
# [600-800]=> Paveletskaya_city: № 643 -> Длина записи: 31727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 644 -> Длина записи: 4201391; Маркер выборки: 1; Число нарезок: 30
# [600-800]=> Paveletskaya_city: № 645 -> Длина записи: 57071; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 646 -> Длина записи: 2816687; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 647 -> Длина записи: 218351; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 648 -> Длина записи: 3094319; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 649 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 650 -> Длина записи: 2009135; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 651 -> Длина записи: 78383; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 652 -> Длина записи: 941231; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 653 -> Длина записи: 7535; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 654 -> Длина записи: 1683119; Маркер выборки: 1; Число нарезок: 12
# [600-800]=> Paveletskaya_city: № 655 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 656 -> Длина записи: 2476847; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 657 -> Длина записи: 153839; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 658 -> Длина записи: 656111; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 659 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 660 -> Длина записи: 1377839; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 661 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 662 -> Длина записи: 1114607; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 663 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 664 -> Длина записи: 2636975; Маркер выборки: 1; Число нарезок: 19
# [600-800]=> Paveletskaya_city: № 665 -> Длина записи: 121007; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 666 -> Длина записи: 1237295; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 667 -> Длина записи: 158447; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 668 -> Длина записи: 4496303; Маркер выборки: 1; Число нарезок: 32
# [600-800]=> Paveletskaya_city: № 669 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 670 -> Длина записи: 6785327; Маркер выборки: 1; Число нарезок: 49
# [600-800]=> Paveletskaya_city: № 671 -> Длина записи: 142319; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 672 -> Длина записи: 1730351; Маркер выборки: 1; Число нарезок: 12
# [600-800]=> Paveletskaya_city: № 673 -> Длина записи: 212591; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 674 -> Длина записи: 991919; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 675 -> Длина записи: 13871; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 676 -> Длина записи: 2252783; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 677 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 678 -> Длина записи: 726959; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 679 -> Длина записи: 49583; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 680 -> Длина записи: 854255; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 681 -> Длина записи: 210287; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 682 -> Длина записи: 1943471; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 683 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 684 -> Длина записи: 1111151; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 685 -> Длина записи: 23087; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 686 -> Длина записи: 1126127; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 687 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 688 -> Длина записи: 1505711; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 689 -> Длина записи: 92783; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 690 -> Длина записи: 3795887; Маркер выборки: 1; Число нарезок: 27
# [600-800]=> Paveletskaya_city: № 691 -> Длина записи: 179183; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 692 -> Длина записи: 2226863; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 693 -> Длина записи: 182639; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 694 -> Длина записи: 3561455; Маркер выборки: 1; Число нарезок: 25
# [600-800]=> Paveletskaya_city: № 695 -> Длина записи: 183215; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 696 -> Длина записи: 2353583; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 697 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 698 -> Длина записи: 3066671; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 699 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 700 -> Длина записи: 827183; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 701 -> Длина записи: 33455; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 702 -> Длина записи: 2400239; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 703 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 704 -> Длина записи: 1853039; Маркер выборки: 1; Число нарезок: 13
# [600-800]=> Paveletskaya_city: № 705 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 706 -> Длина записи: 460847; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 707 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 708 -> Длина записи: 552431; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 709 -> Длина записи: 28847; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 710 -> Длина записи: 3919151; Маркер выборки: 1; Число нарезок: 28
# [600-800]=> Paveletskaya_city: № 711 -> Длина записи: 26543; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 712 -> Длина записи: 993647; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 713 -> Длина записи: 217199; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 714 -> Длина записи: 2105327; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 715 -> Длина записи: 207407; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 716 -> Длина записи: 1042607; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 717 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 718 -> Длина записи: 1046639; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 719 -> Длина записи: 42671; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 720 -> Длина записи: 3068975; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 721 -> Длина записи: 66287; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 722 -> Длина записи: 1809839; Маркер выборки: 1; Число нарезок: 13
# [600-800]=> Paveletskaya_city: № 723 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 724 -> Длина записи: 2103599; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 725 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 726 -> Длина записи: 754031; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 727 -> Длина записи: 108911; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 728 -> Длина записи: 1152047; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 729 -> Длина записи: 214319; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 730 -> Длина записи: 1653167; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 731 -> Длина записи: 172847; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 732 -> Длина записи: 529391; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 733 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 734 -> Длина записи: 354863; Маркер выборки: 1; Число нарезок: 2
# [600-800]=> Paveletskaya_city: № 735 -> Длина записи: 136559; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 736 -> Длина записи: 2768303; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 737 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 738 -> Длина записи: 578351; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 739 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 740 -> Длина записи: 2539631; Маркер выборки: 1; Число нарезок: 18
# [600-800]=> Paveletskaya_city: № 741 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 742 -> Длина записи: 555887; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 743 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 744 -> Длина записи: 4833839; Маркер выборки: 1; Число нарезок: 35
# [600-800]=> Paveletskaya_city: № 745 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 746 -> Длина записи: 2862191; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 747 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 748 -> Длина записи: 1413551; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 749 -> Длина записи: 103727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 750 -> Длина записи: 2087471; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 751 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 752 -> Длина записи: 6627503; Маркер выборки: 1; Число нарезок: 48
# [600-800]=> Paveletskaya_city: № 753 -> Длина записи: 161327; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 754 -> Длина записи: 872111; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 755 -> Длина записи: 18479; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 756 -> Длина записи: 1313327; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 757 -> Длина записи: 180911; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 758 -> Длина записи: 2221679; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 759 -> Длина записи: 44399; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 760 -> Длина записи: 819119; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 761 -> Длина записи: 19631; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 762 -> Длина записи: 510959; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 763 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 764 -> Длина записи: 542639; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 765 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 766 -> Длина записи: 787439; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 767 -> Длина записи: 8687; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 768 -> Длина записи: 2521199; Маркер выборки: 1; Число нарезок: 18
# [600-800]=> Paveletskaya_city: № 769 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 770 -> Длина записи: 1619183; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 771 -> Длина записи: 12719; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 772 -> Длина записи: 1373807; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 773 -> Длина записи: 97391; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 774 -> Длина записи: 1525871; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 775 -> Длина записи: 127343; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 776 -> Длина записи: 651503; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 777 -> Длина записи: 53039; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 778 -> Длина записи: 205103; Маркер выборки: 1; Число нарезок: 1
# [600-800]=> Paveletskaya_city: № 779 -> Длина записи: 43247; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 780 -> Длина записи: 936623; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 781 -> Длина записи: 50735; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 782 -> Длина записи: 385967; Маркер выборки: 1; Число нарезок: 2
# [600-800]=> Paveletskaya_city: № 783 -> Длина записи: 179183; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 784 -> Длина записи: 1236719; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 785 -> Длина записи: 36911; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 786 -> Длина записи: 3979055; Маркер выборки: 1; Число нарезок: 28
# [600-800]=> Paveletskaya_city: № 787 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 788 -> Длина записи: 3010799; Маркер выборки: 1; Число нарезок: 21
# [600-800]=> Paveletskaya_city: № 789 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 790 -> Длина записи: 4445039; Маркер выборки: 1; Число нарезок: 32
# [600-800]=> Paveletskaya_city: № 791 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 792 -> Длина записи: 2100719; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 793 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 794 -> Длина записи: 951599; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 795 -> Длина записи: 157871; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 796 -> Длина записи: 1618607; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 797 -> Длина записи: 49583; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 798 -> Длина записи: 3118511; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 799 -> Длина записи: 103727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 800 -> Длина записи: 2765999; Маркер выборки: 1; Число нарезок: 20
#
# XTrain1.shape:  (2720, 137781, 1)
# YTrain1.shape:  (2720, 2)
# XTrain1V.shape:  (266, 137781, 1)
# YTrain1V.shape:  (266, 2)
# Обучающая выборка X_Train1 - Целевых: 10756; Нецелевых: 1175
# Валидационная выборка X_Train1V - Целевых: 1060; Нецелевых: 45

# %% [markdown]
# ---

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [600_800] - 1-й из 18
# [600-800]=> Paveletskaya_city: № 1 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 2 -> Длина записи: 1931951; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 3 -> Длина записи: 133679; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 4 -> Длина записи: 1586927; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 5 -> Длина записи: 29423; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 6 -> Длина записи: 425711; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 7 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 8 -> Длина записи: 4136303; Маркер выборки: 1; Число нарезок: 30
# [600-800]=> Paveletskaya_city: № 9 -> Длина записи: 3454895; Маркер выборки: 0; Число нарезок: 25
# [600-800]=> Headliner: № 10 -> Длина записи: 5197871; Маркер выборки: 1; Число нарезок: 37
# [600-800]=> Paveletskaya_city: № 11 -> Длина записи: 91631; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 12 -> Длина записи: 8424047; Маркер выборки: 1; Число нарезок: 61
# [600-800]=> Paveletskaya_city: № 13 -> Длина записи: 26543; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 14 -> Длина записи: 2852399; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 15 -> Длина записи: 134831; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 16 -> Длина записи: 2058095; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 17 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 18 -> Длина записи: 868655; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 19 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 20 -> Длина записи: 3776879; Маркер выборки: 1; Число нарезок: 27
# [600-800]=> Paveletskaya_city: № 21 -> Длина записи: 84719; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 22 -> Длина записи: 1587503; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 23 -> Длина записи: 41519; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 24 -> Длина записи: 4420847; Маркер выборки: 1; Число нарезок: 32
# [600-800]=> Paveletskaya_city: № 25 -> Длина записи: 122159; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 26 -> Длина записи: 2364527; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 27 -> Длина записи: 8687; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 28 -> Длина записи: 2924399; Маркер выборки: 1; Число нарезок: 21
# [600-800]=> Paveletskaya_city: № 29 -> Длина записи: 78959; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 30 -> Длина записи: 438383; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 31 -> Длина записи: 125615; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 32 -> Длина записи: 1010351; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 33 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 34 -> Длина записи: 1296047; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 35 -> Длина записи: 87023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 36 -> Длина записи: 3524591; Маркер выборки: 1; Число нарезок: 25
# [600-800]=> Paveletskaya_city: № 37 -> Длина записи: 169391; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 38 -> Длина записи: 591023; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 39 -> Длина записи: 57647; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 40 -> Длина записи: 557039; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 41 -> Длина записи: 168815; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 42 -> Длина записи: 3016559; Маркер выборки: 1; Число нарезок: 21
# [600-800]=> Paveletskaya_city: № 43 -> Длина записи: 31727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 44 -> Длина записи: 4201391; Маркер выборки: 1; Число нарезок: 30
# [600-800]=> Paveletskaya_city: № 45 -> Длина записи: 57071; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 46 -> Длина записи: 2816687; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 47 -> Длина записи: 218351; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 48 -> Длина записи: 3094319; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 49 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 50 -> Длина записи: 2009135; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 51 -> Длина записи: 78383; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 52 -> Длина записи: 941231; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 53 -> Длина записи: 7535; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 54 -> Длина записи: 1683119; Маркер выборки: 1; Число нарезок: 12
# [600-800]=> Paveletskaya_city: № 55 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 56 -> Длина записи: 2476847; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 57 -> Длина записи: 153839; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 58 -> Длина записи: 656111; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 59 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 60 -> Длина записи: 1377839; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 61 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 62 -> Длина записи: 1114607; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 63 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 64 -> Длина записи: 2636975; Маркер выборки: 1; Число нарезок: 19
# [600-800]=> Paveletskaya_city: № 65 -> Длина записи: 121007; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 66 -> Длина записи: 1237295; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 67 -> Длина записи: 158447; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 68 -> Длина записи: 4496303; Маркер выборки: 1; Число нарезок: 32
# [600-800]=> Paveletskaya_city: № 69 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 70 -> Длина записи: 6785327; Маркер выборки: 1; Число нарезок: 49
# [600-800]=> Paveletskaya_city: № 71 -> Длина записи: 142319; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 72 -> Длина записи: 1730351; Маркер выборки: 1; Число нарезок: 12
# [600-800]=> Paveletskaya_city: № 73 -> Длина записи: 212591; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 74 -> Длина записи: 991919; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 75 -> Длина записи: 13871; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 76 -> Длина записи: 2252783; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 77 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 78 -> Длина записи: 726959; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 79 -> Длина записи: 49583; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 80 -> Длина записи: 854255; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 81 -> Длина записи: 210287; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 82 -> Длина записи: 1943471; Маркер выборки: 1; Число нарезок: 14
# [600-800]=> Paveletskaya_city: № 83 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 84 -> Длина записи: 1111151; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 85 -> Длина записи: 23087; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 86 -> Длина записи: 1126127; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 87 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 88 -> Длина записи: 1505711; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 89 -> Длина записи: 92783; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 90 -> Длина записи: 3795887; Маркер выборки: 1; Число нарезок: 27
# [600-800]=> Paveletskaya_city: № 91 -> Длина записи: 179183; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 92 -> Длина записи: 2226863; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 93 -> Длина записи: 182639; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 94 -> Длина записи: 3561455; Маркер выборки: 1; Число нарезок: 25
# [600-800]=> Paveletskaya_city: № 95 -> Длина записи: 183215; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 96 -> Длина записи: 2353583; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 97 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 98 -> Длина записи: 3066671; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 99 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 100 -> Длина записи: 827183; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 101 -> Длина записи: 33455; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 102 -> Длина записи: 2400239; Маркер выборки: 1; Число нарезок: 17
# [600-800]=> Paveletskaya_city: № 103 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 104 -> Длина записи: 1853039; Маркер выборки: 1; Число нарезок: 13
# [600-800]=> Paveletskaya_city: № 105 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 106 -> Длина записи: 460847; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 107 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 108 -> Длина записи: 552431; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 109 -> Длина записи: 28847; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 110 -> Длина записи: 3919151; Маркер выборки: 1; Число нарезок: 28
# [600-800]=> Paveletskaya_city: № 111 -> Длина записи: 26543; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 112 -> Длина записи: 993647; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 113 -> Длина записи: 217199; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 114 -> Длина записи: 2105327; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 115 -> Длина записи: 207407; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 116 -> Длина записи: 1042607; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 117 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 118 -> Длина записи: 1046639; Маркер выборки: 1; Число нарезок: 7
# [600-800]=> Paveletskaya_city: № 119 -> Длина записи: 42671; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 120 -> Длина записи: 3068975; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 121 -> Длина записи: 66287; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 122 -> Длина записи: 1809839; Маркер выборки: 1; Число нарезок: 13
# [600-800]=> Paveletskaya_city: № 123 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 124 -> Длина записи: 2103599; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 125 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 126 -> Длина записи: 754031; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 127 -> Длина записи: 108911; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 128 -> Длина записи: 1152047; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 129 -> Длина записи: 214319; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 130 -> Длина записи: 1653167; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 131 -> Длина записи: 172847; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 132 -> Длина записи: 529391; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 133 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 134 -> Длина записи: 354863; Маркер выборки: 1; Число нарезок: 2
# [600-800]=> Paveletskaya_city: № 135 -> Длина записи: 136559; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 136 -> Длина записи: 2768303; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 137 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 138 -> Длина записи: 578351; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 139 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 140 -> Длина записи: 2539631; Маркер выборки: 1; Число нарезок: 18
# [600-800]=> Paveletskaya_city: № 141 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 142 -> Длина записи: 555887; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 143 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 144 -> Длина записи: 4833839; Маркер выборки: 1; Число нарезок: 35
# [600-800]=> Paveletskaya_city: № 145 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 146 -> Длина записи: 2862191; Маркер выборки: 1; Число нарезок: 20
# [600-800]=> Paveletskaya_city: № 147 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 148 -> Длина записи: 1413551; Маркер выборки: 1; Число нарезок: 10
# [600-800]=> Paveletskaya_city: № 149 -> Длина записи: 103727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 150 -> Длина записи: 2087471; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 151 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 152 -> Длина записи: 6627503; Маркер выборки: 1; Число нарезок: 48
# [600-800]=> Paveletskaya_city: № 153 -> Длина записи: 161327; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 154 -> Длина записи: 872111; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 155 -> Длина записи: 18479; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 156 -> Длина записи: 1313327; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 157 -> Длина записи: 180911; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 158 -> Длина записи: 2221679; Маркер выборки: 1; Число нарезок: 16
# [600-800]=> Paveletskaya_city: № 159 -> Длина записи: 44399; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 160 -> Длина записи: 819119; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 161 -> Длина записи: 19631; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 162 -> Длина записи: 510959; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 163 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 164 -> Длина записи: 542639; Маркер выборки: 1; Число нарезок: 3
# [600-800]=> Paveletskaya_city: № 165 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 166 -> Длина записи: 787439; Маркер выборки: 1; Число нарезок: 5
# [600-800]=> Paveletskaya_city: № 167 -> Длина записи: 8687; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 168 -> Длина записи: 2521199; Маркер выборки: 1; Число нарезок: 18
# [600-800]=> Paveletskaya_city: № 169 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 170 -> Длина записи: 1619183; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 171 -> Длина записи: 12719; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 172 -> Длина записи: 1373807; Маркер выборки: 1; Число нарезок: 9
# [600-800]=> Paveletskaya_city: № 173 -> Длина записи: 97391; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 174 -> Длина записи: 1525871; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 175 -> Длина записи: 127343; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 176 -> Длина записи: 651503; Маркер выборки: 1; Число нарезок: 4
# [600-800]=> Paveletskaya_city: № 177 -> Длина записи: 53039; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 178 -> Длина записи: 205103; Маркер выборки: 1; Число нарезок: 1
# [600-800]=> Paveletskaya_city: № 179 -> Длина записи: 43247; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 180 -> Длина записи: 936623; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 181 -> Длина записи: 50735; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 182 -> Длина записи: 385967; Маркер выборки: 1; Число нарезок: 2
# [600-800]=> Paveletskaya_city: № 183 -> Длина записи: 179183; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 184 -> Длина записи: 1236719; Маркер выборки: 1; Число нарезок: 8
# [600-800]=> Paveletskaya_city: № 185 -> Длина записи: 36911; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 186 -> Длина записи: 3979055; Маркер выборки: 1; Число нарезок: 28
# [600-800]=> Paveletskaya_city: № 187 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 188 -> Длина записи: 3010799; Маркер выборки: 1; Число нарезок: 21
# [600-800]=> Paveletskaya_city: № 189 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 190 -> Длина записи: 4445039; Маркер выборки: 1; Число нарезок: 32
# [600-800]=> Paveletskaya_city: № 191 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 192 -> Длина записи: 2100719; Маркер выборки: 1; Число нарезок: 15
# [600-800]=> Paveletskaya_city: № 193 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 194 -> Длина записи: 951599; Маркер выборки: 1; Число нарезок: 6
# [600-800]=> Paveletskaya_city: № 195 -> Длина записи: 157871; Маркер выборки: 0; Число нарезок: 1
# [600-800]=> Headliner: № 196 -> Длина записи: 1618607; Маркер выборки: 1; Число нарезок: 11
# [600-800]=> Paveletskaya_city: № 197 -> Длина записи: 49583; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 198 -> Длина записи: 3118511; Маркер выборки: 1; Число нарезок: 22
# [600-800]=> Paveletskaya_city: № 199 -> Длина записи: 103727; Маркер выборки: 0; Число нарезок: 0
# [600-800]=> Headliner: № 200 -> Длина записи: 2765999; Маркер выборки: 1; Число нарезок: 20
#
# XTrain1.shape:  (2720, 137781, 1)
# YTrain1.shape:  (2720, 2)
# XTrain1V.shape:  (266, 137781, 1)
# YTrain1V.shape:  (266, 2)
# Обучающая выборка X_Train1 - Целевых: 2645; Нецелевых: 75
# Валидационная выборка X_Train1V - Целевых: 261; Нецелевых: 5
# Epoch 1/20
# 22/22 [==============================] - 51s 1s/step - loss: 0.1286 - accuracy: 0.9632 - val_loss: 0.2196 - val_accuracy: 0.9812
# Epoch 2/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0430 - accuracy: 0.9864 - val_loss: 0.8008 - val_accuracy: 0.9812
# Epoch 3/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.7305 - val_accuracy: 0.9812
# Epoch 4/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.5367 - val_accuracy: 0.9812
# Epoch 5/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.4177 - val_accuracy: 0.9812
# Epoch 6/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.4636 - val_accuracy: 0.9812
# Epoch 7/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.4585 - val_accuracy: 0.9812
# Epoch 8/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0394 - val_accuracy: 0.9925
# Epoch 9/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.5332 - val_accuracy: 0.9812
# Epoch 10/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9812
# Epoch 11/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.3143 - val_accuracy: 0.9812
# Epoch 12/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.1001 - val_accuracy: 0.9850
# Epoch 13/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0410 - val_accuracy: 0.9925
# Epoch 14/20
# 22/22 [==============================] - 25s 1s/step - loss: 5.2137e-04 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9925
# Epoch 15/20
# 22/22 [==============================] - 24s 1s/step - loss: 5.5850e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9887
# Epoch 16/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0302 - val_accuracy: 0.9887
# Epoch 17/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 2.8789e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 22/22 [==============================] - 24s 1s/step - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.0071 - val_accuracy: 0.9962
# Epoch 19/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0368 - accuracy: 0.9842 - val_loss: 0.5179 - val_accuracy: 0.8271
# Epoch 20/20
# 22/22 [==============================] - 25s 1s/step - loss: 0.0217 - accuracy: 0.9912 - val_loss: 0.0062 - val_accuracy: 0.9962
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [600_800] - 1-й из 18
#
# Запущен блок [800_1000] - 2-й из 18
# [800-1000]=> Paveletskaya_city: № 201 -> Длина записи: 117551; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 202 -> Длина записи: 650351; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 203 -> Длина записи: 104879; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 204 -> Длина записи: 5269871; Маркер выборки: 1; Число нарезок: 38
# [800-1000]=> Paveletskaya_city: № 205 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 206 -> Длина записи: 3154223; Маркер выборки: 1; Число нарезок: 22
# [800-1000]=> Paveletskaya_city: № 207 -> Длина записи: 56495; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 208 -> Длина записи: 3468719; Маркер выборки: 1; Число нарезок: 25
# [800-1000]=> Paveletskaya_city: № 209 -> Длина записи: 31727; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 210 -> Длина записи: 4040111; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 211 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 212 -> Длина записи: 805871; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 213 -> Длина записи: 84143; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 214 -> Длина записи: 1472879; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_city: № 215 -> Длина записи: 153263; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 216 -> Длина записи: 1114031; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 217 -> Длина записи: 112943; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 218 -> Длина записи: 2986607; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_city: № 219 -> Длина записи: 61679; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 220 -> Длина записи: 3433583; Маркер выборки: 1; Число нарезок: 24
# [800-1000]=> Paveletskaya_city: № 221 -> Длина записи: 82991; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 222 -> Длина записи: 1387631; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_city: № 223 -> Длина записи: 55919; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 224 -> Длина записи: 3091439; Маркер выборки: 1; Число нарезок: 22
# [800-1000]=> Paveletskaya_city: № 225 -> Длина записи: 50159; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 226 -> Длина записи: 2308655; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 227 -> Длина записи: 42671; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 228 -> Длина записи: 2250479; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 229 -> Длина записи: 182063; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 230 -> Длина записи: 4722095; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_city: № 231 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 232 -> Длина записи: 850223; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 233 -> Длина записи: 125039; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 234 -> Длина записи: 6639023; Маркер выборки: 1; Число нарезок: 48
# [800-1000]=> Paveletskaya_city: № 235 -> Длина записи: 62831; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 236 -> Длина записи: 798383; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 237 -> Длина записи: 13295; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 238 -> Длина записи: 1099631; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_city: № 239 -> Длина записи: 205679; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 240 -> Длина записи: 1529327; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 241 -> Длина записи: 62255; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 242 -> Длина записи: 1809263; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 243 -> Длина записи: 6383; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 244 -> Длина записи: 788591; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 245 -> Длина записи: 5231; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 246 -> Длина записи: 3790703; Маркер выборки: 1; Число нарезок: 27
# [800-1000]=> Paveletskaya_city: № 247 -> Длина записи: 78959; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 248 -> Длина записи: 2370863; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 249 -> Длина записи: 80111; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 250 -> Длина записи: 542063; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 251 -> Длина записи: 12143; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 252 -> Длина записи: 5273903; Маркер выборки: 1; Число нарезок: 38
# [800-1000]=> Paveletskaya_city: № 253 -> Длина записи: 90479; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 254 -> Длина записи: 2570159; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 255 -> Длина записи: 195887; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 256 -> Длина записи: 569711; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 257 -> Длина записи: 220655; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 258 -> Длина записи: 1060463; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_city: № 259 -> Длина записи: 128495; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 260 -> Длина записи: 448175; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 261 -> Длина записи: 30575; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 262 -> Длина записи: 633071; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 263 -> Длина записи: 207983; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 264 -> Длина записи: 4403567; Маркер выборки: 1; Число нарезок: 31
# [800-1000]=> Paveletskaya_city: № 265 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 266 -> Длина записи: 2494703; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 267 -> Длина записи: 131951; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 268 -> Длина записи: 2632367; Маркер выборки: 1; Число нарезок: 19
# [800-1000]=> Paveletskaya_city: № 269 -> Длина записи: 195311; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 270 -> Длина записи: 759791; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 271 -> Длина записи: 150383; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 272 -> Длина записи: 3639791; Маркер выборки: 1; Число нарезок: 26
# [800-1000]=> Paveletskaya_city: № 273 -> Длина записи: 104303; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 274 -> Длина записи: 2172719; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_city: № 275 -> Длина записи: 90479; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 276 -> Длина записи: 4725551; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_city: № 277 -> Длина записи: 175727; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 278 -> Длина записи: 4519919; Маркер выборки: 1; Число нарезок: 32
# [800-1000]=> Paveletskaya_city: № 279 -> Длина записи: 58223; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 280 -> Длина записи: 1736111; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 281 -> Длина записи: 87023; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 282 -> Длина записи: 1299503; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_city: № 283 -> Длина записи: 132527; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 284 -> Длина записи: 1627247; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 285 -> Длина записи: 20783; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 286 -> Длина записи: 464879; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 287 -> Длина записи: 38063; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 288 -> Длина записи: 2330543; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 289 -> Длина записи: 42095; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 290 -> Длина записи: 2930735; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_city: № 291 -> Длина записи: 69743; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 292 -> Длина записи: 1732655; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 293 -> Длина записи: 94511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 294 -> Длина записи: 2575343; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 295 -> Длина записи: 137135; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 296 -> Длина записи: 855983; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 297 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 298 -> Длина записи: 2412335; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 299 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 300 -> Длина записи: 722351; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 301 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 302 -> Длина записи: 2170991; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_city: № 303 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 304 -> Длина записи: 962543; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 305 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 306 -> Длина записи: 4049327; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 307 -> Длина записи: 68015; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 308 -> Длина записи: 271919; Маркер выборки: 1; Число нарезок: 1
# [800-1000]=> Paveletskaya_city: № 309 -> Длина записи: 84719; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 310 -> Длина записи: 1195823; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 311 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 312 -> Длина записи: 1614575; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 313 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 314 -> Длина записи: 2431343; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 315 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 316 -> Длина записи: 2836271; Маркер выборки: 1; Число нарезок: 20
# [800-1000]=> Paveletskaya_city: № 317 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 318 -> Длина записи: 2396783; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 319 -> Длина записи: 84719; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 320 -> Длина записи: 1105391; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 321 -> Длина записи: 52463; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 322 -> Длина записи: 1293743; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_city: № 323 -> Длина записи: 58223; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 324 -> Длина записи: 1828847; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 325 -> Длина записи: 220079; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 326 -> Длина записи: 895727; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 327 -> Длина записи: 34031; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 328 -> Длина записи: 873839; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 329 -> Длина записи: 77807; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 330 -> Длина записи: 4094831; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 331 -> Длина записи: 106607; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 332 -> Длина записи: 1845551; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 333 -> Длина записи: 22511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 334 -> Длина записи: 221231; Маркер выборки: 1; Число нарезок: 1
# [800-1000]=> Paveletskaya_city: № 335 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 336 -> Длина записи: 498863; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 337 -> Длина записи: 134831; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 338 -> Длина записи: 1217711; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 339 -> Длина записи: 153263; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 340 -> Длина записи: 1762031; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 341 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 342 -> Длина записи: 1656623; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 343 -> Длина записи: 23663; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 344 -> Длина записи: 1584047; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 345 -> Длина записи: 22511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 346 -> Длина записи: 1184879; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 347 -> Длина записи: 191279; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 348 -> Длина записи: 4566575; Маркер выборки: 1; Число нарезок: 33
# [800-1000]=> Paveletskaya_city: № 349 -> Длина записи: 55343; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 350 -> Длина записи: 5811887; Маркер выборки: 1; Число нарезок: 42
# [800-1000]=> Paveletskaya_turbo: № 351 -> Длина записи: 184367; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 352 -> Длина записи: 1018991; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 353 -> Длина записи: 169391; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 354 -> Длина записи: 812783; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 355 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 356 -> Длина записи: 2313263; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_turbo: № 357 -> Длина записи: 195887; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 358 -> Длина записи: 748271; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 359 -> Длина записи: 38063; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 360 -> Длина записи: 4737647; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_turbo: № 361 -> Длина записи: 220079; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 362 -> Длина записи: 1448111; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_turbo: № 363 -> Длина записи: 4655; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 364 -> Длина записи: 979823; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 365 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 366 -> Длина записи: 1063343; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 367 -> Длина записи: 160175; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 368 -> Длина записи: 1707311; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_turbo: № 369 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 370 -> Длина записи: 1072559; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 371 -> Длина записи: 3422639; Маркер выборки: 0; Число нарезок: 24
# [800-1000]=> Headliner: № 372 -> Длина записи: 1040879; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 373 -> Длина записи: 1023023; Маркер выборки: 0; Число нарезок: 7
# [800-1000]=> Headliner: № 374 -> Длина записи: 2104751; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_turbo: № 375 -> Длина записи: 639983; Маркер выборки: 0; Число нарезок: 4
# [800-1000]=> Headliner: № 376 -> Длина записи: 1045487; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 377 -> Длина записи: 293231; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 378 -> Длина записи: 5943791; Маркер выборки: 1; Число нарезок: 43
# [800-1000]=> Paveletskaya_turbo: № 379 -> Длина записи: 1836335; Маркер выборки: 0; Число нарезок: 13
# [800-1000]=> Headliner: № 380 -> Длина записи: 11733743; Маркер выборки: 1; Число нарезок: 85
# [800-1000]=> Paveletskaya_turbo: № 381 -> Длина записи: 33455; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 382 -> Длина записи: 3901295; Маркер выборки: 1; Число нарезок: 28
# [800-1000]=> Paveletskaya_turbo: № 383 -> Длина записи: 20248751; Маркер выборки: 0; Число нарезок: 146
# [800-1000]=> Headliner: № 384 -> Длина записи: 747119; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 385 -> Длина записи: 380783; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 386 -> Длина записи: 2877743; Маркер выборки: 1; Число нарезок: 20
# [800-1000]=> Paveletskaya_turbo: № 387 -> Длина записи: 134255; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 388 -> Длина записи: 1335215; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_turbo: № 389 -> Длина записи: 327215; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 390 -> Длина записи: 3238319; Маркер выборки: 1; Число нарезок: 23
# [800-1000]=> Paveletskaya_turbo: № 391 -> Длина записи: 63407; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 392 -> Длина записи: 550127; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_turbo: № 393 -> Длина записи: 106607; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 394 -> Длина записи: 1268975; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_turbo: № 395 -> Длина записи: 1138223; Маркер выборки: 0; Число нарезок: 8
# [800-1000]=> Headliner: № 396 -> Длина записи: 2974511; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_turbo: № 397 -> Длина записи: 4721519; Маркер выборки: 0; Число нарезок: 34
# [800-1000]=> Headliner: № 398 -> Длина записи: 3975023; Маркер выборки: 1; Число нарезок: 28
# [800-1000]=> Paveletskaya_turbo: № 399 -> Длина записи: 1726319; Маркер выборки: 0; Число нарезок: 12
# [800-1000]=> Headliner: № 400 -> Длина записи: 1672751; Маркер выборки: 1; Число нарезок: 12
#
# XTrain1.shape:  (3373, 137781, 1)
# YTrain1.shape:  (3373, 2)
# XTrain1V.shape:  (341, 137781, 1)
# YTrain1V.shape:  (341, 2)
# Обучающая выборка X_Train1 - Целевых: 5525; Нецелевых: 568
# Валидационная выборка X_Train1V - Целевых: 552; Нецелевых: 55
# Epoch 1/20
# 27/27 [==============================] - 45s 1s/step - loss: 0.3989 - accuracy: 0.8449 - val_loss: 27.5663 - val_accuracy: 0.9120
# Epoch 2/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.2084 - accuracy: 0.9271 - val_loss: 8.1527 - val_accuracy: 0.9355
# Epoch 3/20
# 27/27 [==============================] - 31s 1s/step - loss: 0.1882 - accuracy: 0.9277 - val_loss: 15.1667 - val_accuracy: 0.8739
# Epoch 4/20
# 27/27 [==============================] - 31s 1s/step - loss: 0.1500 - accuracy: 0.9286 - val_loss: 2.6601 - val_accuracy: 0.8944
# Epoch 5/20
# 13/27 [=============>................] - ETA: 15s - loss: 0.1299 - accuracy: 0.9327Время обработки: 1198.85 с
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-16-0f3a5489c9d8> in <cell line: 4>()
#     173
#     174     # Обучаем
# --> 175     trainModel(model_au, X_train1, Y_train1, X_train1V, Y_train1V, batch_size=128, epochs=20)
#     176     # Сохраняем
#     177     model_au.save(DUMP + '/model_au.h5')
#
# <ipython-input-12-90ac3d577340> in trainModel(model, X_train1, Y_train1, X_train1V, Y_train1V, batch_size, epochs)
#       1 def trainModel(model, X_train1, Y_train1, X_train1V, Y_train1V, batch_size, epochs):
#       2
# ----> 3   history = model.fit(X_train1,
#       4                       Y_train1,
#       5                       epochs=epochs,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node gradient_tape/model/max_pooling1d/MaxPool/MaxPoolGrad defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-16-0f3a5489c9d8>", line 175, in <cell line: 4>
#
#   File "<ipython-input-12-90ac3d577340>", line 3, in trainModel
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1783, in fit
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1377, in train_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1360, in step_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1349, in run_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1130, in train_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py", line 543, in minimize
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py", line 276, in compute_gradients
#
# OOM when allocating tensor with shape[128,128,19683,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/model/max_pooling1d/MaxPool/MaxPoolGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_13763]

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [800_1000] - 1-й из 17
# [800-1000]=> Paveletskaya_city: № 1 -> Длина записи: 117551; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 2 -> Длина записи: 650351; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 3 -> Длина записи: 104879; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 4 -> Длина записи: 5269871; Маркер выборки: 1; Число нарезок: 38
# [800-1000]=> Paveletskaya_city: № 5 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 6 -> Длина записи: 3154223; Маркер выборки: 1; Число нарезок: 22
# [800-1000]=> Paveletskaya_city: № 7 -> Длина записи: 56495; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 8 -> Длина записи: 3468719; Маркер выборки: 1; Число нарезок: 25
# [800-1000]=> Paveletskaya_city: № 9 -> Длина записи: 31727; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 10 -> Длина записи: 4040111; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 11 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 12 -> Длина записи: 805871; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 13 -> Длина записи: 84143; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 14 -> Длина записи: 1472879; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_city: № 15 -> Длина записи: 153263; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 16 -> Длина записи: 1114031; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 17 -> Длина записи: 112943; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 18 -> Длина записи: 2986607; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_city: № 19 -> Длина записи: 61679; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 20 -> Длина записи: 3433583; Маркер выборки: 1; Число нарезок: 24
# [800-1000]=> Paveletskaya_city: № 21 -> Длина записи: 82991; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 22 -> Длина записи: 1387631; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_city: № 23 -> Длина записи: 55919; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 24 -> Длина записи: 3091439; Маркер выборки: 1; Число нарезок: 22
# [800-1000]=> Paveletskaya_city: № 25 -> Длина записи: 50159; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 26 -> Длина записи: 2308655; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 27 -> Длина записи: 42671; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 28 -> Длина записи: 2250479; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 29 -> Длина записи: 182063; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 30 -> Длина записи: 4722095; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_city: № 31 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 32 -> Длина записи: 850223; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 33 -> Длина записи: 125039; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 34 -> Длина записи: 6639023; Маркер выборки: 1; Число нарезок: 48
# [800-1000]=> Paveletskaya_city: № 35 -> Длина записи: 62831; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 36 -> Длина записи: 798383; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 37 -> Длина записи: 13295; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 38 -> Длина записи: 1099631; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_city: № 39 -> Длина записи: 205679; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 40 -> Длина записи: 1529327; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 41 -> Длина записи: 62255; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 42 -> Длина записи: 1809263; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 43 -> Длина записи: 6383; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 44 -> Длина записи: 788591; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 45 -> Длина записи: 5231; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 46 -> Длина записи: 3790703; Маркер выборки: 1; Число нарезок: 27
# [800-1000]=> Paveletskaya_city: № 47 -> Длина записи: 78959; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 48 -> Длина записи: 2370863; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 49 -> Длина записи: 80111; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 50 -> Длина записи: 542063; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 51 -> Длина записи: 12143; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 52 -> Длина записи: 5273903; Маркер выборки: 1; Число нарезок: 38
# [800-1000]=> Paveletskaya_city: № 53 -> Длина записи: 90479; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 54 -> Длина записи: 2570159; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 55 -> Длина записи: 195887; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 56 -> Длина записи: 569711; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 57 -> Длина записи: 220655; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 58 -> Длина записи: 1060463; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_city: № 59 -> Длина записи: 128495; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 60 -> Длина записи: 448175; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 61 -> Длина записи: 30575; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 62 -> Длина записи: 633071; Маркер выборки: 1; Число нарезок: 4
# [800-1000]=> Paveletskaya_city: № 63 -> Длина записи: 207983; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 64 -> Длина записи: 4403567; Маркер выборки: 1; Число нарезок: 31
# [800-1000]=> Paveletskaya_city: № 65 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 66 -> Длина записи: 2494703; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 67 -> Длина записи: 131951; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 68 -> Длина записи: 2632367; Маркер выборки: 1; Число нарезок: 19
# [800-1000]=> Paveletskaya_city: № 69 -> Длина записи: 195311; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 70 -> Длина записи: 759791; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 71 -> Длина записи: 150383; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 72 -> Длина записи: 3639791; Маркер выборки: 1; Число нарезок: 26
# [800-1000]=> Paveletskaya_city: № 73 -> Длина записи: 104303; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 74 -> Длина записи: 2172719; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_city: № 75 -> Длина записи: 90479; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 76 -> Длина записи: 4725551; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_city: № 77 -> Длина записи: 175727; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 78 -> Длина записи: 4519919; Маркер выборки: 1; Число нарезок: 32
# [800-1000]=> Paveletskaya_city: № 79 -> Длина записи: 58223; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 80 -> Длина записи: 1736111; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 81 -> Длина записи: 87023; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 82 -> Длина записи: 1299503; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_city: № 83 -> Длина записи: 132527; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 84 -> Длина записи: 1627247; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 85 -> Длина записи: 20783; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 86 -> Длина записи: 464879; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 87 -> Длина записи: 38063; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 88 -> Длина записи: 2330543; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_city: № 89 -> Длина записи: 42095; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 90 -> Длина записи: 2930735; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_city: № 91 -> Длина записи: 69743; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 92 -> Длина записи: 1732655; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 93 -> Длина записи: 94511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 94 -> Длина записи: 2575343; Маркер выборки: 1; Число нарезок: 18
# [800-1000]=> Paveletskaya_city: № 95 -> Длина записи: 137135; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 96 -> Длина записи: 855983; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 97 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 98 -> Длина записи: 2412335; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 99 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 100 -> Длина записи: 722351; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_city: № 101 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 102 -> Длина записи: 2170991; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_city: № 103 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 104 -> Длина записи: 962543; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 105 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 106 -> Длина записи: 4049327; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 107 -> Длина записи: 68015; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 108 -> Длина записи: 271919; Маркер выборки: 1; Число нарезок: 1
# [800-1000]=> Paveletskaya_city: № 109 -> Длина записи: 84719; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 110 -> Длина записи: 1195823; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 111 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 112 -> Длина записи: 1614575; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 113 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 114 -> Длина записи: 2431343; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 115 -> Длина записи: 191855; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 116 -> Длина записи: 2836271; Маркер выборки: 1; Число нарезок: 20
# [800-1000]=> Paveletskaya_city: № 117 -> Длина записи: 208559; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 118 -> Длина записи: 2396783; Маркер выборки: 1; Число нарезок: 17
# [800-1000]=> Paveletskaya_city: № 119 -> Длина записи: 84719; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 120 -> Длина записи: 1105391; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 121 -> Длина записи: 52463; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 122 -> Длина записи: 1293743; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_city: № 123 -> Длина записи: 58223; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 124 -> Длина записи: 1828847; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 125 -> Длина записи: 220079; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 126 -> Длина записи: 895727; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 127 -> Длина записи: 34031; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 128 -> Длина записи: 873839; Маркер выборки: 1; Число нарезок: 6
# [800-1000]=> Paveletskaya_city: № 129 -> Длина записи: 77807; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 130 -> Длина записи: 4094831; Маркер выборки: 1; Число нарезок: 29
# [800-1000]=> Paveletskaya_city: № 131 -> Длина записи: 106607; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 132 -> Длина записи: 1845551; Маркер выборки: 1; Число нарезок: 13
# [800-1000]=> Paveletskaya_city: № 133 -> Длина записи: 22511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 134 -> Длина записи: 221231; Маркер выборки: 1; Число нарезок: 1
# [800-1000]=> Paveletskaya_city: № 135 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 136 -> Длина записи: 498863; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_city: № 137 -> Длина записи: 134831; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 138 -> Длина записи: 1217711; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 139 -> Длина записи: 153263; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 140 -> Длина записи: 1762031; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 141 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 142 -> Длина записи: 1656623; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_city: № 143 -> Длина записи: 23663; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 144 -> Длина записи: 1584047; Маркер выборки: 1; Число нарезок: 11
# [800-1000]=> Paveletskaya_city: № 145 -> Длина записи: 22511; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 146 -> Длина записи: 1184879; Маркер выборки: 1; Число нарезок: 8
# [800-1000]=> Paveletskaya_city: № 147 -> Длина записи: 191279; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 148 -> Длина записи: 4566575; Маркер выборки: 1; Число нарезок: 33
# [800-1000]=> Paveletskaya_city: № 149 -> Длина записи: 55343; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 150 -> Длина записи: 5811887; Маркер выборки: 1; Число нарезок: 42
# [800-1000]=> Paveletskaya_turbo: № 151 -> Длина записи: 184367; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 152 -> Длина записи: 1018991; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 153 -> Длина записи: 169391; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 154 -> Длина записи: 812783; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 155 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 156 -> Длина записи: 2313263; Маркер выборки: 1; Число нарезок: 16
# [800-1000]=> Paveletskaya_turbo: № 157 -> Длина записи: 195887; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 158 -> Длина записи: 748271; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 159 -> Длина записи: 38063; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 160 -> Длина записи: 4737647; Маркер выборки: 1; Число нарезок: 34
# [800-1000]=> Paveletskaya_turbo: № 161 -> Длина записи: 220079; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 162 -> Длина записи: 1448111; Маркер выборки: 1; Число нарезок: 10
# [800-1000]=> Paveletskaya_turbo: № 163 -> Длина записи: 4655; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 164 -> Длина записи: 979823; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 165 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 166 -> Длина записи: 1063343; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 167 -> Длина записи: 160175; Маркер выборки: 0; Число нарезок: 1
# [800-1000]=> Headliner: № 168 -> Длина записи: 1707311; Маркер выборки: 1; Число нарезок: 12
# [800-1000]=> Paveletskaya_turbo: № 169 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 170 -> Длина записи: 1072559; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 171 -> Длина записи: 3422639; Маркер выборки: 0; Число нарезок: 24
# [800-1000]=> Headliner: № 172 -> Длина записи: 1040879; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 173 -> Длина записи: 1023023; Маркер выборки: 0; Число нарезок: 7
# [800-1000]=> Headliner: № 174 -> Длина записи: 2104751; Маркер выборки: 1; Число нарезок: 15
# [800-1000]=> Paveletskaya_turbo: № 175 -> Длина записи: 639983; Маркер выборки: 0; Число нарезок: 4
# [800-1000]=> Headliner: № 176 -> Длина записи: 1045487; Маркер выборки: 1; Число нарезок: 7
# [800-1000]=> Paveletskaya_turbo: № 177 -> Длина записи: 293231; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 178 -> Длина записи: 5943791; Маркер выборки: 1; Число нарезок: 43
# [800-1000]=> Paveletskaya_turbo: № 179 -> Длина записи: 1836335; Маркер выборки: 0; Число нарезок: 13
# [800-1000]=> Headliner: № 180 -> Длина записи: 11733743; Маркер выборки: 1; Число нарезок: 85
# [800-1000]=> Paveletskaya_turbo: № 181 -> Длина записи: 33455; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 182 -> Длина записи: 3901295; Маркер выборки: 1; Число нарезок: 28
# [800-1000]=> Paveletskaya_turbo: № 183 -> Длина записи: 20248751; Маркер выборки: 0; Число нарезок: 146
# [800-1000]=> Headliner: № 184 -> Длина записи: 747119; Маркер выборки: 1; Число нарезок: 5
# [800-1000]=> Paveletskaya_turbo: № 185 -> Длина записи: 380783; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 186 -> Длина записи: 2877743; Маркер выборки: 1; Число нарезок: 20
# [800-1000]=> Paveletskaya_turbo: № 187 -> Длина записи: 134255; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 188 -> Длина записи: 1335215; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_turbo: № 189 -> Длина записи: 327215; Маркер выборки: 0; Число нарезок: 2
# [800-1000]=> Headliner: № 190 -> Длина записи: 3238319; Маркер выборки: 1; Число нарезок: 23
# [800-1000]=> Paveletskaya_turbo: № 191 -> Длина записи: 63407; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 192 -> Длина записи: 550127; Маркер выборки: 1; Число нарезок: 3
# [800-1000]=> Paveletskaya_turbo: № 193 -> Длина записи: 106607; Маркер выборки: 0; Число нарезок: 0
# [800-1000]=> Headliner: № 194 -> Длина записи: 1268975; Маркер выборки: 1; Число нарезок: 9
# [800-1000]=> Paveletskaya_turbo: № 195 -> Длина записи: 1138223; Маркер выборки: 0; Число нарезок: 8
# [800-1000]=> Headliner: № 196 -> Длина записи: 2974511; Маркер выборки: 1; Число нарезок: 21
# [800-1000]=> Paveletskaya_turbo: № 197 -> Длина записи: 4721519; Маркер выборки: 0; Число нарезок: 34
# [800-1000]=> Headliner: № 198 -> Длина записи: 3975023; Маркер выборки: 1; Число нарезок: 28
# [800-1000]=> Paveletskaya_turbo: № 199 -> Длина записи: 1726319; Маркер выборки: 0; Число нарезок: 12
# [800-1000]=> Headliner: № 200 -> Длина записи: 1672751; Маркер выборки: 1; Число нарезок: 12
#
# XTrain1.shape:  (3373, 137781, 1)
# YTrain1.shape:  (3373, 2)
# XTrain1V.shape:  (341, 137781, 1)
# YTrain1V.shape:  (341, 2)
# Обучающая выборка X_Train1 - Целевых: 2880; Нецелевых: 493
# Валидационная выборка X_Train1V - Целевых: 291; Нецелевых: 50
# Epoch 1/20
# 27/27 [==============================] - 59s 1s/step - loss: 0.4551 - accuracy: 0.8669 - val_loss: 1.1028 - val_accuracy: 0.6804
# Epoch 2/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.2275 - accuracy: 0.9028 - val_loss: 0.5618 - val_accuracy: 0.9208
# Epoch 3/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.1655 - accuracy: 0.9357 - val_loss: 0.2285 - val_accuracy: 0.9326
# Epoch 4/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.1528 - accuracy: 0.9413 - val_loss: 0.1737 - val_accuracy: 0.9531
# Epoch 5/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0979 - accuracy: 0.9665 - val_loss: 0.3332 - val_accuracy: 0.9150
# Epoch 6/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.1048 - accuracy: 0.9665 - val_loss: 0.4083 - val_accuracy: 0.8651
# Epoch 7/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0881 - accuracy: 0.9730 - val_loss: 0.6161 - val_accuracy: 0.8622
# Epoch 8/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.0886 - accuracy: 0.9683 - val_loss: 1.0786 - val_accuracy: 0.8827
# Epoch 9/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0712 - accuracy: 0.9778 - val_loss: 0.9530 - val_accuracy: 0.9091
# Epoch 10/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0508 - accuracy: 0.9801 - val_loss: 2.9055 - val_accuracy: 0.8534
# Epoch 11/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0424 - accuracy: 0.9890 - val_loss: 0.0331 - val_accuracy: 0.9824
# Epoch 12/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0270 - accuracy: 0.9929 - val_loss: 1.8018 - val_accuracy: 0.8915
# Epoch 13/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 10.3700 - val_accuracy: 0.8534
# Epoch 14/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.0376 - accuracy: 0.9908 - val_loss: 4.5551 - val_accuracy: 0.8446
# Epoch 15/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.2365 - val_accuracy: 0.9531
# Epoch 16/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0759 - accuracy: 0.9733 - val_loss: 0.2291 - val_accuracy: 0.9648
# Epoch 17/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0342 - accuracy: 0.9890 - val_loss: 2.3384 - val_accuracy: 0.9091
# Epoch 18/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.4184 - val_accuracy: 0.9179
# Epoch 19/20
# 27/27 [==============================] - 30s 1s/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 2.1769 - val_accuracy: 0.8622
# Epoch 20/20
# 27/27 [==============================] - 29s 1s/step - loss: 0.0334 - accuracy: 0.9923 - val_loss: 25.6658 - val_accuracy: 0.8387
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [800_1000] - 1-й из 17
#
# Запущен блок [1000_1200] - 2-й из 17
# [1000-1200]=> Paveletskaya_turbo: № 201 -> Длина записи: 3661103; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 202 -> Длина записи: 3242927; Маркер выборки: 1; Число нарезок: 23
# [1000-1200]=> Paveletskaya_turbo: № 203 -> Длина записи: 61103; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 204 -> Длина записи: 2897903; Маркер выборки: 1; Число нарезок: 21
# [1000-1200]=> Paveletskaya_turbo: № 205 -> Длина записи: 72623; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 206 -> Длина записи: 1195823; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 207 -> Длина записи: 1287407; Маркер выборки: 0; Число нарезок: 9
# [1000-1200]=> Headliner: № 208 -> Длина записи: 3456623; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 209 -> Длина записи: 1082351; Маркер выборки: 0; Число нарезок: 7
# [1000-1200]=> Headliner: № 210 -> Длина записи: 1592111; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 211 -> Длина записи: 1224623; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 212 -> Длина записи: 6040559; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 213 -> Длина записи: 1204463; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 214 -> Длина записи: 1577135; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 215 -> Длина записи: 141743; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 216 -> Длина записи: 11412335; Маркер выборки: 1; Число нарезок: 82
# [1000-1200]=> Paveletskaya_turbo: № 217 -> Длина записи: 262703; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 218 -> Длина записи: 2302895; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 219 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 220 -> Длина записи: 2165231; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 221 -> Длина записи: 2358767; Маркер выборки: 0; Число нарезок: 17
# [1000-1200]=> Headliner: № 222 -> Длина записи: 1878383; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 223 -> Длина записи: 7216751; Маркер выборки: 0; Число нарезок: 52
# [1000-1200]=> Headliner: № 224 -> Длина записи: 6164399; Маркер выборки: 1; Число нарезок: 44
# [1000-1200]=> Paveletskaya_turbo: № 225 -> Длина записи: 69743; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 226 -> Длина записи: 5956463; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 227 -> Длина записи: 2867951; Маркер выборки: 0; Число нарезок: 20
# [1000-1200]=> Headliner: № 228 -> Длина записи: 967151; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 229 -> Длина записи: 57071; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 230 -> Длина записи: 1878959; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 231 -> Длина записи: 243695; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 232 -> Длина записи: 1550063; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 233 -> Длина записи: 427439; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 234 -> Длина записи: 2521199; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 235 -> Длина записи: 2006831; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 236 -> Длина записи: 2528111; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 237 -> Длина записи: 4266479; Маркер выборки: 0; Число нарезок: 30
# [1000-1200]=> Headliner: № 238 -> Длина записи: 5557871; Маркер выборки: 1; Число нарезок: 40
# [1000-1200]=> Paveletskaya_turbo: № 239 -> Длина записи: 138287; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 240 -> Длина записи: 1010351; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 241 -> Длина записи: 361199; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 242 -> Длина записи: 5136239; Маркер выборки: 1; Число нарезок: 37
# [1000-1200]=> Paveletskaya_turbo: № 243 -> Длина записи: 569135; Маркер выборки: 0; Число нарезок: 4
# [1000-1200]=> Headliner: № 244 -> Длина записи: 922223; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 245 -> Длина записи: 211439; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 246 -> Длина записи: 1868591; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 247 -> Длина записи: 978671; Маркер выборки: 0; Число нарезок: 7
# [1000-1200]=> Headliner: № 248 -> Длина записи: 1513199; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 249 -> Длина записи: 46703; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 250 -> Длина записи: 846191; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 251 -> Длина записи: 218351; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 252 -> Длина записи: 869807; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 253 -> Длина записи: 6367151; Маркер выборки: 0; Число нарезок: 46
# [1000-1200]=> Headliner: № 254 -> Длина записи: 5050991; Маркер выборки: 1; Число нарезок: 36
# [1000-1200]=> Paveletskaya_turbo: № 255 -> Длина записи: 4685807; Маркер выборки: 0; Число нарезок: 34
# [1000-1200]=> Headliner: № 256 -> Длина записи: 754031; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 257 -> Длина записи: 3199151; Маркер выборки: 0; Число нарезок: 23
# [1000-1200]=> Headliner: № 258 -> Длина записи: 544367; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 259 -> Длина записи: 3101231; Маркер выборки: 0; Число нарезок: 22
# [1000-1200]=> Headliner: № 260 -> Длина записи: 697583; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 261 -> Длина записи: 5698415; Маркер выборки: 0; Число нарезок: 41
# [1000-1200]=> Headliner: № 262 -> Длина записи: 1441199; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 263 -> Длина записи: 893423; Маркер выборки: 0; Число нарезок: 6
# [1000-1200]=> Headliner: № 264 -> Длина записи: 2709551; Маркер выборки: 1; Число нарезок: 19
# [1000-1200]=> Paveletskaya_turbo: № 265 -> Длина записи: 117551; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 266 -> Длина записи: 2158319; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 267 -> Длина записи: 5290607; Маркер выборки: 0; Число нарезок: 38
# [1000-1200]=> Headliner: № 268 -> Длина записи: 2008559; Маркер выборки: 1; Число нарезок: 14
# [1000-1200]=> Paveletskaya_turbo: № 269 -> Длина записи: 177455; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 270 -> Длина записи: 1027055; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 271 -> Длина записи: 5114351; Маркер выборки: 0; Число нарезок: 37
# [1000-1200]=> Headliner: № 272 -> Длина записи: 2821871; Маркер выборки: 1; Число нарезок: 20
# [1000-1200]=> Paveletskaya_turbo: № 273 -> Длина записи: 388271; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 274 -> Длина записи: 796655; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 275 -> Длина записи: 4881647; Маркер выборки: 0; Число нарезок: 35
# [1000-1200]=> Headliner: № 276 -> Длина записи: 11272943; Маркер выборки: 1; Число нарезок: 81
# [1000-1200]=> Paveletskaya_turbo: № 277 -> Длина записи: 1581743; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 278 -> Длина записи: 467183; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 279 -> Длина записи: 1759727; Маркер выборки: 0; Число нарезок: 12
# [1000-1200]=> Headliner: № 280 -> Длина записи: 2068463; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 281 -> Длина записи: 3666287; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 282 -> Длина записи: 1608239; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 283 -> Длина записи: 1539695; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 284 -> Длина записи: 3450287; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 285 -> Длина записи: 10991; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 286 -> Длина записи: 676847; Маркер выборки: 1; Число нарезок: 4
# [1000-1200]=> Paveletskaya_turbo: № 287 -> Длина записи: 65135; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 288 -> Длина записи: 403823; Маркер выборки: 1; Число нарезок: 2
# [1000-1200]=> Paveletskaya_turbo: № 289 -> Длина записи: 3981935; Маркер выборки: 0; Число нарезок: 28
# [1000-1200]=> Headliner: № 290 -> Длина записи: 3709487; Маркер выборки: 1; Число нарезок: 26
# [1000-1200]=> Paveletskaya_turbo: № 291 -> Длина записи: 127919; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 292 -> Длина записи: 1166447; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 293 -> Длина записи: 25391; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 294 -> Длина записи: 1176815; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 295 -> Длина записи: 89903; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 296 -> Длина записи: 1329455; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 297 -> Длина записи: 37487; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 298 -> Длина записи: 1358831; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 299 -> Длина записи: 168239; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 300 -> Длина записи: 1145135; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 301 -> Длина записи: 4254383; Маркер выборки: 0; Число нарезок: 30
# [1000-1200]=> Headliner: № 302 -> Длина записи: 2830511; Маркер выборки: 1; Число нарезок: 20
# [1000-1200]=> Paveletskaya_turbo: № 303 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 304 -> Длина записи: 6018095; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 305 -> Длина записи: 5497967; Маркер выборки: 0; Число нарезок: 39
# [1000-1200]=> Headliner: № 306 -> Длина записи: 1377839; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 307 -> Длина записи: 71471; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 308 -> Длина записи: 688943; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 309 -> Длина записи: 376175; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 310 -> Длина записи: 1642223; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 311 -> Длина записи: 382511; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 312 -> Длина записи: 2203247; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 313 -> Длина записи: 48431; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 314 -> Длина записи: 1289711; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 315 -> Длина записи: 2675567; Маркер выборки: 0; Число нарезок: 19
# [1000-1200]=> Headliner: № 316 -> Длина записи: 532847; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 317 -> Длина записи: 2569007; Маркер выборки: 0; Число нарезок: 18
# [1000-1200]=> Headliner: № 318 -> Длина записи: 1464239; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 319 -> Длина записи: 2196911; Маркер выборки: 0; Число нарезок: 15
# [1000-1200]=> Headliner: № 320 -> Длина записи: 1702127; Маркер выборки: 1; Число нарезок: 12
# [1000-1200]=> Paveletskaya_turbo: № 321 -> Длина записи: 1168751; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 322 -> Длина записи: 904367; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 323 -> Длина записи: 5574575; Маркер выборки: 0; Число нарезок: 40
# [1000-1200]=> Headliner: № 324 -> Длина записи: 654959; Маркер выборки: 1; Число нарезок: 4
# [1000-1200]=> Paveletskaya_turbo: № 325 -> Длина записи: 1231535; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 326 -> Длина записи: 1017263; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 327 -> Длина записи: 442415; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 328 -> Длина записи: 449903; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 329 -> Длина записи: 3801071; Маркер выборки: 0; Число нарезок: 27
# [1000-1200]=> Headliner: № 330 -> Длина записи: 1604783; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 331 -> Длина записи: 3616175; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 332 -> Длина записи: 975215; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 333 -> Длина записи: 1761455; Маркер выборки: 0; Число нарезок: 12
# [1000-1200]=> Headliner: № 334 -> Длина записи: 2671535; Маркер выборки: 1; Число нарезок: 19
# [1000-1200]=> Paveletskaya_turbo: № 335 -> Длина записи: 339887; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 336 -> Длина записи: 1101935; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 337 -> Длина записи: 4442159; Маркер выборки: 0; Число нарезок: 32
# [1000-1200]=> Headliner: № 338 -> Длина записи: 2218223; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 339 -> Длина записи: 150383; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 340 -> Длина записи: 874415; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 341 -> Длина записи: 8177519; Маркер выборки: 0; Число нарезок: 59
# [1000-1200]=> Headliner: № 342 -> Длина записи: 5167343; Маркер выборки: 1; Число нарезок: 37
# [1000-1200]=> Paveletskaya_turbo: № 343 -> Длина записи: 61679; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 344 -> Длина записи: 1312751; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 345 -> Длина записи: 87599; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 346 -> Длина записи: 2169263; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 347 -> Длина записи: 118127; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 348 -> Длина записи: 2428463; Маркер выборки: 1; Число нарезок: 17
# [1000-1200]=> Paveletskaya_turbo: № 349 -> Длина записи: 2968751; Маркер выборки: 0; Число нарезок: 21
# [1000-1200]=> Headliner: № 350 -> Длина записи: 2597807; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 351 -> Длина записи: 1898543; Маркер выборки: 0; Число нарезок: 13
# [1000-1200]=> Headliner: № 352 -> Длина записи: 865199; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 353 -> Длина записи: 24815; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 354 -> Длина записи: 1844399; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 355 -> Длина записи: 8111; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 356 -> Длина записи: 948719; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 357 -> Длина записи: 258671; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 358 -> Длина записи: 707375; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 359 -> Длина записи: 6664943; Маркер выборки: 0; Число нарезок: 48
# [1000-1200]=> Headliner: № 360 -> Длина записи: 2191727; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 361 -> Длина записи: 369839; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 362 -> Длина записи: 6013487; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 363 -> Длина записи: 447023; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 364 -> Длина записи: 2227439; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 365 -> Длина записи: 160751; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 366 -> Длина записи: 3353519; Маркер выборки: 1; Число нарезок: 24
# [1000-1200]=> Paveletskaya_turbo: № 367 -> Длина записи: 110063; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 368 -> Длина записи: 3526895; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 369 -> Длина записи: 1578287; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 370 -> Длина записи: 3817199; Маркер выборки: 1; Число нарезок: 27
# [1000-1200]=> Paveletskaya_turbo: № 371 -> Длина записи: 4599983; Маркер выборки: 0; Число нарезок: 33
# [1000-1200]=> Headliner: № 372 -> Длина записи: 866351; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 373 -> Длина записи: 3557999; Маркер выборки: 0; Число нарезок: 25
# [1000-1200]=> Headliner: № 374 -> Длина записи: 1767215; Маркер выборки: 1; Число нарезок: 12
# [1000-1200]=> Paveletskaya_turbo: № 375 -> Длина записи: 193583; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 376 -> Длина записи: 1335215; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 377 -> Длина записи: 1794287; Маркер выборки: 0; Число нарезок: 13
# [1000-1200]=> Headliner: № 378 -> Длина записи: 2142191; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 379 -> Длина записи: 447599; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 380 -> Длина записи: 963695; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 381 -> Длина записи: 41519; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 382 -> Длина записи: 2246447; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 383 -> Длина записи: 143471; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 384 -> Длина записи: 959087; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 385 -> Длина записи: 2187119; Маркер выборки: 0; Число нарезок: 15
# [1000-1200]=> Headliner: № 386 -> Длина записи: 2505071; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 387 -> Длина записи: 621551; Маркер выборки: 0; Число нарезок: 4
# [1000-1200]=> Headliner: № 388 -> Длина записи: 699311; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 389 -> Длина записи: 4580399; Маркер выборки: 0; Число нарезок: 33
# [1000-1200]=> Headliner: № 390 -> Длина записи: 2256239; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 391 -> Длина записи: 1970543; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 392 -> Длина записи: 2311535; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 393 -> Длина записи: 868079; Маркер выборки: 0; Число нарезок: 6
# [1000-1200]=> Headliner: № 394 -> Длина записи: 2196911; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 395 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 396 -> Длина записи: 216047; Маркер выборки: 1; Число нарезок: 1
# [1000-1200]=> Paveletskaya_turbo: № 397 -> Длина записи: 2051759; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 398 -> Длина записи: 2267759; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 399 -> Длина записи: 2297711; Маркер выборки: 0; Число нарезок: 16
# [1000-1200]=> Headliner: № 400 -> Длина записи: 2729711; Маркер выборки: 1; Число нарезок: 19

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [1000_1200] - 1-й из 16
# [1000-1200]=> Paveletskaya_turbo: № 1 -> Длина записи: 3661103; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 2 -> Длина записи: 3242927; Маркер выборки: 1; Число нарезок: 23
# [1000-1200]=> Paveletskaya_turbo: № 3 -> Длина записи: 61103; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 4 -> Длина записи: 2897903; Маркер выборки: 1; Число нарезок: 21
# [1000-1200]=> Paveletskaya_turbo: № 5 -> Длина записи: 72623; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 6 -> Длина записи: 1195823; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 7 -> Длина записи: 1287407; Маркер выборки: 0; Число нарезок: 9
# [1000-1200]=> Headliner: № 8 -> Длина записи: 3456623; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 9 -> Длина записи: 1082351; Маркер выборки: 0; Число нарезок: 7
# [1000-1200]=> Headliner: № 10 -> Длина записи: 1592111; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 11 -> Длина записи: 1224623; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 12 -> Длина записи: 6040559; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 13 -> Длина записи: 1204463; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 14 -> Длина записи: 1577135; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 15 -> Длина записи: 141743; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 16 -> Длина записи: 11412335; Маркер выборки: 1; Число нарезок: 82
# [1000-1200]=> Paveletskaya_turbo: № 17 -> Длина записи: 262703; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 18 -> Длина записи: 2302895; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 19 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 20 -> Длина записи: 2165231; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 21 -> Длина записи: 2358767; Маркер выборки: 0; Число нарезок: 17
# [1000-1200]=> Headliner: № 22 -> Длина записи: 1878383; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 23 -> Длина записи: 7216751; Маркер выборки: 0; Число нарезок: 52
# [1000-1200]=> Headliner: № 24 -> Длина записи: 6164399; Маркер выборки: 1; Число нарезок: 44
# [1000-1200]=> Paveletskaya_turbo: № 25 -> Длина записи: 69743; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 26 -> Длина записи: 5956463; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 27 -> Длина записи: 2867951; Маркер выборки: 0; Число нарезок: 20
# [1000-1200]=> Headliner: № 28 -> Длина записи: 967151; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 29 -> Длина записи: 57071; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 30 -> Длина записи: 1878959; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 31 -> Длина записи: 243695; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 32 -> Длина записи: 1550063; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 33 -> Длина записи: 427439; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 34 -> Длина записи: 2521199; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 35 -> Длина записи: 2006831; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 36 -> Длина записи: 2528111; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 37 -> Длина записи: 4266479; Маркер выборки: 0; Число нарезок: 30
# [1000-1200]=> Headliner: № 38 -> Длина записи: 5557871; Маркер выборки: 1; Число нарезок: 40
# [1000-1200]=> Paveletskaya_turbo: № 39 -> Длина записи: 138287; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 40 -> Длина записи: 1010351; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 41 -> Длина записи: 361199; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 42 -> Длина записи: 5136239; Маркер выборки: 1; Число нарезок: 37
# [1000-1200]=> Paveletskaya_turbo: № 43 -> Длина записи: 569135; Маркер выборки: 0; Число нарезок: 4
# [1000-1200]=> Headliner: № 44 -> Длина записи: 922223; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 45 -> Длина записи: 211439; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 46 -> Длина записи: 1868591; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 47 -> Длина записи: 978671; Маркер выборки: 0; Число нарезок: 7
# [1000-1200]=> Headliner: № 48 -> Длина записи: 1513199; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 49 -> Длина записи: 46703; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 50 -> Длина записи: 846191; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 51 -> Длина записи: 218351; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 52 -> Длина записи: 869807; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 53 -> Длина записи: 6367151; Маркер выборки: 0; Число нарезок: 46
# [1000-1200]=> Headliner: № 54 -> Длина записи: 5050991; Маркер выборки: 1; Число нарезок: 36
# [1000-1200]=> Paveletskaya_turbo: № 55 -> Длина записи: 4685807; Маркер выборки: 0; Число нарезок: 34
# [1000-1200]=> Headliner: № 56 -> Длина записи: 754031; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 57 -> Длина записи: 3199151; Маркер выборки: 0; Число нарезок: 23
# [1000-1200]=> Headliner: № 58 -> Длина записи: 544367; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 59 -> Длина записи: 3101231; Маркер выборки: 0; Число нарезок: 22
# [1000-1200]=> Headliner: № 60 -> Длина записи: 697583; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 61 -> Длина записи: 5698415; Маркер выборки: 0; Число нарезок: 41
# [1000-1200]=> Headliner: № 62 -> Длина записи: 1441199; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 63 -> Длина записи: 893423; Маркер выборки: 0; Число нарезок: 6
# [1000-1200]=> Headliner: № 64 -> Длина записи: 2709551; Маркер выборки: 1; Число нарезок: 19
# [1000-1200]=> Paveletskaya_turbo: № 65 -> Длина записи: 117551; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 66 -> Длина записи: 2158319; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 67 -> Длина записи: 5290607; Маркер выборки: 0; Число нарезок: 38
# [1000-1200]=> Headliner: № 68 -> Длина записи: 2008559; Маркер выборки: 1; Число нарезок: 14
# [1000-1200]=> Paveletskaya_turbo: № 69 -> Длина записи: 177455; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 70 -> Длина записи: 1027055; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 71 -> Длина записи: 5114351; Маркер выборки: 0; Число нарезок: 37
# [1000-1200]=> Headliner: № 72 -> Длина записи: 2821871; Маркер выборки: 1; Число нарезок: 20
# [1000-1200]=> Paveletskaya_turbo: № 73 -> Длина записи: 388271; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 74 -> Длина записи: 796655; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 75 -> Длина записи: 4881647; Маркер выборки: 0; Число нарезок: 35
# [1000-1200]=> Headliner: № 76 -> Длина записи: 11272943; Маркер выборки: 1; Число нарезок: 81
# [1000-1200]=> Paveletskaya_turbo: № 77 -> Длина записи: 1581743; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 78 -> Длина записи: 467183; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 79 -> Длина записи: 1759727; Маркер выборки: 0; Число нарезок: 12
# [1000-1200]=> Headliner: № 80 -> Длина записи: 2068463; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 81 -> Длина записи: 3666287; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 82 -> Длина записи: 1608239; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 83 -> Длина записи: 1539695; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 84 -> Длина записи: 3450287; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 85 -> Длина записи: 10991; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 86 -> Длина записи: 676847; Маркер выборки: 1; Число нарезок: 4
# [1000-1200]=> Paveletskaya_turbo: № 87 -> Длина записи: 65135; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 88 -> Длина записи: 403823; Маркер выборки: 1; Число нарезок: 2
# [1000-1200]=> Paveletskaya_turbo: № 89 -> Длина записи: 3981935; Маркер выборки: 0; Число нарезок: 28
# [1000-1200]=> Headliner: № 90 -> Длина записи: 3709487; Маркер выборки: 1; Число нарезок: 26
# [1000-1200]=> Paveletskaya_turbo: № 91 -> Длина записи: 127919; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 92 -> Длина записи: 1166447; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 93 -> Длина записи: 25391; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 94 -> Длина записи: 1176815; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 95 -> Длина записи: 89903; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 96 -> Длина записи: 1329455; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 97 -> Длина записи: 37487; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 98 -> Длина записи: 1358831; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 99 -> Длина записи: 168239; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 100 -> Длина записи: 1145135; Маркер выборки: 1; Число нарезок: 8
# [1000-1200]=> Paveletskaya_turbo: № 101 -> Длина записи: 4254383; Маркер выборки: 0; Число нарезок: 30
# [1000-1200]=> Headliner: № 102 -> Длина записи: 2830511; Маркер выборки: 1; Число нарезок: 20
# [1000-1200]=> Paveletskaya_turbo: № 103 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 104 -> Длина записи: 6018095; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 105 -> Длина записи: 5497967; Маркер выборки: 0; Число нарезок: 39
# [1000-1200]=> Headliner: № 106 -> Длина записи: 1377839; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 107 -> Длина записи: 71471; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 108 -> Длина записи: 688943; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 109 -> Длина записи: 376175; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 110 -> Длина записи: 1642223; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 111 -> Длина записи: 382511; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 112 -> Длина записи: 2203247; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 113 -> Длина записи: 48431; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 114 -> Длина записи: 1289711; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 115 -> Длина записи: 2675567; Маркер выборки: 0; Число нарезок: 19
# [1000-1200]=> Headliner: № 116 -> Длина записи: 532847; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 117 -> Длина записи: 2569007; Маркер выборки: 0; Число нарезок: 18
# [1000-1200]=> Headliner: № 118 -> Длина записи: 1464239; Маркер выборки: 1; Число нарезок: 10
# [1000-1200]=> Paveletskaya_turbo: № 119 -> Длина записи: 2196911; Маркер выборки: 0; Число нарезок: 15
# [1000-1200]=> Headliner: № 120 -> Длина записи: 1702127; Маркер выборки: 1; Число нарезок: 12
# [1000-1200]=> Paveletskaya_turbo: № 121 -> Длина записи: 1168751; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 122 -> Длина записи: 904367; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 123 -> Длина записи: 5574575; Маркер выборки: 0; Число нарезок: 40
# [1000-1200]=> Headliner: № 124 -> Длина записи: 654959; Маркер выборки: 1; Число нарезок: 4
# [1000-1200]=> Paveletskaya_turbo: № 125 -> Длина записи: 1231535; Маркер выборки: 0; Число нарезок: 8
# [1000-1200]=> Headliner: № 126 -> Длина записи: 1017263; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 127 -> Длина записи: 442415; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 128 -> Длина записи: 449903; Маркер выборки: 1; Число нарезок: 3
# [1000-1200]=> Paveletskaya_turbo: № 129 -> Длина записи: 3801071; Маркер выборки: 0; Число нарезок: 27
# [1000-1200]=> Headliner: № 130 -> Длина записи: 1604783; Маркер выборки: 1; Число нарезок: 11
# [1000-1200]=> Paveletskaya_turbo: № 131 -> Длина записи: 3616175; Маркер выборки: 0; Число нарезок: 26
# [1000-1200]=> Headliner: № 132 -> Длина записи: 975215; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 133 -> Длина записи: 1761455; Маркер выборки: 0; Число нарезок: 12
# [1000-1200]=> Headliner: № 134 -> Длина записи: 2671535; Маркер выборки: 1; Число нарезок: 19
# [1000-1200]=> Paveletskaya_turbo: № 135 -> Длина записи: 339887; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 136 -> Длина записи: 1101935; Маркер выборки: 1; Число нарезок: 7
# [1000-1200]=> Paveletskaya_turbo: № 137 -> Длина записи: 4442159; Маркер выборки: 0; Число нарезок: 32
# [1000-1200]=> Headliner: № 138 -> Длина записи: 2218223; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 139 -> Длина записи: 150383; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 140 -> Длина записи: 874415; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 141 -> Длина записи: 8177519; Маркер выборки: 0; Число нарезок: 59
# [1000-1200]=> Headliner: № 142 -> Длина записи: 5167343; Маркер выборки: 1; Число нарезок: 37
# [1000-1200]=> Paveletskaya_turbo: № 143 -> Длина записи: 61679; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 144 -> Длина записи: 1312751; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 145 -> Длина записи: 87599; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 146 -> Длина записи: 2169263; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 147 -> Длина записи: 118127; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 148 -> Длина записи: 2428463; Маркер выборки: 1; Число нарезок: 17
# [1000-1200]=> Paveletskaya_turbo: № 149 -> Длина записи: 2968751; Маркер выборки: 0; Число нарезок: 21
# [1000-1200]=> Headliner: № 150 -> Длина записи: 2597807; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 151 -> Длина записи: 1898543; Маркер выборки: 0; Число нарезок: 13
# [1000-1200]=> Headliner: № 152 -> Длина записи: 865199; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 153 -> Длина записи: 24815; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 154 -> Длина записи: 1844399; Маркер выборки: 1; Число нарезок: 13
# [1000-1200]=> Paveletskaya_turbo: № 155 -> Длина записи: 8111; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 156 -> Длина записи: 948719; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 157 -> Длина записи: 258671; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 158 -> Длина записи: 707375; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 159 -> Длина записи: 6664943; Маркер выборки: 0; Число нарезок: 48
# [1000-1200]=> Headliner: № 160 -> Длина записи: 2191727; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 161 -> Длина записи: 369839; Маркер выборки: 0; Число нарезок: 2
# [1000-1200]=> Headliner: № 162 -> Длина записи: 6013487; Маркер выборки: 1; Число нарезок: 43
# [1000-1200]=> Paveletskaya_turbo: № 163 -> Длина записи: 447023; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 164 -> Длина записи: 2227439; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 165 -> Длина записи: 160751; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 166 -> Длина записи: 3353519; Маркер выборки: 1; Число нарезок: 24
# [1000-1200]=> Paveletskaya_turbo: № 167 -> Длина записи: 110063; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 168 -> Длина записи: 3526895; Маркер выборки: 1; Число нарезок: 25
# [1000-1200]=> Paveletskaya_turbo: № 169 -> Длина записи: 1578287; Маркер выборки: 0; Число нарезок: 11
# [1000-1200]=> Headliner: № 170 -> Длина записи: 3817199; Маркер выборки: 1; Число нарезок: 27
# [1000-1200]=> Paveletskaya_turbo: № 171 -> Длина записи: 4599983; Маркер выборки: 0; Число нарезок: 33
# [1000-1200]=> Headliner: № 172 -> Длина записи: 866351; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 173 -> Длина записи: 3557999; Маркер выборки: 0; Число нарезок: 25
# [1000-1200]=> Headliner: № 174 -> Длина записи: 1767215; Маркер выборки: 1; Число нарезок: 12
# [1000-1200]=> Paveletskaya_turbo: № 175 -> Длина записи: 193583; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 176 -> Длина записи: 1335215; Маркер выборки: 1; Число нарезок: 9
# [1000-1200]=> Paveletskaya_turbo: № 177 -> Длина записи: 1794287; Маркер выборки: 0; Число нарезок: 13
# [1000-1200]=> Headliner: № 178 -> Длина записи: 2142191; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 179 -> Длина записи: 447599; Маркер выборки: 0; Число нарезок: 3
# [1000-1200]=> Headliner: № 180 -> Длина записи: 963695; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 181 -> Длина записи: 41519; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 182 -> Длина записи: 2246447; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 183 -> Длина записи: 143471; Маркер выборки: 0; Число нарезок: 1
# [1000-1200]=> Headliner: № 184 -> Длина записи: 959087; Маркер выборки: 1; Число нарезок: 6
# [1000-1200]=> Paveletskaya_turbo: № 185 -> Длина записи: 2187119; Маркер выборки: 0; Число нарезок: 15
# [1000-1200]=> Headliner: № 186 -> Длина записи: 2505071; Маркер выборки: 1; Число нарезок: 18
# [1000-1200]=> Paveletskaya_turbo: № 187 -> Длина записи: 621551; Маркер выборки: 0; Число нарезок: 4
# [1000-1200]=> Headliner: № 188 -> Длина записи: 699311; Маркер выборки: 1; Число нарезок: 5
# [1000-1200]=> Paveletskaya_turbo: № 189 -> Длина записи: 4580399; Маркер выборки: 0; Число нарезок: 33
# [1000-1200]=> Headliner: № 190 -> Длина записи: 2256239; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 191 -> Длина записи: 1970543; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 192 -> Длина записи: 2311535; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 193 -> Длина записи: 868079; Маркер выборки: 0; Число нарезок: 6
# [1000-1200]=> Headliner: № 194 -> Длина записи: 2196911; Маркер выборки: 1; Число нарезок: 15
# [1000-1200]=> Paveletskaya_turbo: № 195 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1000-1200]=> Headliner: № 196 -> Длина записи: 216047; Маркер выборки: 1; Число нарезок: 1
# [1000-1200]=> Paveletskaya_turbo: № 197 -> Длина записи: 2051759; Маркер выборки: 0; Число нарезок: 14
# [1000-1200]=> Headliner: № 198 -> Длина записи: 2267759; Маркер выборки: 1; Число нарезок: 16
# [1000-1200]=> Paveletskaya_turbo: № 199 -> Длина записи: 2297711; Маркер выборки: 0; Число нарезок: 16
# [1000-1200]=> Headliner: № 200 -> Длина записи: 2729711; Маркер выборки: 1; Число нарезок: 19
#
# XTrain1.shape:  (5084, 137781, 1)
# YTrain1.shape:  (5084, 2)
# XTrain1V.shape:  (517, 137781, 1)
# YTrain1V.shape:  (517, 2)
# Обучающая выборка X_Train1 - Целевых: 2878; Нецелевых: 2206
# Валидационная выборка X_Train1V - Целевых: 291; Нецелевых: 226
# Epoch 1/20
# 40/40 [==============================] - 72s 1s/step - loss: 0.6594 - accuracy: 0.7321 - val_loss: 0.8206 - val_accuracy: 0.5938
# Epoch 2/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.3900 - accuracy: 0.8122 - val_loss: 12.1480 - val_accuracy: 0.4371
# Epoch 3/20
# 40/40 [==============================] - 44s 1s/step - loss: 0.2847 - accuracy: 0.8731 - val_loss: 2.0796 - val_accuracy: 0.6151
# Epoch 4/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.2329 - accuracy: 0.8971 - val_loss: 4.1343 - val_accuracy: 0.6789
# Epoch 5/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.2105 - accuracy: 0.9138 - val_loss: 14.5959 - val_accuracy: 0.6132
# Epoch 6/20
# 40/40 [==============================] - 45s 1s/step - loss: 0.1956 - accuracy: 0.9117 - val_loss: 7.0823 - val_accuracy: 0.6422
# Epoch 7/20
# 40/40 [==============================] - 45s 1s/step - loss: 0.1771 - accuracy: 0.9256 - val_loss: 3.8347 - val_accuracy: 0.7060
# Epoch 8/20
# 40/40 [==============================] - 44s 1s/step - loss: 0.1538 - accuracy: 0.9402 - val_loss: 1.4757 - val_accuracy: 0.7021
# Epoch 9/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.1352 - accuracy: 0.9459 - val_loss: 1.4912 - val_accuracy: 0.7466
# Epoch 10/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.1219 - accuracy: 0.9567 - val_loss: 1.5252 - val_accuracy: 0.7253
# Epoch 11/20
# 40/40 [==============================] - 45s 1s/step - loss: 0.1219 - accuracy: 0.9548 - val_loss: 1.6185 - val_accuracy: 0.7234
# Epoch 12/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0900 - accuracy: 0.9642 - val_loss: 1.1630 - val_accuracy: 0.7311
# Epoch 13/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0740 - accuracy: 0.9695 - val_loss: 1.4881 - val_accuracy: 0.7988
# Epoch 14/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0646 - accuracy: 0.9760 - val_loss: 1.3069 - val_accuracy: 0.7988
# Epoch 15/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0878 - accuracy: 0.9668 - val_loss: 2.2942 - val_accuracy: 0.6499
# Epoch 16/20
# 40/40 [==============================] - 44s 1s/step - loss: 0.0402 - accuracy: 0.9825 - val_loss: 4.0023 - val_accuracy: 0.6248
# Epoch 17/20
# 40/40 [==============================] - 44s 1s/step - loss: 0.0616 - accuracy: 0.9801 - val_loss: 1.1439 - val_accuracy: 0.7408
# Epoch 18/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0479 - accuracy: 0.9792 - val_loss: 7.0920 - val_accuracy: 0.6267
# Epoch 19/20
# 40/40 [==============================] - 45s 1s/step - loss: 0.0406 - accuracy: 0.9845 - val_loss: 0.3694 - val_accuracy: 0.9226
# Epoch 20/20
# 40/40 [==============================] - 46s 1s/step - loss: 0.0502 - accuracy: 0.9813 - val_loss: 7.4997 - val_accuracy: 0.6750
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [1000_1200] - 1-й из 16
#
# Запущен блок [1200_1400] - 2-й из 16
# [1200-1400]=> Paveletskaya_turbo: № 201 -> Длина записи: 1832303; Маркер выборки: 0; Число нарезок: 13
# [1200-1400]=> Headliner: № 202 -> Длина записи: 742511; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 203 -> Длина записи: 2633519; Маркер выборки: 0; Число нарезок: 19
# [1200-1400]=> Headliner: № 204 -> Длина записи: 1798319; Маркер выборки: 1; Число нарезок: 13
# [1200-1400]=> Paveletskaya_turbo: № 205 -> Длина записи: 14447; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 206 -> Длина записи: 1963631; Маркер выборки: 1; Число нарезок: 14
# [1200-1400]=> Paveletskaya_turbo: № 207 -> Длина записи: 1849583; Маркер выборки: 0; Число нарезок: 13
# [1200-1400]=> Headliner: № 208 -> Длина записи: 1688303; Маркер выборки: 1; Число нарезок: 12
# [1200-1400]=> Paveletskaya_turbo: № 209 -> Длина записи: 2403695; Маркер выборки: 0; Число нарезок: 17
# [1200-1400]=> Headliner: № 210 -> Длина записи: 1978607; Маркер выборки: 1; Число нарезок: 14
# [1200-1400]=> Paveletskaya_turbo: № 211 -> Длина записи: 2029295; Маркер выборки: 0; Число нарезок: 14
# [1200-1400]=> Headliner: № 212 -> Длина записи: 1838639; Маркер выборки: 1; Число нарезок: 13
# [1200-1400]=> Paveletskaya_turbo: № 213 -> Длина записи: 2960687; Маркер выборки: 0; Число нарезок: 21
# [1200-1400]=> Headliner: № 214 -> Длина записи: 2718767; Маркер выборки: 1; Число нарезок: 19
# [1200-1400]=> Paveletskaya_turbo: № 215 -> Длина записи: 951599; Маркер выборки: 0; Число нарезок: 6
# [1200-1400]=> Headliner: № 216 -> Длина записи: 441839; Маркер выборки: 1; Число нарезок: 3
# [1200-1400]=> Paveletskaya_turbo: № 217 -> Длина записи: 253487; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 218 -> Длина записи: 243119; Маркер выборки: 1; Число нарезок: 1
# [1200-1400]=> Paveletskaya_turbo: № 219 -> Длина записи: 194159; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 220 -> Длина записи: 3224495; Маркер выборки: 1; Число нарезок: 23
# [1200-1400]=> Paveletskaya_turbo: № 221 -> Длина записи: 1694063; Маркер выборки: 0; Число нарезок: 12
# [1200-1400]=> Headliner: № 222 -> Длина записи: 2714735; Маркер выборки: 1; Число нарезок: 19
# [1200-1400]=> Paveletskaya_turbo: № 223 -> Длина записи: 19055; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 224 -> Длина записи: 2673839; Маркер выборки: 1; Число нарезок: 19
# [1200-1400]=> Paveletskaya_turbo: № 225 -> Длина записи: 150959; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 226 -> Длина записи: 1415279; Маркер выборки: 1; Число нарезок: 10
# [1200-1400]=> Paveletskaya_turbo: № 227 -> Длина записи: 1967663; Маркер выборки: 0; Число нарезок: 14
# [1200-1400]=> Headliner: № 228 -> Длина записи: 354863; Маркер выборки: 1; Число нарезок: 2
# [1200-1400]=> Paveletskaya_turbo: № 229 -> Длина записи: 149231; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 230 -> Длина записи: 6238703; Маркер выборки: 1; Число нарезок: 45
# [1200-1400]=> Paveletskaya_turbo: № 231 -> Длина записи: 339311; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 232 -> Длина записи: 2272367; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 233 -> Длина записи: 344495; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 234 -> Длина записи: 5841839; Маркер выборки: 1; Число нарезок: 42
# [1200-1400]=> Paveletskaya_turbo: № 235 -> Длина записи: 784559; Маркер выборки: 0; Число нарезок: 5
# [1200-1400]=> Headliner: № 236 -> Длина записи: 809327; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 237 -> Длина записи: 1764911; Маркер выборки: 0; Число нарезок: 12
# [1200-1400]=> Headliner: № 238 -> Длина записи: 563951; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 239 -> Длина записи: 2004527; Маркер выборки: 0; Число нарезок: 14
# [1200-1400]=> Headliner: № 240 -> Длина записи: 930863; Маркер выборки: 1; Число нарезок: 6
# [1200-1400]=> Paveletskaya_turbo: № 241 -> Длина записи: 1266671; Маркер выборки: 0; Число нарезок: 9
# [1200-1400]=> Headliner: № 242 -> Длина записи: 1893359; Маркер выборки: 1; Число нарезок: 13
# [1200-1400]=> Paveletskaya_turbo: № 243 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 244 -> Длина записи: 654959; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 245 -> Длина записи: 323183; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 246 -> Длина записи: 2191151; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 247 -> Длина записи: 20783; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 248 -> Длина записи: 3813743; Маркер выборки: 1; Число нарезок: 27
# [1200-1400]=> Paveletskaya_turbo: № 249 -> Длина записи: 3366191; Маркер выборки: 0; Число нарезок: 24
# [1200-1400]=> Headliner: № 250 -> Длина записи: 2578799; Маркер выборки: 1; Число нарезок: 18
# [1200-1400]=> Paveletskaya_turbo: № 251 -> Длина записи: 144623; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 252 -> Длина записи: 6192047; Маркер выборки: 1; Число нарезок: 44
# [1200-1400]=> Paveletskaya_turbo: № 253 -> Длина записи: 832943; Маркер выборки: 0; Число нарезок: 6
# [1200-1400]=> Headliner: № 254 -> Длина записи: 626735; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 255 -> Длина записи: 583535; Маркер выборки: 0; Число нарезок: 4
# [1200-1400]=> Headliner: № 256 -> Длина записи: 2569007; Маркер выборки: 1; Число нарезок: 18
# [1200-1400]=> Paveletskaya_turbo: № 257 -> Длина записи: 2408303; Маркер выборки: 0; Число нарезок: 17
# [1200-1400]=> Headliner: № 258 -> Длина записи: 725807; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 259 -> Длина записи: 3388655; Маркер выборки: 0; Число нарезок: 24
# [1200-1400]=> Headliner: № 260 -> Длина записи: 549551; Маркер выборки: 1; Число нарезок: 3
# [1200-1400]=> Paveletskaya_turbo: № 261 -> Длина записи: 271343; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 262 -> Длина записи: 1871471; Маркер выборки: 1; Число нарезок: 13
# [1200-1400]=> Paveletskaya_turbo: № 263 -> Длина записи: 3702575; Маркер выборки: 0; Число нарезок: 26
# [1200-1400]=> Headliner: № 264 -> Длина записи: 2416943; Маркер выборки: 1; Число нарезок: 17
# [1200-1400]=> Paveletskaya_turbo: № 265 -> Длина записи: 3016559; Маркер выборки: 0; Число нарезок: 21
# [1200-1400]=> Headliner: № 266 -> Длина записи: 3236015; Маркер выборки: 1; Число нарезок: 23
# [1200-1400]=> Paveletskaya_turbo: № 267 -> Длина записи: 5774447; Маркер выборки: 0; Число нарезок: 41
# [1200-1400]=> Headliner: № 268 -> Длина записи: 686063; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 269 -> Длина записи: 2438255; Маркер выборки: 0; Число нарезок: 17
# [1200-1400]=> Headliner: № 270 -> Длина записи: 2134127; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 271 -> Длина записи: 403823; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 272 -> Длина записи: 1258607; Маркер выборки: 1; Число нарезок: 9
# [1200-1400]=> Paveletskaya_turbo: № 273 -> Длина записи: 184943; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 274 -> Длина записи: 1973423; Маркер выборки: 1; Число нарезок: 14
# [1200-1400]=> Paveletskaya_turbo: № 275 -> Длина записи: 2677295; Маркер выборки: 0; Число нарезок: 19
# [1200-1400]=> Headliner: № 276 -> Длина записи: 1061039; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 277 -> Длина записи: 502895; Маркер выборки: 0; Число нарезок: 3
# [1200-1400]=> Headliner: № 278 -> Длина записи: 3585071; Маркер выборки: 1; Число нарезок: 26
# [1200-1400]=> Paveletskaya_turbo: № 279 -> Длина записи: 449903; Маркер выборки: 0; Число нарезок: 3
# [1200-1400]=> Headliner: № 280 -> Длина записи: 2336879; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 281 -> Длина записи: 518447; Маркер выборки: 0; Число нарезок: 3
# [1200-1400]=> Headliner: № 282 -> Длина записи: 1020719; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 283 -> Длина записи: 184367; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 284 -> Длина записи: 1430255; Маркер выборки: 1; Число нарезок: 10
# [1200-1400]=> Paveletskaya_turbo: № 285 -> Длина записи: 1930799; Маркер выборки: 0; Число нарезок: 14
# [1200-1400]=> Headliner: № 286 -> Длина записи: 2737199; Маркер выборки: 1; Число нарезок: 19
# [1200-1400]=> Paveletskaya_turbo: № 287 -> Длина записи: 1832303; Маркер выборки: 0; Число нарезок: 13
# [1200-1400]=> Headliner: № 288 -> Длина записи: 2566703; Маркер выборки: 1; Число нарезок: 18
# [1200-1400]=> Paveletskaya_turbo: № 289 -> Длина записи: 209135; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 290 -> Длина записи: 1243631; Маркер выборки: 1; Число нарезок: 9
# [1200-1400]=> Paveletskaya_turbo: № 291 -> Длина записи: 404399; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 292 -> Длина записи: 2150255; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 293 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 294 -> Длина записи: 2229167; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 295 -> Длина записи: 2721071; Маркер выборки: 0; Число нарезок: 19
# [1200-1400]=> Headliner: № 296 -> Длина записи: 752879; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 297 -> Длина записи: 56495; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 298 -> Длина записи: 12546479; Маркер выборки: 1; Число нарезок: 91
# [1200-1400]=> Paveletskaya_turbo: № 299 -> Длина записи: 820847; Маркер выборки: 0; Число нарезок: 5
# [1200-1400]=> Headliner: № 300 -> Длина записи: 1707311; Маркер выборки: 1; Число нарезок: 12
# [1200-1400]=> Paveletskaya_turbo: № 301 -> Длина записи: 1267823; Маркер выборки: 0; Число нарезок: 9
# [1200-1400]=> Headliner: № 302 -> Длина записи: 2394479; Маркер выборки: 1; Число нарезок: 17
# [1200-1400]=> Paveletskaya_turbo: № 303 -> Длина записи: 2605871; Маркер выборки: 0; Число нарезок: 18
# [1200-1400]=> Headliner: № 304 -> Длина записи: 1097327; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 305 -> Длина записи: 974063; Маркер выборки: 0; Число нарезок: 7
# [1200-1400]=> Headliner: № 306 -> Длина записи: 762671; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 307 -> Длина записи: 381935; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 308 -> Длина записи: 985007; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 309 -> Длина записи: 5877551; Маркер выборки: 0; Число нарезок: 42
# [1200-1400]=> Headliner: № 310 -> Длина записи: 521903; Маркер выборки: 1; Число нарезок: 3
# [1200-1400]=> Paveletskaya_turbo: № 311 -> Длина записи: 5479535; Маркер выборки: 0; Число нарезок: 39
# [1200-1400]=> Headliner: № 312 -> Длина записи: 3751535; Маркер выборки: 1; Число нарезок: 27
# [1200-1400]=> Paveletskaya_turbo: № 313 -> Длина записи: 586991; Маркер выборки: 0; Число нарезок: 4
# [1200-1400]=> Headliner: № 314 -> Длина записи: 2430191; Маркер выборки: 1; Число нарезок: 17
# [1200-1400]=> Paveletskaya_turbo: № 315 -> Длина записи: 258671; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 316 -> Длина записи: 2120879; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 317 -> Длина записи: 3471023; Маркер выборки: 0; Число нарезок: 25
# [1200-1400]=> Headliner: № 318 -> Длина записи: 384815; Маркер выборки: 1; Число нарезок: 2
# [1200-1400]=> Paveletskaya_turbo: № 319 -> Длина записи: 70895; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 320 -> Длина записи: 3443375; Маркер выборки: 1; Число нарезок: 24
# [1200-1400]=> Paveletskaya_turbo: № 321 -> Длина записи: 40943; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 322 -> Длина записи: 1607663; Маркер выборки: 1; Число нарезок: 11
# [1200-1400]=> Paveletskaya_turbo: № 323 -> Длина записи: 762671; Маркер выборки: 0; Число нарезок: 5
# [1200-1400]=> Headliner: № 324 -> Длина записи: 851951; Маркер выборки: 1; Число нарезок: 6
# [1200-1400]=> Paveletskaya_turbo: № 325 -> Длина записи: 224111; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 326 -> Длина записи: 2261999; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 327 -> Длина записи: 2422703; Маркер выборки: 0; Число нарезок: 17
# [1200-1400]=> Headliner: № 328 -> Длина записи: 680879; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 329 -> Длина записи: 145199; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 330 -> Длина записи: 808751; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 331 -> Длина записи: 684335; Маркер выборки: 0; Число нарезок: 4
# [1200-1400]=> Headliner: № 332 -> Длина записи: 1437167; Маркер выборки: 1; Число нарезок: 10
# [1200-1400]=> Paveletskaya_turbo: № 333 -> Длина записи: 231599; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 334 -> Длина записи: 3797039; Маркер выборки: 1; Число нарезок: 27
# [1200-1400]=> Paveletskaya_turbo: № 335 -> Длина записи: 180335; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 336 -> Длина записи: 761519; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 337 -> Длина записи: 16751; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 338 -> Длина записи: 797807; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 339 -> Длина записи: 142319; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 340 -> Длина записи: 1863407; Маркер выборки: 1; Число нарезок: 13
# [1200-1400]=> Paveletskaya_turbo: № 341 -> Длина записи: 989615; Маркер выборки: 0; Число нарезок: 7
# [1200-1400]=> Headliner: № 342 -> Длина записи: 227567; Маркер выборки: 1; Число нарезок: 1
# [1200-1400]=> Paveletskaya_turbo: № 343 -> Длина записи: 2537903; Маркер выборки: 0; Число нарезок: 18
# [1200-1400]=> Headliner: № 344 -> Длина записи: 2221679; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 345 -> Длина записи: 5266991; Маркер выборки: 0; Число нарезок: 38
# [1200-1400]=> Headliner: № 346 -> Длина записи: 2194607; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 347 -> Длина записи: 638255; Маркер выборки: 0; Число нарезок: 4
# [1200-1400]=> Headliner: № 348 -> Длина записи: 3141551; Маркер выборки: 1; Число нарезок: 22
# [1200-1400]=> Paveletskaya_turbo: № 349 -> Длина записи: 214895; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 350 -> Длина записи: 2077103; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 351 -> Длина записи: 5354543; Маркер выборки: 0; Число нарезок: 38
# [1200-1400]=> Headliner: № 352 -> Длина записи: 1057583; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 353 -> Длина записи: 12719; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 354 -> Длина записи: 2801711; Маркер выборки: 1; Число нарезок: 20
# [1200-1400]=> Paveletskaya_turbo: № 355 -> Длина записи: 1345583; Маркер выборки: 0; Число нарезок: 9
# [1200-1400]=> Headliner: № 356 -> Длина записи: 2283311; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 357 -> Длина записи: 3090863; Маркер выборки: 0; Число нарезок: 22
# [1200-1400]=> Headliner: № 358 -> Длина записи: 602543; Маркер выборки: 1; Число нарезок: 4
# [1200-1400]=> Paveletskaya_turbo: № 359 -> Длина записи: 1036847; Маркер выборки: 0; Число нарезок: 7
# [1200-1400]=> Headliner: № 360 -> Длина записи: 7129199; Маркер выборки: 1; Число нарезок: 51
# [1200-1400]=> Paveletskaya_turbo: № 361 -> Длина записи: 112943; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 362 -> Длина записи: 2605871; Маркер выборки: 1; Число нарезок: 18
# [1200-1400]=> Paveletskaya_turbo: № 363 -> Длина записи: 678575; Маркер выборки: 0; Число нарезок: 4
# [1200-1400]=> Headliner: № 364 -> Длина записи: 1249391; Маркер выборки: 1; Число нарезок: 9
# [1200-1400]=> Paveletskaya_turbo: № 365 -> Длина записи: 373871; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 366 -> Длина записи: 4959407; Маркер выборки: 1; Число нарезок: 35
# [1200-1400]=> Paveletskaya_turbo: № 367 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 368 -> Длина записи: 2991791; Маркер выборки: 1; Число нарезок: 21
# [1200-1400]=> Paveletskaya_turbo: № 369 -> Длина записи: 1827119; Маркер выборки: 0; Число нарезок: 13
# [1200-1400]=> Headliner: № 370 -> Длина записи: 1290287; Маркер выборки: 1; Число нарезок: 9
# [1200-1400]=> Paveletskaya_turbo: № 371 -> Длина записи: 473519; Маркер выборки: 0; Число нарезок: 3
# [1200-1400]=> Headliner: № 372 -> Длина записи: 3510191; Маркер выборки: 1; Число нарезок: 25
# [1200-1400]=> Paveletskaya_turbo: № 373 -> Длина записи: 141167; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 374 -> Длина записи: 2245871; Маркер выборки: 1; Число нарезок: 16
# [1200-1400]=> Paveletskaya_turbo: № 375 -> Длина записи: 6045743; Маркер выборки: 0; Число нарезок: 43
# [1200-1400]=> Headliner: № 376 -> Длина записи: 3843119; Маркер выборки: 1; Число нарезок: 27
# [1200-1400]=> Paveletskaya_turbo: № 377 -> Длина записи: 2274671; Маркер выборки: 0; Число нарезок: 16
# [1200-1400]=> Headliner: № 378 -> Длина записи: 4097135; Маркер выборки: 1; Число нарезок: 29
# [1200-1400]=> Paveletskaya_turbo: № 379 -> Длина записи: 386543; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 380 -> Длина записи: 718895; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 381 -> Длина записи: 5306159; Маркер выборки: 0; Число нарезок: 38
# [1200-1400]=> Headliner: № 382 -> Длина записи: 740207; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 383 -> Длина записи: 323759; Маркер выборки: 0; Число нарезок: 2
# [1200-1400]=> Headliner: № 384 -> Длина записи: 1061039; Маркер выборки: 1; Число нарезок: 7
# [1200-1400]=> Paveletskaya_turbo: № 385 -> Длина записи: 254063; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 386 -> Длина записи: 293231; Маркер выборки: 1; Число нарезок: 2
# [1200-1400]=> Paveletskaya_turbo: № 387 -> Длина записи: 157295; Маркер выборки: 0; Число нарезок: 1
# [1200-1400]=> Headliner: № 388 -> Длина записи: 4784879; Маркер выборки: 1; Число нарезок: 34
# [1200-1400]=> Paveletskaya_turbo: № 389 -> Длина записи: 4588463; Маркер выборки: 0; Число нарезок: 33
# [1200-1400]=> Headliner: № 390 -> Длина записи: 8687; Маркер выборки: 1; Число нарезок: 0
# [1200-1400]=> Paveletskaya_turbo: № 391 -> Длина записи: 43247; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 392 -> Длина записи: 2119151; Маркер выборки: 1; Число нарезок: 15
# [1200-1400]=> Paveletskaya_turbo: № 393 -> Длина записи: 2927; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 394 -> Длина записи: 1979183; Маркер выборки: 1; Число нарезок: 14
# [1200-1400]=> Paveletskaya_turbo: № 395 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 396 -> Длина записи: 1233263; Маркер выборки: 1; Число нарезок: 8
# [1200-1400]=> Paveletskaya_turbo: № 397 -> Длина записи: 5241647; Маркер выборки: 0; Число нарезок: 38
# [1200-1400]=> Headliner: № 398 -> Длина записи: 741359; Маркер выборки: 1; Число нарезок: 5
# [1200-1400]=> Paveletskaya_turbo: № 399 -> Длина записи: 93359; Маркер выборки: 0; Число нарезок: 0
# [1200-1400]=> Headliner: № 400 -> Длина записи: 3744623; Маркер выборки: 1; Число нарезок: 27

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [1600_1700] - 1-й из 25
# [1600-1700]=> Paveletskaya_turbo: № 1 -> Длина записи: 328367; Маркер выборки: 0; Число нарезок: 2
# [1600-1700]=> Headliner: № 2 -> Длина записи: 292079; Маркер выборки: 1; Число нарезок: 2
# [1600-1700]=> Paveletskaya_turbo: № 3 -> Длина записи: 2690543; Маркер выборки: 0; Число нарезок: 19
# [1600-1700]=> Headliner: № 4 -> Длина записи: 1254575; Маркер выборки: 1; Число нарезок: 9
# [1600-1700]=> Paveletskaya_turbo: № 5 -> Длина записи: 417071; Маркер выборки: 0; Число нарезок: 3
# [1600-1700]=> Headliner: № 6 -> Длина записи: 1347887; Маркер выборки: 1; Число нарезок: 9
# [1600-1700]=> Paveletskaya_turbo: № 7 -> Длина записи: 2191151; Маркер выборки: 0; Число нарезок: 15
# [1600-1700]=> Headliner: № 8 -> Длина записи: 1012079; Маркер выборки: 1; Число нарезок: 7
# [1600-1700]=> Paveletskaya_turbo: № 9 -> Длина записи: 876719; Маркер выборки: 0; Число нарезок: 6
# [1600-1700]=> Headliner: № 10 -> Длина записи: 2203823; Маркер выборки: 1; Число нарезок: 15
# [1600-1700]=> Paveletskaya_turbo: № 11 -> Длина записи: 965423; Маркер выборки: 0; Число нарезок: 7
# [1600-1700]=> Headliner: № 12 -> Длина записи: 1188911; Маркер выборки: 1; Число нарезок: 8
# [1600-1700]=> Paveletskaya_turbo: № 13 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 14 -> Длина записи: 1263791; Маркер выборки: 1; Число нарезок: 9
# [1600-1700]=> Paveletskaya_turbo: № 15 -> Длина записи: 1258607; Маркер выборки: 0; Число нарезок: 9
# [1600-1700]=> Headliner: № 16 -> Длина записи: 2247023; Маркер выборки: 1; Число нарезок: 16
# [1600-1700]=> Paveletskaya_turbo: № 17 -> Длина записи: 1763759; Маркер выборки: 0; Число нарезок: 12
# [1600-1700]=> Headliner: № 18 -> Длина записи: 1997039; Маркер выборки: 1; Число нарезок: 14
# [1600-1700]=> Paveletskaya_turbo: № 19 -> Длина записи: 438959; Маркер выборки: 0; Число нарезок: 3
# [1600-1700]=> Headliner: № 20 -> Длина записи: 2501615; Маркер выборки: 1; Число нарезок: 18
# [1600-1700]=> Paveletskaya_turbo: № 21 -> Длина записи: 7535; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 22 -> Длина записи: 8019119; Маркер выборки: 1; Число нарезок: 58
# [1600-1700]=> Paveletskaya_turbo: № 23 -> Длина записи: 4436975; Маркер выборки: 0; Число нарезок: 32
# [1600-1700]=> Headliner: № 24 -> Длина записи: 453359; Маркер выборки: 1; Число нарезок: 3
# [1600-1700]=> Paveletskaya_turbo: № 25 -> Длина записи: 6424175; Маркер выборки: 0; Число нарезок: 46
# [1600-1700]=> Headliner: № 26 -> Длина записи: 368111; Маркер выборки: 1; Число нарезок: 2
# [1600-1700]=> Paveletskaya_turbo: № 27 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 28 -> Длина записи: 2549423; Маркер выборки: 1; Число нарезок: 18
# [1600-1700]=> Paveletskaya_turbo: № 29 -> Длина записи: 3842543; Маркер выборки: 0; Число нарезок: 27
# [1600-1700]=> Headliner: № 30 -> Длина записи: 1759727; Маркер выборки: 1; Число нарезок: 12
# [1600-1700]=> Paveletskaya_turbo: № 31 -> Длина записи: 3948527; Маркер выборки: 0; Число нарезок: 28
# [1600-1700]=> Headliner: № 32 -> Длина записи: 4116719; Маркер выборки: 1; Число нарезок: 29
# [1600-1700]=> Paveletskaya_turbo: № 33 -> Длина записи: 1384175; Маркер выборки: 0; Число нарезок: 10
# [1600-1700]=> Headliner: № 34 -> Длина записи: 944687; Маркер выборки: 1; Число нарезок: 6
# [1600-1700]=> Paveletskaya_turbo: № 35 -> Длина записи: 153839; Маркер выборки: 0; Число нарезок: 1
# [1600-1700]=> Headliner: № 36 -> Длина записи: 1495343; Маркер выборки: 1; Число нарезок: 10
# [1600-1700]=> Paveletskaya_turbo: № 37 -> Длина записи: 6357935; Маркер выборки: 0; Число нарезок: 46
# [1600-1700]=> Headliner: № 38 -> Длина записи: 591023; Маркер выборки: 1; Число нарезок: 4
# [1600-1700]=> Paveletskaya_turbo: № 39 -> Длина записи: 3901295; Маркер выборки: 0; Число нарезок: 28
# [1600-1700]=> Headliner: № 40 -> Длина записи: 1980335; Маркер выборки: 1; Число нарезок: 14
# [1600-1700]=> Paveletskaya_turbo: № 41 -> Длина записи: 1194095; Маркер выборки: 0; Число нарезок: 8
# [1600-1700]=> Headliner: № 42 -> Длина записи: 1609967; Маркер выборки: 1; Число нарезок: 11
# [1600-1700]=> Paveletskaya_turbo: № 43 -> Длина записи: 2721071; Маркер выборки: 0; Число нарезок: 19
# [1600-1700]=> Headliner: № 44 -> Длина записи: 1105391; Маркер выборки: 1; Число нарезок: 8
# [1600-1700]=> Paveletskaya_turbo: № 45 -> Длина записи: 5439791; Маркер выборки: 0; Число нарезок: 39
# [1600-1700]=> Headliner: № 46 -> Длина записи: 6550319; Маркер выборки: 1; Число нарезок: 47
# [1600-1700]=> Paveletskaya_turbo: № 47 -> Длина записи: 4193903; Маркер выборки: 0; Число нарезок: 30
# [1600-1700]=> Headliner: № 48 -> Длина записи: 2993519; Маркер выборки: 1; Число нарезок: 21
# [1600-1700]=> Paveletskaya_turbo: № 49 -> Длина записи: 1023599; Маркер выборки: 0; Число нарезок: 7
# [1600-1700]=> Headliner: № 50 -> Длина записи: 462575; Маркер выборки: 1; Число нарезок: 3
# [1600-1700]=> Paveletskaya_turbo: № 51 -> Длина записи: 1457327; Маркер выборки: 0; Число нарезок: 10
# [1600-1700]=> Headliner: № 52 -> Длина записи: 4548143; Маркер выборки: 1; Число нарезок: 33
# [1600-1700]=> Paveletskaya_turbo: № 53 -> Длина записи: 275951; Маркер выборки: 0; Число нарезок: 2
# [1600-1700]=> Headliner: № 54 -> Длина записи: 5041775; Маркер выборки: 1; Число нарезок: 36
# [1600-1700]=> Paveletskaya_turbo: № 55 -> Длина записи: 5372399; Маркер выборки: 0; Число нарезок: 38
# [1600-1700]=> Headliner: № 56 -> Длина записи: 855407; Маркер выборки: 1; Число нарезок: 6
# [1600-1700]=> Paveletskaya_turbo: № 57 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 58 -> Длина записи: 2176751; Маркер выборки: 1; Число нарезок: 15
# [1600-1700]=> Paveletskaya_turbo: № 59 -> Длина записи: 3480815; Маркер выборки: 0; Число нарезок: 25
# [1600-1700]=> Headliner: № 60 -> Длина записи: 1000559; Маркер выборки: 1; Число нарезок: 7
# [1600-1700]=> Paveletskaya_turbo: № 61 -> Длина записи: 2321903; Маркер выборки: 0; Число нарезок: 16
# [1600-1700]=> Headliner: № 62 -> Длина записи: 6173615; Маркер выборки: 1; Число нарезок: 44
# [1600-1700]=> Paveletskaya_turbo: № 63 -> Длина записи: 8614127; Маркер выборки: 0; Число нарезок: 62
# [1600-1700]=> Headliner: № 64 -> Длина записи: 387695; Маркер выборки: 1; Число нарезок: 2
# [1600-1700]=> Paveletskaya_turbo: № 65 -> Длина записи: 1590959; Маркер выборки: 0; Число нарезок: 11
# [1600-1700]=> Headliner: № 66 -> Длина записи: 4474991; Маркер выборки: 1; Число нарезок: 32
# [1600-1700]=> Paveletskaya_turbo: № 67 -> Длина записи: 5116655; Маркер выборки: 0; Число нарезок: 37
# [1600-1700]=> Headliner: № 68 -> Длина записи: 4052207; Маркер выборки: 1; Число нарезок: 29
# [1600-1700]=> Paveletskaya_turbo: № 69 -> Длина записи: 960815; Маркер выборки: 0; Число нарезок: 6
# [1600-1700]=> Headliner: № 70 -> Длина записи: 1791407; Маркер выборки: 1; Число нарезок: 13
# [1600-1700]=> Paveletskaya_turbo: № 71 -> Длина записи: 1483247; Маркер выборки: 0; Число нарезок: 10
# [1600-1700]=> Headliner: № 72 -> Длина записи: 2287343; Маркер выборки: 1; Число нарезок: 16
# [1600-1700]=> Paveletskaya_turbo: № 73 -> Длина записи: 986159; Маркер выборки: 0; Число нарезок: 7
# [1600-1700]=> Headliner: № 74 -> Длина записи: 831791; Маркер выборки: 1; Число нарезок: 6
# [1600-1700]=> Paveletskaya_turbo: № 75 -> Длина записи: 623279; Маркер выборки: 0; Число нарезок: 4
# [1600-1700]=> Headliner: № 76 -> Длина записи: 1013231; Маркер выборки: 1; Число нарезок: 7
# [1600-1700]=> Paveletskaya_turbo: № 77 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 78 -> Длина записи: 432623; Маркер выборки: 1; Число нарезок: 3
# [1600-1700]=> Paveletskaya_turbo: № 79 -> Длина записи: 1023599; Маркер выборки: 0; Число нарезок: 7
# [1600-1700]=> Headliner: № 80 -> Длина записи: 13436975; Маркер выборки: 1; Число нарезок: 97
# [1600-1700]=> Paveletskaya_turbo: № 81 -> Длина записи: 1420463; Маркер выборки: 0; Число нарезок: 10
# [1600-1700]=> Headliner: № 82 -> Длина записи: 2166383; Маркер выборки: 1; Число нарезок: 15
# [1600-1700]=> Paveletskaya_turbo: № 83 -> Длина записи: 550703; Маркер выборки: 0; Число нарезок: 3
# [1600-1700]=> Headliner: № 84 -> Длина записи: 293807; Маркер выборки: 1; Число нарезок: 2
# [1600-1700]=> Paveletskaya_turbo: № 85 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 86 -> Длина записи: 357167; Маркер выборки: 1; Число нарезок: 2
# [1600-1700]=> Paveletskaya_turbo: № 87 -> Длина записи: 119279; Маркер выборки: 0; Число нарезок: 0
# [1600-1700]=> Headliner: № 88 -> Длина записи: 2037359; Маркер выборки: 1; Число нарезок: 14
# [1600-1700]=> Paveletskaya_turbo: № 89 -> Длина записи: 141167; Маркер выборки: 0; Число нарезок: 1
# [1600-1700]=> Headliner: № 90 -> Длина записи: 2960111; Маркер выборки: 1; Число нарезок: 21
# [1600-1700]=> Paveletskaya_turbo: № 91 -> Длина записи: 2031599; Маркер выборки: 0; Число нарезок: 14
# [1600-1700]=> Headliner: № 92 -> Длина записи: 1013807; Маркер выборки: 1; Число нарезок: 7
# [1600-1700]=> Paveletskaya_turbo: № 93 -> Длина записи: 308783; Маркер выборки: 0; Число нарезок: 2
# [1600-1700]=> Headliner: № 94 -> Длина записи: 153263; Маркер выборки: 1; Число нарезок: 1
# [1600-1700]=> Paveletskaya_turbo: № 95 -> Длина записи: 1089263; Маркер выборки: 0; Число нарезок: 7
# [1600-1700]=> Headliner: № 96 -> Длина записи: 2544815; Маркер выборки: 1; Число нарезок: 18
# [1600-1700]=> Paveletskaya_turbo: № 97 -> Длина записи: 3264815; Маркер выборки: 0; Число нарезок: 23
# [1600-1700]=> Headliner: № 98 -> Длина записи: 2482607; Маркер выборки: 1; Число нарезок: 18
# [1600-1700]=> Paveletskaya_turbo: № 99 -> Длина записи: 5673071; Маркер выборки: 0; Число нарезок: 41
# [1600-1700]=> Headliner: № 100 -> Длина записи: 1343855; Маркер выборки: 1; Число нарезок: 9
#
# XTrain1.shape:  (2812, 137781, 1)
# YTrain1.shape:  (2812, 2)
# XTrain1V.shape:  (289, 137781, 1)
# YTrain1V.shape:  (289, 2)
# Обучающая выборка X_Train1 - Целевых: 1472; Нецелевых: 1340
# Валидационная выборка X_Train1V - Целевых: 147; Нецелевых: 142
# Epoch 1/20

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [1600_1650] - 1-й из 51
# [1600-1650]=> Paveletskaya_turbo: № 1 -> Длина записи: 328367; Маркер выборки: 0; Число нарезок: 2
# [1600-1650]=> Headliner: № 2 -> Длина записи: 292079; Маркер выборки: 1; Число нарезок: 2
# [1600-1650]=> Paveletskaya_turbo: № 3 -> Длина записи: 2690543; Маркер выборки: 0; Число нарезок: 19
# [1600-1650]=> Headliner: № 4 -> Длина записи: 1254575; Маркер выборки: 1; Число нарезок: 9
# [1600-1650]=> Paveletskaya_turbo: № 5 -> Длина записи: 417071; Маркер выборки: 0; Число нарезок: 3
# [1600-1650]=> Headliner: № 6 -> Длина записи: 1347887; Маркер выборки: 1; Число нарезок: 9
# [1600-1650]=> Paveletskaya_turbo: № 7 -> Длина записи: 2191151; Маркер выборки: 0; Число нарезок: 15
# [1600-1650]=> Headliner: № 8 -> Длина записи: 1012079; Маркер выборки: 1; Число нарезок: 7
# [1600-1650]=> Paveletskaya_turbo: № 9 -> Длина записи: 876719; Маркер выборки: 0; Число нарезок: 6
# [1600-1650]=> Headliner: № 10 -> Длина записи: 2203823; Маркер выборки: 1; Число нарезок: 15
# [1600-1650]=> Paveletskaya_turbo: № 11 -> Длина записи: 965423; Маркер выборки: 0; Число нарезок: 7
# [1600-1650]=> Headliner: № 12 -> Длина записи: 1188911; Маркер выборки: 1; Число нарезок: 8
# [1600-1650]=> Paveletskaya_turbo: № 13 -> Длина записи: 20207; Маркер выборки: 0; Число нарезок: 0
# [1600-1650]=> Headliner: № 14 -> Длина записи: 1263791; Маркер выборки: 1; Число нарезок: 9
# [1600-1650]=> Paveletskaya_turbo: № 15 -> Длина записи: 1258607; Маркер выборки: 0; Число нарезок: 9
# [1600-1650]=> Headliner: № 16 -> Длина записи: 2247023; Маркер выборки: 1; Число нарезок: 16
# [1600-1650]=> Paveletskaya_turbo: № 17 -> Длина записи: 1763759; Маркер выборки: 0; Число нарезок: 12
# [1600-1650]=> Headliner: № 18 -> Длина записи: 1997039; Маркер выборки: 1; Число нарезок: 14
# [1600-1650]=> Paveletskaya_turbo: № 19 -> Длина записи: 438959; Маркер выборки: 0; Число нарезок: 3
# [1600-1650]=> Headliner: № 20 -> Длина записи: 2501615; Маркер выборки: 1; Число нарезок: 18
# [1600-1650]=> Paveletskaya_turbo: № 21 -> Длина записи: 7535; Маркер выборки: 0; Число нарезок: 0
# [1600-1650]=> Headliner: № 22 -> Длина записи: 8019119; Маркер выборки: 1; Число нарезок: 58
# [1600-1650]=> Paveletskaya_turbo: № 23 -> Длина записи: 4436975; Маркер выборки: 0; Число нарезок: 32
# [1600-1650]=> Headliner: № 24 -> Длина записи: 453359; Маркер выборки: 1; Число нарезок: 3
# [1600-1650]=> Paveletskaya_turbo: № 25 -> Длина записи: 6424175; Маркер выборки: 0; Число нарезок: 46
# [1600-1650]=> Headliner: № 26 -> Длина записи: 368111; Маркер выборки: 1; Число нарезок: 2
# [1600-1650]=> Paveletskaya_turbo: № 27 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1600-1650]=> Headliner: № 28 -> Длина записи: 2549423; Маркер выборки: 1; Число нарезок: 18
# [1600-1650]=> Paveletskaya_turbo: № 29 -> Длина записи: 3842543; Маркер выборки: 0; Число нарезок: 27
# [1600-1650]=> Headliner: № 30 -> Длина записи: 1759727; Маркер выборки: 1; Число нарезок: 12
# [1600-1650]=> Paveletskaya_turbo: № 31 -> Длина записи: 3948527; Маркер выборки: 0; Число нарезок: 28
# [1600-1650]=> Headliner: № 32 -> Длина записи: 4116719; Маркер выборки: 1; Число нарезок: 29
# [1600-1650]=> Paveletskaya_turbo: № 33 -> Длина записи: 1384175; Маркер выборки: 0; Число нарезок: 10
# [1600-1650]=> Headliner: № 34 -> Длина записи: 944687; Маркер выборки: 1; Число нарезок: 6
# [1600-1650]=> Paveletskaya_turbo: № 35 -> Длина записи: 153839; Маркер выборки: 0; Число нарезок: 1
# [1600-1650]=> Headliner: № 36 -> Длина записи: 1495343; Маркер выборки: 1; Число нарезок: 10
# [1600-1650]=> Paveletskaya_turbo: № 37 -> Длина записи: 6357935; Маркер выборки: 0; Число нарезок: 46
# [1600-1650]=> Headliner: № 38 -> Длина записи: 591023; Маркер выборки: 1; Число нарезок: 4
# [1600-1650]=> Paveletskaya_turbo: № 39 -> Длина записи: 3901295; Маркер выборки: 0; Число нарезок: 28
# [1600-1650]=> Headliner: № 40 -> Длина записи: 1980335; Маркер выборки: 1; Число нарезок: 14
# [1600-1650]=> Paveletskaya_turbo: № 41 -> Длина записи: 1194095; Маркер выборки: 0; Число нарезок: 8
# [1600-1650]=> Headliner: № 42 -> Длина записи: 1609967; Маркер выборки: 1; Число нарезок: 11
# [1600-1650]=> Paveletskaya_turbo: № 43 -> Длина записи: 2721071; Маркер выборки: 0; Число нарезок: 19
# [1600-1650]=> Headliner: № 44 -> Длина записи: 1105391; Маркер выборки: 1; Число нарезок: 8
# [1600-1650]=> Paveletskaya_turbo: № 45 -> Длина записи: 5439791; Маркер выборки: 0; Число нарезок: 39
# [1600-1650]=> Headliner: № 46 -> Длина записи: 6550319; Маркер выборки: 1; Число нарезок: 47
# [1600-1650]=> Paveletskaya_turbo: № 47 -> Длина записи: 4193903; Маркер выборки: 0; Число нарезок: 30
# [1600-1650]=> Headliner: № 48 -> Длина записи: 2993519; Маркер выборки: 1; Число нарезок: 21
# [1600-1650]=> Paveletskaya_turbo: № 49 -> Длина записи: 1023599; Маркер выборки: 0; Число нарезок: 7
# [1600-1650]=> Headliner: № 50 -> Длина записи: 462575; Маркер выборки: 1; Число нарезок: 3
#
# XTrain1.shape:  (1369, 137781, 1)
# YTrain1.shape:  (1369, 2)
# XTrain1V.shape:  (138, 137781, 1)
# YTrain1V.shape:  (138, 2)
# Обучающая выборка X_Train1 - Целевых: 645; Нецелевых: 724
# Валидационная выборка X_Train1V - Целевых: 61; Нецелевых: 77
# Epoch 1/20
# 43/43 [==============================] - 555s 13s/step - loss: 0.5095 - accuracy: 0.8247 - val_loss: 3.6116 - val_accuracy: 0.5797
# Epoch 2/20
# 43/43 [==============================] - 554s 13s/step - loss: 0.2834 - accuracy: 0.8985 - val_loss: 9.5118 - val_accuracy: 0.4420
# Epoch 3/20
# 43/43 [==============================] - 547s 13s/step - loss: 0.3721 - accuracy: 0.8488 - val_loss: 12.7807 - val_accuracy: 0.5652
# Epoch 4/20
# 43/43 [==============================] - 544s 13s/step - loss: 0.3191 - accuracy: 0.8802 - val_loss: 7.5839 - val_accuracy: 0.4420
# Epoch 5/20
# 43/43 [==============================] - 536s 12s/step - loss: 0.2918 - accuracy: 0.8897 - val_loss: 3.1117 - val_accuracy: 0.8333
# Epoch 6/20
# 43/43 [==============================] - 545s 13s/step - loss: 0.3801 - accuracy: 0.8510 - val_loss: 1.6033 - val_accuracy: 0.5507
# Epoch 7/20
# 43/43 [==============================] - 543s 13s/step - loss: 0.2461 - accuracy: 0.9036 - val_loss: 0.5542 - val_accuracy: 0.6594
# Epoch 8/20
# 43/43 [==============================] - 544s 13s/step - loss: 0.1865 - accuracy: 0.9313 - val_loss: 91.5157 - val_accuracy: 0.4420
# Epoch 9/20
# 43/43 [==============================] - 542s 13s/step - loss: 0.1903 - accuracy: 0.9335 - val_loss: 45.4691 - val_accuracy: 0.4420
# Epoch 10/20
# 43/43 [==============================] - 536s 12s/step - loss: 0.1148 - accuracy: 0.9518 - val_loss: 0.6993 - val_accuracy: 0.9420
# Epoch 11/20
# 43/43 [==============================] - 545s 13s/step - loss: 0.1487 - accuracy: 0.9481 - val_loss: 43.0171 - val_accuracy: 0.4420
# Epoch 12/20
# 43/43 [==============================] - 547s 13s/step - loss: 0.1223 - accuracy: 0.9598 - val_loss: 0.3611 - val_accuracy: 0.9058
# Epoch 13/20
# 43/43 [==============================] - 548s 13s/step - loss: 0.0845 - accuracy: 0.9686 - val_loss: 57.5091 - val_accuracy: 0.4420
# Epoch 14/20
# 43/43 [==============================] - 545s 13s/step - loss: 0.1512 - accuracy: 0.9438 - val_loss: 11963.1670 - val_accuracy: 0.7319
# Epoch 15/20
# 43/43 [==============================] - 544s 13s/step - loss: 0.1533 - accuracy: 0.9401 - val_loss: 384.3715 - val_accuracy: 0.8333
# Epoch 16/20
# 43/43 [==============================] - 547s 13s/step - loss: 0.0798 - accuracy: 0.9722 - val_loss: 33.0152 - val_accuracy: 0.4420
# Epoch 17/20
# 43/43 [==============================] - 549s 13s/step - loss: 0.0968 - accuracy: 0.9686 - val_loss: 0.3392 - val_accuracy: 0.8406
# Epoch 18/20
# 43/43 [==============================] - 534s 12s/step - loss: 0.0420 - accuracy: 0.9803 - val_loss: 2.3495 - val_accuracy: 0.8696
# Epoch 19/20
# 43/43 [==============================] - 539s 13s/step - loss: 0.0551 - accuracy: 0.9832 - val_loss: 44.8518 - val_accuracy: 0.4420
# Epoch 20/20
# 43/43 [==============================] - 535s 12s/step - loss: 0.0647 - accuracy: 0.9774 - val_loss: 37.9467 - val_accuracy: 0.4493
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [1600_1650] - 1-й из 51
#
# Запущен блок [1650_1700] - 2-й из 51
# [1650-1700]=> Paveletskaya_turbo: № 51 -> Длина записи: 1457327; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 52 -> Длина записи: 4548143; Маркер выборки: 1; Число нарезок: 33
# [1650-1700]=> Paveletskaya_turbo: № 53 -> Длина записи: 275951; Маркер выборки: 0; Число нарезок: 2
# [1650-1700]=> Headliner: № 54 -> Длина записи: 5041775; Маркер выборки: 1; Число нарезок: 36
# [1650-1700]=> Paveletskaya_turbo: № 55 -> Длина записи: 5372399; Маркер выборки: 0; Число нарезок: 38
# [1650-1700]=> Headliner: № 56 -> Длина записи: 855407; Маркер выборки: 1; Число нарезок: 6
# [1650-1700]=> Paveletskaya_turbo: № 57 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 58 -> Длина записи: 2176751; Маркер выборки: 1; Число нарезок: 15
# [1650-1700]=> Paveletskaya_turbo: № 59 -> Длина записи: 3480815; Маркер выборки: 0; Число нарезок: 25
# [1650-1700]=> Headliner: № 60 -> Длина записи: 1000559; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 61 -> Длина записи: 2321903; Маркер выборки: 0; Число нарезок: 16
# [1650-1700]=> Headliner: № 62 -> Длина записи: 6173615; Маркер выборки: 1; Число нарезок: 44
# [1650-1700]=> Paveletskaya_turbo: № 63 -> Длина записи: 8614127; Маркер выборки: 0; Число нарезок: 62
# [1650-1700]=> Headliner: № 64 -> Длина записи: 387695; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 65 -> Длина записи: 1590959; Маркер выборки: 0; Число нарезок: 11
# [1650-1700]=> Headliner: № 66 -> Длина записи: 4474991; Маркер выборки: 1; Число нарезок: 32
# [1650-1700]=> Paveletskaya_turbo: № 67 -> Длина записи: 5116655; Маркер выборки: 0; Число нарезок: 37
# [1650-1700]=> Headliner: № 68 -> Длина записи: 4052207; Маркер выборки: 1; Число нарезок: 29
# [1650-1700]=> Paveletskaya_turbo: № 69 -> Длина записи: 960815; Маркер выборки: 0; Число нарезок: 6
# [1650-1700]=> Headliner: № 70 -> Длина записи: 1791407; Маркер выборки: 1; Число нарезок: 13
# [1650-1700]=> Paveletskaya_turbo: № 71 -> Длина записи: 1483247; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 72 -> Длина записи: 2287343; Маркер выборки: 1; Число нарезок: 16
# [1650-1700]=> Paveletskaya_turbo: № 73 -> Длина записи: 986159; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 74 -> Длина записи: 831791; Маркер выборки: 1; Число нарезок: 6
# [1650-1700]=> Paveletskaya_turbo: № 75 -> Длина записи: 623279; Маркер выборки: 0; Число нарезок: 4
# [1650-1700]=> Headliner: № 76 -> Длина записи: 1013231; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 77 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 78 -> Длина записи: 432623; Маркер выборки: 1; Число нарезок: 3
# [1650-1700]=> Paveletskaya_turbo: № 79 -> Длина записи: 1023599; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 80 -> Длина записи: 13436975; Маркер выборки: 1; Число нарезок: 97
# [1650-1700]=> Paveletskaya_turbo: № 81 -> Длина записи: 1420463; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 82 -> Длина записи: 2166383; Маркер выборки: 1; Число нарезок: 15
# [1650-1700]=> Paveletskaya_turbo: № 83 -> Длина записи: 550703; Маркер выборки: 0; Число нарезок: 3
# [1650-1700]=> Headliner: № 84 -> Длина записи: 293807; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 85 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 86 -> Длина записи: 357167; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 87 -> Длина записи: 119279; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 88 -> Длина записи: 2037359; Маркер выборки: 1; Число нарезок: 14
# [1650-1700]=> Paveletskaya_turbo: № 89 -> Длина записи: 141167; Маркер выборки: 0; Число нарезок: 1
# [1650-1700]=> Headliner: № 90 -> Длина записи: 2960111; Маркер выборки: 1; Число нарезок: 21
# [1650-1700]=> Paveletskaya_turbo: № 91 -> Длина записи: 2031599; Маркер выборки: 0; Число нарезок: 14
# [1650-1700]=> Headliner: № 92 -> Длина записи: 1013807; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 93 -> Длина записи: 308783; Маркер выборки: 0; Число нарезок: 2
# [1650-1700]=> Headliner: № 94 -> Длина записи: 153263; Маркер выборки: 1; Число нарезок: 1
# [1650-1700]=> Paveletskaya_turbo: № 95 -> Длина записи: 1089263; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 96 -> Длина записи: 2544815; Маркер выборки: 1; Число нарезок: 18
# [1650-1700]=> Paveletskaya_turbo: № 97 -> Длина записи: 3264815; Маркер выборки: 0; Число нарезок: 23
# [1650-1700]=> Headliner: № 98 -> Длина записи: 2482607; Маркер выборки: 1; Число нарезок: 18
# [1650-1700]=> Paveletskaya_turbo: № 99 -> Длина записи: 5673071; Маркер выборки: 0; Число нарезок: 41
# [1650-1700]=> Headliner: № 100 -> Длина записи: 1343855; Маркер выборки: 1; Число нарезок: 9
#
# XTrain1.shape:  (1443, 137781, 1)
# YTrain1.shape:  (1443, 2)
# XTrain1V.shape:  (151, 137781, 1)
# YTrain1V.shape:  (151, 2)
# Обучающая выборка X_Train1 - Целевых: 1472; Нецелевых: 1340
# Валидационная выборка X_Train1V - Целевых: 147; Нецелевых: 142
# Epoch 1/20
# 46/46 [==============================] - 555s 12s/step - loss: 0.3478 - accuracy: 0.8773 - val_loss: 0.3753 - val_accuracy: 0.8146
# Epoch 2/20
# 46/46 [==============================] - 565s 12s/step - loss: 0.4301 - accuracy: 0.8489 - val_loss: 9.5281 - val_accuracy: 0.6225
# Epoch 3/20
# 46/46 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.6902

# %%
def neuro_au():
  #
  # Параметры настройки нарезки обучения и слоёв модели
  #
  name_list_ = ['Headliner','Paveletskaya_city', 'Paveletskaya_turbo', 'Primavera']
  audio_path_ = [WAV_HEADL, WAV_PAVEL, WAV_PAVEL, WAV_PRIMA]

  #Размер пулинга
  pull_size = PULL_SIZE

  # Количество фильтров (параметр filters в Conv1D ) в сверточных слоях
  # в каждом из классифицирующих блоков
  sections = SECTIONS

  conv_pull_blocks = len(sections) # Число классифицирующих блоков (свертка + пулинг)

  strider = CONV_STRIDE_1 # stride на 1-м слое

  # Расчёт нарезки аудиофайлов при подаче на 1-й слой НС.
  # Т.е. длина кусочков, на которые мы нарезаем исходный сигнал
  # Количество фильтров (sections), их ядра и размер пуллинга подбираются из расчёта
  # получить размерность выхода 1 на последней свёртке
  audio_slicing_size = strider * (pull_size ** conv_pull_blocks)

  # print("Длина нарезки аудиофайла: ", audio_slicing_size)

  #### Борьба с вылетами по оперпамяти: работаем по частям с сохранением промежуточных результатовов и отключением виртуальной машины
  ####
  #data_number_ = 0
  #df_pre_train_ = df_pre_train[df_pre_train.DataNumber == data_number_]
  df_pre_train_ = df_pre_train
  #
  a_files_count_ = 0

  # Проходимся по всем аудиофайлам
  ## for au_name_ in df_pre_train_.AudioFile:
  # df_pre_train_.shape[0] = 6115

  #####
  ##### Основной цикл: создания блока выборок, запуска обучения, сохранения модели
  #####

  # Счётчик блоков аудиофайлов
  tr_block_number_ = 0
  tr_block_count_ = len(TR_BLOCKS)

  # Счётчики Целевой/Нецелевой по выборркам обучения
  X_Marker_0 = 0
  X_Marker_1 = 0
  XV_Marker_0 = 0
  XV_Marker_1 = 0

  for tr_block_ in TR_BLOCKS:
    tr_block_number_ += 1
    blk_ = '['+str(tr_block_[0])+'_'+str(tr_block_[1])+']'
    print(f'\nЗапущен блок {blk_} - {tr_block_number_}-й из {tr_block_count_}')
    # Обучающая выборка
    X_train1 = []
    Y_train1 = []
    # Валидационная выборка
    X_train1V = []
    Y_train1V = []
    # Тестовая выборка
    X_test1 = []
    Y_test1 = []
    for i in range(tr_block_[0], tr_block_[1]):

      start_time = time.time()
      a_files_count_ +=1

      au_name_ = df_pre_train_.loc[i]['AudioFile']

      ## data_number_ = df_pre_train_.iloc[df_pre_train_[df_pre_train_.AudioFile == au_name_].index[0]]['DataNumber']
      data_number_ = df_pre_train_.loc[i]['DataNumber']

      try:
        y, sr = librosa.load(audio_path_[data_number_]+'/'+au_name_, mono=True, sr=SR) #Загружаем аудиофайл
      except LibsndfileError:
        print(f'Ошибка обработки файла: {audio_path_[data_number_]+"/"+au_name_}')
        continue
      except FileNotFoundError:
        print(f'Не найден файл: {audio_path_[data_number_]+"/"+au_name_}')
        continue

      au_len_ = len(y) # Количество сигналов

      # Значение маркера текущего аудиофайла
      ## training_marker_ = df_pre_train_.iloc[df_pre_train_[df_pre_train_.AudioFile == au_name_].index[0]]['Tags']
      training_marker_ = df_pre_train_.loc[i]['Tags']
      ohe_marker_ = lambda training_marker_: [1, 0] if training_marker_ == 0 else [0, 1]

#      print(f'\n<<<<< [{tr_block_[0]}-{tr_block_[1]}]=> {name_list_[data_number_]}: № {a_files_count_} -> {au_name_} >>>>>')
#      print(f'      Длина записи: {au_len_}; Маркер выборки: {training_marker_}; Длина нарезки: {audio_slicing_size}; Число нарезок: {round(au_len_//audio_slicing_size)}')
      print(f'[{tr_block_[0]}-{tr_block_[1]}]=> {name_list_[data_number_]}: № {a_files_count_} -> Длина записи: {au_len_}; Маркер выборки: {training_marker_}; Число нарезок: {round(au_len_//audio_slicing_size)}',
            end='\n')

      counter = 0 # Счетчик обработанных аудиоданных
      pos = 0 # Указатель на начало вырезки аудио

      while (pos + audio_slicing_size < len(y)):  # Пробегаем по файлу
        counter+=1
        if counter % 10 != 0: # ~ 80% - 90% режем в обучение
          if counter % 12 == 0: # Отстегнём в тестовую выборку из обучающей
            X_test1.append(y[pos: pos + audio_slicing_size]) # Вырезаем часть размером нарезки и добавляем в тестовую выборку
            Y_test1.append(ohe_marker_(training_marker_)) # Соответствующий маркер в Ytest
          else:
            X_train1.append(y[pos: pos + audio_slicing_size]) # Вырезаем часть размером нарезки и добавляем в обучающую выборку
            Y_train1.append(ohe_marker_(training_marker_)) # Соответствующий маркер в YTrain
            if training_marker_ == 0:
              X_Marker_0 += 1
            else:
              X_Marker_1 += 1
        else: # В валидационную выборку
          X_train1V.append(y[pos: pos + audio_slicing_size]) #  Вырезаем часть размером нарезки и добавляем в валидационную выборку
          Y_train1V.append(ohe_marker_(training_marker_)) # Маркер для проверки
          if training_marker_ == 0:
            XV_Marker_0 += 1
          else:
            XV_Marker_1 += 1
        pos += audio_slicing_size // CUTTING_PART_TRAIN # Шаг сдвига нарезки

  #    print(f'len(X_train1) = {len(X_train1)}')
  #    print(f'len(Y_train1) = {len(Y_train1)}')
  #    print(f'len(X_train1V) = {len(X_train1V)}')
  #    print(f'len(Y_train1V) = {len(Y_train1V)}')
  #    print(f'len(X_test1) = {len(X_test1)}')
  #    print(f'len(Y_test1) = {len(Y_test1)}')
  #    print(f'Время обработки файла: {round((time.time()-start_time)/60, 2)} минут')
      # print(f'Ообработано аудиофайлов: {a_files_count_}')

  #  print('Сохраняем...')

  #  with open(DUMP+'/X_train1_'+blk_+'.pkl', 'wb') as pickle_out:
  #    pkl.dump(X_train1, pickle_out)
  #  with open(DUMP+'/Y_train1_'+blk_+'.pkl', 'wb') as pickle_out:
  #    pkl.dump(Y_train1, pickle_out)
  #  with open(DUMP+'/X_train1V_'+blk_+'.pkl', 'wb') as pickle_out:
  #    pkl.dump(X_train1V, pickle_out)
  #  with open(DUMP+'/Y_train1V_'+blk_+'.pkl', 'wb') as pickle_out:
  #    pkl.dump(Y_train1V, pickle_out)
    with open(DUMP+'/X_test1_'+blk_+'.pkl', 'wb') as pickle_out:
      pkl.dump(X_test1, pickle_out)
    with open(DUMP+'/Y_test1_'+blk_+'.pkl', 'wb') as pickle_out:
      pkl.dump(Y_test1, pickle_out)

    del X_test1
    del Y_test1

    ##########################3
  #  print('Переводим в numpy...')
    X_train1 = np.array(X_train1)
    Y_train1 = np.array(Y_train1)

    X_train1V = np.array(X_train1V)
    Y_train1V = np.array(Y_train1V)

  #  X_test1 = np.array(X_test1)
  #  Y_test1 = np.array(Y_test1)

  #  print('Перемешиваем...')
    X_train1, Y_train1 = shuffle(X_train1, Y_train1)

  #  print('Добавляем измерение для свёртки...')
    X_train1 = np.expand_dims(X_train1, axis=2)
    X_train1V = np.expand_dims(X_train1V, axis=2)

#    if 'model_au' not in locals(): # Если вошли в начале цикла обучения, - создание и компиляция модели
#     model_au = create_compile_model()
  #  else: # Читаем сохранённую модель с диска
  #   model_au = load_model(DUMP + '/model_au.h5')

    if 'model_au' not in locals():
      model_au = load_model(DUMP + '/model_au.h5')

    print("\nXTrain1.shape: ", X_train1.shape)
    print("YTrain1.shape: ", Y_train1.shape)
    print("XTrain1V.shape: ", X_train1V.shape)
    print("YTrain1V.shape: ", Y_train1V.shape)

    print(f'Обучающая выборка X_Train1 - Целевых: {X_Marker_1}; Нецелевых: {X_Marker_0}')
    print(f'Валидационная выборка X_Train1V - Целевых: {XV_Marker_1}; Нецелевых: {XV_Marker_0}')

    # Обучаем
    trainModel(model_au, X_train1, Y_train1, X_train1V, Y_train1V, batch_size=32, epochs=20)
    # Сохраняем
    model_au.save(DUMP + '/model_au.h5')

    del X_train1
    del Y_train1
    del X_train1V
    del Y_train1V

    print(f'Завершён блок {blk_} - {tr_block_number_}-й из {tr_block_count_} ')

  print('Завершено обучение всех запущенных блоков.')

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [1650_1700] - 1-й из 50
# [1650-1700]=> Paveletskaya_turbo: № 1 -> Длина записи: 1457327; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 2 -> Длина записи: 4548143; Маркер выборки: 1; Число нарезок: 33
# [1650-1700]=> Paveletskaya_turbo: № 3 -> Длина записи: 275951; Маркер выборки: 0; Число нарезок: 2
# [1650-1700]=> Headliner: № 4 -> Длина записи: 5041775; Маркер выборки: 1; Число нарезок: 36
# [1650-1700]=> Paveletskaya_turbo: № 5 -> Длина записи: 5372399; Маркер выборки: 0; Число нарезок: 38
# [1650-1700]=> Headliner: № 6 -> Длина записи: 855407; Маркер выборки: 1; Число нарезок: 6
# [1650-1700]=> Paveletskaya_turbo: № 7 -> Длина записи: 77231; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 8 -> Длина записи: 2176751; Маркер выборки: 1; Число нарезок: 15
# [1650-1700]=> Paveletskaya_turbo: № 9 -> Длина записи: 3480815; Маркер выборки: 0; Число нарезок: 25
# [1650-1700]=> Headliner: № 10 -> Длина записи: 1000559; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 11 -> Длина записи: 2321903; Маркер выборки: 0; Число нарезок: 16
# [1650-1700]=> Headliner: № 12 -> Длина записи: 6173615; Маркер выборки: 1; Число нарезок: 44
# [1650-1700]=> Paveletskaya_turbo: № 13 -> Длина записи: 8614127; Маркер выборки: 0; Число нарезок: 62
# [1650-1700]=> Headliner: № 14 -> Длина записи: 387695; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 15 -> Длина записи: 1590959; Маркер выборки: 0; Число нарезок: 11
# [1650-1700]=> Headliner: № 16 -> Длина записи: 4474991; Маркер выборки: 1; Число нарезок: 32
# [1650-1700]=> Paveletskaya_turbo: № 17 -> Длина записи: 5116655; Маркер выборки: 0; Число нарезок: 37
# [1650-1700]=> Headliner: № 18 -> Длина записи: 4052207; Маркер выборки: 1; Число нарезок: 29
# [1650-1700]=> Paveletskaya_turbo: № 19 -> Длина записи: 960815; Маркер выборки: 0; Число нарезок: 6
# [1650-1700]=> Headliner: № 20 -> Длина записи: 1791407; Маркер выборки: 1; Число нарезок: 13
# [1650-1700]=> Paveletskaya_turbo: № 21 -> Длина записи: 1483247; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 22 -> Длина записи: 2287343; Маркер выборки: 1; Число нарезок: 16
# [1650-1700]=> Paveletskaya_turbo: № 23 -> Длина записи: 986159; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 24 -> Длина записи: 831791; Маркер выборки: 1; Число нарезок: 6
# [1650-1700]=> Paveletskaya_turbo: № 25 -> Длина записи: 623279; Маркер выборки: 0; Число нарезок: 4
# [1650-1700]=> Headliner: № 26 -> Длина записи: 1013231; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 27 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 28 -> Длина записи: 432623; Маркер выборки: 1; Число нарезок: 3
# [1650-1700]=> Paveletskaya_turbo: № 29 -> Длина записи: 1023599; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 30 -> Длина записи: 13436975; Маркер выборки: 1; Число нарезок: 97
# [1650-1700]=> Paveletskaya_turbo: № 31 -> Длина записи: 1420463; Маркер выборки: 0; Число нарезок: 10
# [1650-1700]=> Headliner: № 32 -> Длина записи: 2166383; Маркер выборки: 1; Число нарезок: 15
# [1650-1700]=> Paveletskaya_turbo: № 33 -> Длина записи: 550703; Маркер выборки: 0; Число нарезок: 3
# [1650-1700]=> Headliner: № 34 -> Длина записи: 293807; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 35 -> Длина записи: 59951; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 36 -> Длина записи: 357167; Маркер выборки: 1; Число нарезок: 2
# [1650-1700]=> Paveletskaya_turbo: № 37 -> Длина записи: 119279; Маркер выборки: 0; Число нарезок: 0
# [1650-1700]=> Headliner: № 38 -> Длина записи: 2037359; Маркер выборки: 1; Число нарезок: 14
# [1650-1700]=> Paveletskaya_turbo: № 39 -> Длина записи: 141167; Маркер выборки: 0; Число нарезок: 1
# [1650-1700]=> Headliner: № 40 -> Длина записи: 2960111; Маркер выборки: 1; Число нарезок: 21
# [1650-1700]=> Paveletskaya_turbo: № 41 -> Длина записи: 2031599; Маркер выборки: 0; Число нарезок: 14
# [1650-1700]=> Headliner: № 42 -> Длина записи: 1013807; Маркер выборки: 1; Число нарезок: 7
# [1650-1700]=> Paveletskaya_turbo: № 43 -> Длина записи: 308783; Маркер выборки: 0; Число нарезок: 2
# [1650-1700]=> Headliner: № 44 -> Длина записи: 153263; Маркер выборки: 1; Число нарезок: 1
# [1650-1700]=> Paveletskaya_turbo: № 45 -> Длина записи: 1089263; Маркер выборки: 0; Число нарезок: 7
# [1650-1700]=> Headliner: № 46 -> Длина записи: 2544815; Маркер выборки: 1; Число нарезок: 18
# [1650-1700]=> Paveletskaya_turbo: № 47 -> Длина записи: 3264815; Маркер выборки: 0; Число нарезок: 23
# [1650-1700]=> Headliner: № 48 -> Длина записи: 2482607; Маркер выборки: 1; Число нарезок: 18
# [1650-1700]=> Paveletskaya_turbo: № 49 -> Длина записи: 5673071; Маркер выборки: 0; Число нарезок: 41
# [1650-1700]=> Headliner: № 50 -> Длина записи: 1343855; Маркер выборки: 1; Число нарезок: 9
#
# XTrain1.shape:  (1443, 137781, 1)
# YTrain1.shape:  (1443, 2)
# XTrain1V.shape:  (151, 137781, 1)
# YTrain1V.shape:  (151, 2)
# Обучающая выборка X_Train1 - Целевых: 827; Нецелевых: 616
# Валидационная выборка X_Train1V - Целевых: 86; Нецелевых: 65
# Epoch 1/20
# 46/46 [==============================] - 31s 317ms/step - loss: 0.4129 - accuracy: 0.8739 - val_loss: 0.8848 - val_accuracy: 0.8411
# Epoch 2/20
# 46/46 [==============================] - 13s 273ms/step - loss: 0.2917 - accuracy: 0.9134 - val_loss: 0.2420 - val_accuracy: 0.9007
# Epoch 3/20
# 46/46 [==============================] - 13s 280ms/step - loss: 0.1755 - accuracy: 0.9349 - val_loss: 180.4207 - val_accuracy: 0.5762
# Epoch 4/20
# 46/46 [==============================] - 13s 282ms/step - loss: 0.1503 - accuracy: 0.9473 - val_loss: 2.7118 - val_accuracy: 0.6954
# Epoch 5/20
# 46/46 [==============================] - 13s 287ms/step - loss: 0.3280 - accuracy: 0.8753 - val_loss: 50.0003 - val_accuracy: 0.5762
# Epoch 6/20
# 46/46 [==============================] - 13s 285ms/step - loss: 0.2261 - accuracy: 0.9155 - val_loss: 18.9211 - val_accuracy: 0.6093
# Epoch 7/20
# 46/46 [==============================] - 13s 293ms/step - loss: 0.1661 - accuracy: 0.9383 - val_loss: 0.1849 - val_accuracy: 0.9272
# Epoch 8/20
# 46/46 [==============================] - 14s 298ms/step - loss: 0.3893 - accuracy: 0.8531 - val_loss: 7021.3916 - val_accuracy: 0.5762
# Epoch 9/20
# 46/46 [==============================] - 14s 297ms/step - loss: 0.5617 - accuracy: 0.7436 - val_loss: 1.8963 - val_accuracy: 0.6623
# Epoch 10/20
# 46/46 [==============================] - 14s 294ms/step - loss: 0.3488 - accuracy: 0.8531 - val_loss: 58.3385 - val_accuracy: 0.4305
# Epoch 11/20
# 46/46 [==============================] - 13s 294ms/step - loss: 0.2939 - accuracy: 0.9071 - val_loss: 3.1389 - val_accuracy: 0.5894
# Epoch 12/20
# 46/46 [==============================] - 14s 294ms/step - loss: 0.4051 - accuracy: 0.8170 - val_loss: 3.9856 - val_accuracy: 0.4967
# Epoch 13/20
# 46/46 [==============================] - 13s 290ms/step - loss: 0.3380 - accuracy: 0.8697 - val_loss: 1.7014 - val_accuracy: 0.5762
# Epoch 14/20
# 46/46 [==============================] - 14s 296ms/step - loss: 0.2635 - accuracy: 0.8863 - val_loss: 4.5365 - val_accuracy: 0.5762
# Epoch 15/20
# 46/46 [==============================] - 13s 293ms/step - loss: 0.2332 - accuracy: 0.9127 - val_loss: 0.6438 - val_accuracy: 0.7086
# Epoch 16/20
# 46/46 [==============================] - 13s 291ms/step - loss: 0.2055 - accuracy: 0.9058 - val_loss: 1.1304 - val_accuracy: 0.8411
# Epoch 17/20
# 46/46 [==============================] - 13s 291ms/step - loss: 0.2523 - accuracy: 0.8974 - val_loss: 0.7226 - val_accuracy: 0.8212
# Epoch 18/20
# 46/46 [==============================] - 13s 291ms/step - loss: 0.2006 - accuracy: 0.9335 - val_loss: 433.1535 - val_accuracy: 0.5828
# Epoch 19/20
# 46/46 [==============================] - 13s 291ms/step - loss: 0.1737 - accuracy: 0.9099 - val_loss: 1.0266 - val_accuracy: 0.8543
# Epoch 20/20
# 46/46 [==============================] - 14s 296ms/step - loss: 0.1132 - accuracy: 0.9626 - val_loss: 1.7562 - val_accuracy: 0.8013
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [1650_1700] - 1-й из 50
#
# Запущен блок [1700_1750] - 2-й из 50
# [1700-1750]=> Paveletskaya_turbo: № 51 -> Длина записи: 121007; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Headliner: № 52 -> Длина записи: 5929391; Маркер выборки: 1; Число нарезок: 43
# [1700-1750]=> Paveletskaya_turbo: № 53 -> Длина записи: 158447; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Headliner: № 54 -> Длина записи: 2566703; Маркер выборки: 1; Число нарезок: 18
# [1700-1750]=> Paveletskaya_turbo: № 55 -> Длина записи: 1812719; Маркер выборки: 0; Число нарезок: 13
# [1700-1750]=> Headliner: № 56 -> Длина записи: 1709615; Маркер выборки: 1; Число нарезок: 12
# [1700-1750]=> Paveletskaya_turbo: № 57 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Headliner: № 58 -> Длина записи: 3687023; Маркер выборки: 1; Число нарезок: 26
# [1700-1750]=> Paveletskaya_turbo: № 59 -> Длина записи: 142319; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Headliner: № 60 -> Длина записи: 1600751; Маркер выборки: 1; Число нарезок: 11
# [1700-1750]=> Paveletskaya_turbo: № 61 -> Длина записи: 553583; Маркер выборки: 0; Число нарезок: 4
# [1700-1750]=> Headliner: № 62 -> Длина записи: 337583; Маркер выборки: 1; Число нарезок: 2
# [1700-1750]=> Paveletskaya_turbo: № 63 -> Длина записи: 212591; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Headliner: № 64 -> Длина записи: 717743; Маркер выборки: 1; Число нарезок: 5
# [1700-1750]=> Paveletskaya_turbo: № 65 -> Длина записи: 4000943; Маркер выборки: 0; Число нарезок: 29
# [1700-1750]=> Headliner: № 66 -> Длина записи: 849647; Маркер выборки: 1; Число нарезок: 6
# [1700-1750]=> Paveletskaya_turbo: № 67 -> Длина записи: 57647; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Headliner: № 68 -> Длина записи: 3202031; Маркер выборки: 1; Число нарезок: 23
# [1700-1750]=> Paveletskaya_turbo: № 69 -> Длина записи: 1604783; Маркер выборки: 0; Число нарезок: 11
# [1700-1750]=> Paveletskaya_city: № 70 -> Длина записи: 258095; Маркер выборки: 1; Число нарезок: 1
# [1700-1750]=> Paveletskaya_turbo: № 71 -> Длина записи: 13871; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Paveletskaya_city: № 72 -> Длина записи: 3422639; Маркер выборки: 1; Число нарезок: 24
# [1700-1750]=> Paveletskaya_turbo: № 73 -> Длина записи: 1373807; Маркер выборки: 0; Число нарезок: 9
# [1700-1750]=> Paveletskaya_city: № 74 -> Длина записи: 20248751; Маркер выборки: 1; Число нарезок: 146
# [1700-1750]=> Paveletskaya_turbo: № 75 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 76 -> Длина записи: 380783; Маркер выборки: 1; Число нарезок: 2
# [1700-1750]=> Paveletskaya_turbo: № 77 -> Длина записи: 49583; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Paveletskaya_city: № 78 -> Длина записи: 1726319; Маркер выборки: 1; Число нарезок: 12
# [1700-1750]=> Paveletskaya_turbo: № 79 -> Длина записи: 210287; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 80 -> Длина записи: 3661103; Маркер выборки: 1; Число нарезок: 26
# [1700-1750]=> Paveletskaya_turbo: № 81 -> Длина записи: 196463; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 82 -> Длина записи: 262703; Маркер выборки: 1; Число нарезок: 1
# [1700-1750]=> Paveletskaya_turbo: № 83 -> Длина записи: 237359; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 84 -> Длина записи: 2358767; Маркер выборки: 1; Число нарезок: 17
# [1700-1750]=> Paveletskaya_turbo: № 85 -> Длина записи: 1916399; Маркер выборки: 0; Число нарезок: 13
# [1700-1750]=> Paveletskaya_city: № 86 -> Длина записи: 7216751; Маркер выборки: 1; Число нарезок: 52
# [1700-1750]=> Paveletskaya_turbo: № 87 -> Длина записи: 1785071; Маркер выборки: 0; Число нарезок: 12
# [1700-1750]=> Paveletskaya_city: № 88 -> Длина записи: 2867951; Маркер выборки: 1; Число нарезок: 20
# [1700-1750]=> Paveletskaya_turbo: № 89 -> Длина записи: 23087; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Paveletskaya_city: № 90 -> Длина записи: 2006831; Маркер выборки: 1; Число нарезок: 14
# [1700-1750]=> Paveletskaya_turbo: № 91 -> Длина записи: 2041967; Маркер выборки: 0; Число нарезок: 14
# [1700-1750]=> Paveletskaya_city: № 92 -> Длина записи: 978671; Маркер выборки: 1; Число нарезок: 7
# [1700-1750]=> Paveletskaya_turbo: № 93 -> Длина записи: 63983; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Paveletskaya_city: № 94 -> Длина записи: 4685807; Маркер выборки: 1; Число нарезок: 34
# [1700-1750]=> Paveletskaya_turbo: № 95 -> Длина записи: 92783; Маркер выборки: 0; Число нарезок: 0
# [1700-1750]=> Paveletskaya_city: № 96 -> Длина записи: 3199151; Маркер выборки: 1; Число нарезок: 23
# [1700-1750]=> Paveletskaya_turbo: № 97 -> Длина записи: 179183; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 98 -> Длина записи: 3101231; Маркер выборки: 1; Число нарезок: 22
# [1700-1750]=> Paveletskaya_turbo: № 99 -> Длина записи: 182639; Маркер выборки: 0; Число нарезок: 1
# [1700-1750]=> Paveletskaya_city: № 100 -> Длина записи: 5698415; Маркер выборки: 1; Число нарезок: 41
#
# XTrain1.shape:  (1279, 137781, 1)
# YTrain1.shape:  (1279, 2)
# XTrain1V.shape:  (133, 137781, 1)
# YTrain1V.shape:  (133, 2)
# Обучающая выборка X_Train1 - Целевых: 1901; Нецелевых: 821
# Валидационная выборка X_Train1V - Целевых: 201; Нецелевых: 83
# Epoch 1/20
# 40/40 [==============================] - 15s 366ms/step - loss: 0.7688 - accuracy: 0.8225 - val_loss: 0.3359 - val_accuracy: 0.8647
# Epoch 2/20
# 40/40 [==============================] - 12s 311ms/step - loss: 0.3935 - accuracy: 0.8397 - val_loss: 0.3994 - val_accuracy: 0.8647
# Epoch 3/20
# 40/40 [==============================] - 12s 309ms/step - loss: 0.3759 - accuracy: 0.8397 - val_loss: 0.6014 - val_accuracy: 0.8647
# Epoch 4/20
# 40/40 [==============================] - 12s 298ms/step - loss: 0.3570 - accuracy: 0.8397 - val_loss: 2.3861 - val_accuracy: 0.8647
# Epoch 5/20
# 40/40 [==============================] - 12s 301ms/step - loss: 0.3254 - accuracy: 0.8382 - val_loss: 0.4191 - val_accuracy: 0.8647
# Epoch 6/20
# 40/40 [==============================] - 12s 302ms/step - loss: 0.3607 - accuracy: 0.8460 - val_loss: 0.4204 - val_accuracy: 0.8647
# Epoch 7/20
# 40/40 [==============================] - 12s 302ms/step - loss: 0.3175 - accuracy: 0.8397 - val_loss: 0.2555 - val_accuracy: 0.8647
# Epoch 8/20
# 40/40 [==============================] - 12s 298ms/step - loss: 0.2939 - accuracy: 0.8397 - val_loss: 3.1278 - val_accuracy: 0.8647
# Epoch 9/20
# 40/40 [==============================] - 12s 299ms/step - loss: 0.2843 - accuracy: 0.8397 - val_loss: 1.5891 - val_accuracy: 0.8647
# Epoch 10/20
# 40/40 [==============================] - 12s 305ms/step - loss: 0.3138 - accuracy: 0.8397 - val_loss: 33.6456 - val_accuracy: 0.8647
# Epoch 11/20
# 40/40 [==============================] - 12s 305ms/step - loss: 0.3389 - accuracy: 0.8397 - val_loss: 1.2746 - val_accuracy: 0.8647
# Epoch 12/20
# 40/40 [==============================] - 12s 303ms/step - loss: 0.2723 - accuracy: 0.8389 - val_loss: 0.2247 - val_accuracy: 0.8647
# Epoch 13/20
# 40/40 [==============================] - 12s 303ms/step - loss: 0.3136 - accuracy: 0.8397 - val_loss: 0.4267 - val_accuracy: 0.8647
# Epoch 14/20
# 40/40 [==============================] - 12s 303ms/step - loss: 0.3377 - accuracy: 0.8389 - val_loss: 0.7830 - val_accuracy: 0.8647
# Epoch 15/20
# 40/40 [==============================] - 12s 303ms/step - loss: 0.3125 - accuracy: 0.8452 - val_loss: 7.4410 - val_accuracy: 0.8797
# Epoch 16/20
# 40/40 [==============================] - 12s 304ms/step - loss: 0.2597 - accuracy: 0.8397 - val_loss: 5.6389 - val_accuracy: 0.8722
# Epoch 17/20
# 40/40 [==============================] - 12s 304ms/step - loss: 0.2820 - accuracy: 0.8397 - val_loss: 0.5227 - val_accuracy: 0.8647
# Epoch 18/20
# 40/40 [==============================] - 12s 298ms/step - loss: 0.2655 - accuracy: 0.8522 - val_loss: 0.4094 - val_accuracy: 0.8647
# Epoch 19/20
# 40/40 [==============================] - 12s 304ms/step - loss: 0.2616 - accuracy: 0.8538 - val_loss: 42.5029 - val_accuracy: 0.8647
# Epoch 20/20
# 40/40 [==============================] - 12s 303ms/step - loss: 0.2800 - accuracy: 0.8413 - val_loss: 0.5573 - val_accuracy: 0.8647
# Завершён блок [1700_1750] - 2-й из 50
#
# Запущен блок [1750_1800] - 3-й из 50
# [1750-1800]=> Paveletskaya_turbo: № 101 -> Длина записи: 183215; Маркер выборки: 0; Число нарезок: 1
# [1750-1800]=> Paveletskaya_city: № 102 -> Длина записи: 5290607; Маркер выборки: 1; Число нарезок: 38
# [1750-1800]=> Paveletskaya_turbo: № 103 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 104 -> Длина записи: 5114351; Маркер выборки: 1; Число нарезок: 37
# [1750-1800]=> Paveletskaya_turbo: № 105 -> Длина записи: 1061039; Маркер выборки: 0; Число нарезок: 7
# [1750-1800]=> Paveletskaya_city: № 106 -> Длина записи: 3666287; Маркер выборки: 1; Число нарезок: 26
# [1750-1800]=> Paveletskaya_turbo: № 107 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 108 -> Длина записи: 3981935; Маркер выборки: 1; Число нарезок: 28
# [1750-1800]=> Paveletskaya_turbo: № 109 -> Длина записи: 1226927; Маркер выборки: 0; Число нарезок: 8
# [1750-1800]=> Paveletskaya_city: № 110 -> Длина записи: 4254383; Маркер выборки: 1; Число нарезок: 30
# [1750-1800]=> Paveletskaya_turbo: № 111 -> Длина записи: 243119; Маркер выборки: 0; Число нарезок: 1
# [1750-1800]=> Paveletskaya_city: № 112 -> Длина записи: 5497967; Маркер выборки: 1; Число нарезок: 39
# [1750-1800]=> Paveletskaya_turbo: № 113 -> Длина записи: 33455; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 114 -> Длина записи: 2675567; Маркер выборки: 1; Число нарезок: 19
# [1750-1800]=> Paveletskaya_turbo: № 115 -> Длина записи: 133679; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 116 -> Длина записи: 1168751; Маркер выборки: 1; Число нарезок: 8
# [1750-1800]=> Paveletskaya_turbo: № 117 -> Длина записи: 129071; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 118 -> Длина записи: 3616175; Маркер выборки: 1; Число нарезок: 26
# [1750-1800]=> Paveletskaya_turbo: № 119 -> Длина записи: 679727; Маркер выборки: 0; Число нарезок: 4
# [1750-1800]=> Paveletskaya_city: № 120 -> Длина записи: 1761455; Маркер выборки: 1; Число нарезок: 12
# [1750-1800]=> Paveletskaya_turbo: № 121 -> Длина записи: 2279855; Маркер выборки: 0; Число нарезок: 16
# [1750-1800]=> Paveletskaya_city: № 122 -> Длина записи: 4442159; Маркер выборки: 1; Число нарезок: 32
# [1750-1800]=> Paveletskaya_turbo: № 123 -> Длина записи: 5391407; Маркер выборки: 0; Число нарезок: 39
# [1750-1800]=> Paveletskaya_city: № 124 -> Длина записи: 8177519; Маркер выборки: 1; Число нарезок: 59
# [1750-1800]=> Paveletskaya_turbo: № 125 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 126 -> Длина записи: 2968751; Маркер выборки: 1; Число нарезок: 21
# [1750-1800]=> Paveletskaya_turbo: № 127 -> Длина записи: 719471; Маркер выборки: 0; Число нарезок: 5
# [1750-1800]=> Paveletskaya_city: № 128 -> Длина записи: 3557999; Маркер выборки: 1; Число нарезок: 25
# [1750-1800]=> Paveletskaya_turbo: № 129 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 130 -> Длина записи: 2187119; Маркер выборки: 1; Число нарезок: 15
# [1750-1800]=> Paveletskaya_turbo: № 131 -> Длина записи: 28847; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 132 -> Длина записи: 4580399; Маркер выборки: 1; Число нарезок: 33
# [1750-1800]=> Paveletskaya_turbo: № 133 -> Длина записи: 4825199; Маркер выборки: 0; Число нарезок: 35
# [1750-1800]=> Paveletskaya_city: № 134 -> Длина записи: 2633519; Маркер выборки: 1; Число нарезок: 19
# [1750-1800]=> Paveletskaya_turbo: № 135 -> Длина записи: 11396783; Маркер выборки: 0; Число нарезок: 82
# [1750-1800]=> Paveletskaya_city: № 136 -> Длина записи: 2403695; Маркер выборки: 1; Число нарезок: 17
# [1750-1800]=> Paveletskaya_turbo: № 137 -> Длина записи: 2966447; Маркер выборки: 0; Число нарезок: 21
# [1750-1800]=> Paveletskaya_city: № 138 -> Длина записи: 2029295; Маркер выборки: 1; Число нарезок: 14
# [1750-1800]=> Paveletskaya_turbo: № 139 -> Длина записи: 1991855; Маркер выборки: 0; Число нарезок: 14
# [1750-1800]=> Paveletskaya_city: № 140 -> Длина записи: 1694063; Маркер выборки: 1; Число нарезок: 12
# [1750-1800]=> Paveletskaya_turbo: № 141 -> Длина записи: 3460655; Маркер выборки: 0; Число нарезок: 25
# [1750-1800]=> Paveletskaya_city: № 142 -> Длина записи: 1764911; Маркер выборки: 1; Число нарезок: 12
# [1750-1800]=> Paveletskaya_turbo: № 143 -> Длина записи: 952175; Маркер выборки: 0; Число нарезок: 6
# [1750-1800]=> Paveletskaya_city: № 144 -> Длина записи: 2004527; Маркер выборки: 1; Число нарезок: 14
# [1750-1800]=> Paveletskaya_turbo: № 145 -> Длина записи: 26543; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 146 -> Длина записи: 1266671; Маркер выборки: 1; Число нарезок: 9
# [1750-1800]=> Paveletskaya_turbo: № 147 -> Длина записи: 68591; Маркер выборки: 0; Число нарезок: 0
# [1750-1800]=> Paveletskaya_city: № 148 -> Длина записи: 323183; Маркер выборки: 1; Число нарезок: 2
# [1750-1800]=> Paveletskaya_turbo: № 149 -> Длина записи: 1797167; Маркер выборки: 0; Число нарезок: 13
# [1750-1800]=> Paveletskaya_city: № 150 -> Длина записи: 3366191; Маркер выборки: 1; Число нарезок: 24
#
# XTrain1.shape:  (1553, 137781, 1)
# YTrain1.shape:  (1553, 2)
# XTrain1V.shape:  (165, 137781, 1)
# YTrain1V.shape:  (165, 2)
# Обучающая выборка X_Train1 - Целевых: 2946; Нецелевых: 1329
# Валидационная выборка X_Train1V - Целевых: 314; Нецелевых: 135
# Epoch 1/20
# 49/49 [==============================] - 16s 329ms/step - loss: 0.7198 - accuracy: 0.6607 - val_loss: 81.5562 - val_accuracy: 0.7091
# Epoch 2/20
# 49/49 [==============================] - 15s 306ms/step - loss: 0.4831 - accuracy: 0.6729 - val_loss: 0.5087 - val_accuracy: 0.6848
# Epoch 3/20
# 49/49 [==============================] - 15s 303ms/step - loss: 0.4956 - accuracy: 0.6735 - val_loss: 0.3736 - val_accuracy: 0.6848
# Epoch 4/20
# 49/49 [==============================] - 15s 298ms/step - loss: 0.4600 - accuracy: 0.6845 - val_loss: 0.3558 - val_accuracy: 0.8242
# Epoch 5/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.4374 - accuracy: 0.7263 - val_loss: 0.4610 - val_accuracy: 0.8606
# Epoch 6/20
# 49/49 [==============================] - 14s 295ms/step - loss: 0.4576 - accuracy: 0.7070 - val_loss: 1.6178 - val_accuracy: 0.7152
# Epoch 7/20
# 49/49 [==============================] - 15s 300ms/step - loss: 0.4646 - accuracy: 0.7038 - val_loss: 44.0204 - val_accuracy: 0.7333
# Epoch 8/20
# 49/49 [==============================] - 15s 297ms/step - loss: 0.4311 - accuracy: 0.7366 - val_loss: 0.6093 - val_accuracy: 0.8242
# Epoch 9/20
# 49/49 [==============================] - 15s 301ms/step - loss: 0.4404 - accuracy: 0.7263 - val_loss: 24.0942 - val_accuracy: 0.8970
# Epoch 10/20
# 49/49 [==============================] - 15s 296ms/step - loss: 0.4160 - accuracy: 0.7489 - val_loss: 0.7139 - val_accuracy: 0.8121
# Epoch 11/20
# 49/49 [==============================] - 14s 296ms/step - loss: 0.4149 - accuracy: 0.7553 - val_loss: 0.2227 - val_accuracy: 0.9697
# Epoch 12/20
# 49/49 [==============================] - 15s 297ms/step - loss: 0.4429 - accuracy: 0.7077 - val_loss: 0.7684 - val_accuracy: 0.5636
# Epoch 13/20
# 49/49 [==============================] - 14s 295ms/step - loss: 0.4243 - accuracy: 0.7276 - val_loss: 0.5849 - val_accuracy: 0.8364
# Epoch 14/20
# 49/49 [==============================] - 15s 298ms/step - loss: 0.4435 - accuracy: 0.7167 - val_loss: 1.1370 - val_accuracy: 0.8424
# Epoch 15/20
# 49/49 [==============================] - 15s 300ms/step - loss: 0.4279 - accuracy: 0.7334 - val_loss: 0.3840 - val_accuracy: 0.8848
# Epoch 16/20
# 49/49 [==============================] - 15s 296ms/step - loss: 0.4216 - accuracy: 0.7399 - val_loss: 0.2307 - val_accuracy: 0.9455
# Epoch 17/20
# 49/49 [==============================] - 14s 296ms/step - loss: 0.4185 - accuracy: 0.7418 - val_loss: 0.3044 - val_accuracy: 0.9212
# Epoch 18/20
# 49/49 [==============================] - 14s 296ms/step - loss: 0.4098 - accuracy: 0.7547 - val_loss: 5.3203 - val_accuracy: 0.8000
# Epoch 19/20
# 49/49 [==============================] - 15s 298ms/step - loss: 0.3939 - accuracy: 0.7618 - val_loss: 5.4543 - val_accuracy: 0.7879
# Epoch 20/20
# 49/49 [==============================] - 15s 298ms/step - loss: 0.3942 - accuracy: 0.7798 - val_loss: 0.3169 - val_accuracy: 0.8970
# Завершён блок [1750_1800] - 3-й из 50
#
# Запущен блок [1800_1850] - 4-й из 50
# [1800-1850]=> Paveletskaya_turbo: № 151 -> Длина записи: 217199; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 152 -> Длина записи: 2408303; Маркер выборки: 1; Число нарезок: 17
# [1800-1850]=> Paveletskaya_turbo: № 153 -> Длина записи: 284591; Маркер выборки: 0; Число нарезок: 2
# [1800-1850]=> Paveletskaya_city: № 154 -> Длина записи: 3388655; Маркер выборки: 1; Число нарезок: 24
# [1800-1850]=> Paveletskaya_turbo: № 155 -> Длина записи: 3352943; Маркер выборки: 0; Число нарезок: 24
# [1800-1850]=> Paveletskaya_city: № 156 -> Длина записи: 3702575; Маркер выборки: 1; Число нарезок: 26
# [1800-1850]=> Paveletskaya_turbo: № 157 -> Длина записи: 2761391; Маркер выборки: 0; Число нарезок: 20
# [1800-1850]=> Paveletskaya_city: № 158 -> Длина записи: 5774447; Маркер выборки: 1; Число нарезок: 41
# [1800-1850]=> Paveletskaya_turbo: № 159 -> Длина записи: 207407; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 160 -> Длина записи: 403823; Маркер выборки: 1; Число нарезок: 2
# [1800-1850]=> Paveletskaya_turbo: № 161 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 162 -> Длина записи: 1930799; Маркер выборки: 1; Число нарезок: 14
# [1800-1850]=> Paveletskaya_turbo: № 163 -> Длина записи: 42671; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 164 -> Длина записи: 404399; Маркер выборки: 1; Число нарезок: 2
# [1800-1850]=> Paveletskaya_turbo: № 165 -> Длина записи: 858863; Маркер выборки: 0; Число нарезок: 6
# [1800-1850]=> Paveletskaya_city: № 166 -> Длина записи: 5877551; Маркер выборки: 1; Число нарезок: 42
# [1800-1850]=> Paveletskaya_turbo: № 167 -> Длина записи: 1096751; Маркер выборки: 0; Число нарезок: 7
# [1800-1850]=> Paveletskaya_city: № 168 -> Длина записи: 224111; Маркер выборки: 1; Число нарезок: 1
# [1800-1850]=> Paveletskaya_turbo: № 169 -> Длина записи: 66287; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 170 -> Длина записи: 231599; Маркер выборки: 1; Число нарезок: 1
# [1800-1850]=> Paveletskaya_turbo: № 171 -> Длина записи: 1369199; Маркер выборки: 0; Число нарезок: 9
# [1800-1850]=> Paveletskaya_city: № 172 -> Длина записи: 2537903; Маркер выборки: 1; Число нарезок: 18
# [1800-1850]=> Paveletskaya_turbo: № 173 -> Длина записи: 3488879; Маркер выборки: 0; Число нарезок: 25
# [1800-1850]=> Paveletskaya_city: № 174 -> Длина записи: 5266991; Маркер выборки: 1; Число нарезок: 38
# [1800-1850]=> Paveletskaya_turbo: № 175 -> Длина записи: 6102191; Маркер выборки: 0; Число нарезок: 44
# [1800-1850]=> Paveletskaya_city: № 176 -> Длина записи: 2003951; Маркер выборки: 1; Число нарезок: 14
# [1800-1850]=> Paveletskaya_turbo: № 177 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 178 -> Длина записи: 319151; Маркер выборки: 1; Число нарезок: 2
# [1800-1850]=> Paveletskaya_turbo: № 179 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 180 -> Длина записи: 3327023; Маркер выборки: 1; Число нарезок: 24
# [1800-1850]=> Paveletskaya_turbo: № 181 -> Длина записи: 264431; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 182 -> Длина записи: 5354543; Маркер выборки: 1; Число нарезок: 38
# [1800-1850]=> Paveletskaya_turbo: № 183 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 184 -> Длина записи: 3090863; Маркер выборки: 1; Число нарезок: 22
# [1800-1850]=> Paveletskaya_turbo: № 185 -> Длина записи: 108911; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 186 -> Длина записи: 1827119; Маркер выборки: 1; Число нарезок: 13
# [1800-1850]=> Paveletskaya_turbo: № 187 -> Длина записи: 245423; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 188 -> Длина записи: 6045743; Маркер выборки: 1; Число нарезок: 43
# [1800-1850]=> Paveletskaya_turbo: № 189 -> Длина записи: 430895; Маркер выборки: 0; Число нарезок: 3
# [1800-1850]=> Paveletskaya_city: № 190 -> Длина записи: 5306159; Маркер выборки: 1; Число нарезок: 38
# [1800-1850]=> Paveletskaya_turbo: № 191 -> Длина записи: 214319; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 192 -> Длина записи: 254063; Маркер выборки: 1; Число нарезок: 1
# [1800-1850]=> Paveletskaya_turbo: № 193 -> Длина записи: 329519; Маркер выборки: 0; Число нарезок: 2
# [1800-1850]=> Paveletskaya_city: № 194 -> Длина записи: 5241647; Маркер выборки: 1; Число нарезок: 38
# [1800-1850]=> Paveletskaya_turbo: № 195 -> Длина записи: 26543; Маркер выборки: 0; Число нарезок: 0
# [1800-1850]=> Paveletskaya_city: № 196 -> Длина записи: 3583343; Маркер выборки: 1; Число нарезок: 26
# [1800-1850]=> Paveletskaya_turbo: № 197 -> Длина записи: 352559; Маркер выборки: 0; Число нарезок: 2
# [1800-1850]=> Paveletskaya_city: № 198 -> Длина записи: 6406895; Маркер выборки: 1; Число нарезок: 46
# [1800-1850]=> Paveletskaya_turbo: № 199 -> Длина записи: 172847; Маркер выборки: 0; Число нарезок: 1
# [1800-1850]=> Paveletskaya_city: № 200 -> Длина записи: 2943407; Маркер выборки: 1; Число нарезок: 21
#
# XTrain1.shape:  (1282, 137781, 1)
# YTrain1.shape:  (1282, 2)
# XTrain1V.shape:  (136, 137781, 1)
# YTrain1V.shape:  (136, 2)
# Обучающая выборка X_Train1 - Целевых: 3958; Нецелевых: 1599
# Валидационная выборка X_Train1V - Целевых: 424; Нецелевых: 161
# Epoch 1/20
# 41/41 [==============================] - 13s 325ms/step - loss: 0.7830 - accuracy: 0.6505 - val_loss: 0.4556 - val_accuracy: 0.8088
# Epoch 2/20
# 41/41 [==============================] - 12s 303ms/step - loss: 0.5071 - accuracy: 0.7894 - val_loss: 0.4943 - val_accuracy: 0.8088
# Epoch 3/20
# 41/41 [==============================] - 12s 300ms/step - loss: 0.4778 - accuracy: 0.7894 - val_loss: 0.4349 - val_accuracy: 0.8088
# Epoch 4/20
# 41/41 [==============================] - 12s 295ms/step - loss: 0.4823 - accuracy: 0.7894 - val_loss: 0.4195 - val_accuracy: 0.8088
# Epoch 5/20
# 41/41 [==============================] - 12s 297ms/step - loss: 0.4660 - accuracy: 0.7894 - val_loss: 0.4265 - val_accuracy: 0.8088
# Epoch 6/20
# 41/41 [==============================] - 12s 297ms/step - loss: 0.4616 - accuracy: 0.7894 - val_loss: 0.5016 - val_accuracy: 0.8088
# Epoch 7/20
# 41/41 [==============================] - 12s 292ms/step - loss: 0.4515 - accuracy: 0.7894 - val_loss: 0.5076 - val_accuracy: 0.8088
# Epoch 8/20
# 41/41 [==============================] - 12s 292ms/step - loss: 0.4427 - accuracy: 0.7894 - val_loss: 0.3883 - val_accuracy: 0.8088
# Epoch 9/20
# 41/41 [==============================] - 12s 300ms/step - loss: 0.3822 - accuracy: 0.7894 - val_loss: 0.3360 - val_accuracy: 0.8088
# Epoch 10/20
# 41/41 [==============================] - 12s 301ms/step - loss: 0.4308 - accuracy: 0.7839 - val_loss: 350.3463 - val_accuracy: 0.8088
# Epoch 11/20
# 41/41 [==============================] - 12s 299ms/step - loss: 0.4032 - accuracy: 0.7894 - val_loss: 0.4353 - val_accuracy: 0.8088
# Epoch 12/20
# 41/41 [==============================] - 12s 299ms/step - loss: 0.3620 - accuracy: 0.7871 - val_loss: 0.3214 - val_accuracy: 0.8088
# Epoch 13/20
# 41/41 [==============================] - 12s 298ms/step - loss: 0.3757 - accuracy: 0.7878 - val_loss: 0.3252 - val_accuracy: 0.8088
# Epoch 14/20
# 41/41 [==============================] - 12s 298ms/step - loss: 0.3664 - accuracy: 0.7894 - val_loss: 10467.9590 - val_accuracy: 0.8015
# Epoch 15/20
# 41/41 [==============================] - 12s 293ms/step - loss: 0.4090 - accuracy: 0.7894 - val_loss: 1285.0482 - val_accuracy: 0.8088
# Epoch 16/20
# 41/41 [==============================] - 12s 299ms/step - loss: 0.3650 - accuracy: 0.7894 - val_loss: 0.8849 - val_accuracy: 0.8088
# Epoch 17/20
# 41/41 [==============================] - 12s 293ms/step - loss: 0.3782 - accuracy: 0.7894 - val_loss: 0.5609 - val_accuracy: 0.8088
# Epoch 18/20
# 41/41 [==============================] - 12s 295ms/step - loss: 0.3437 - accuracy: 0.7894 - val_loss: 19.7287 - val_accuracy: 0.8088
# Epoch 19/20
# 41/41 [==============================] - 12s 300ms/step - loss: 0.4644 - accuracy: 0.7863 - val_loss: 83.0278 - val_accuracy: 0.7941
# Epoch 20/20
# 41/41 [==============================] - 12s 298ms/step - loss: 0.4242 - accuracy: 0.7894 - val_loss: 0.3763 - val_accuracy: 0.8088
# Завершён блок [1800_1850] - 4-й из 50
#
# Запущен блок [1850_1900] - 5-й из 50
# [1850-1900]=> Paveletskaya_turbo: № 201 -> Длина записи: 6476591; Маркер выборки: 0; Число нарезок: 47
# [1850-1900]=> Paveletskaya_city: № 202 -> Длина записи: 2100719; Маркер выборки: 1; Число нарезок: 15
# [1850-1900]=> Paveletskaya_turbo: № 203 -> Длина записи: 581807; Маркер выборки: 0; Число нарезок: 4
# [1850-1900]=> Paveletskaya_city: № 204 -> Длина записи: 5328047; Маркер выборки: 1; Число нарезок: 38
# [1850-1900]=> Paveletskaya_turbo: № 205 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 206 -> Длина записи: 3066095; Маркер выборки: 1; Число нарезок: 22
# [1850-1900]=> Paveletskaya_turbo: № 207 -> Длина записи: 3020015; Маркер выборки: 0; Число нарезок: 21
# [1850-1900]=> Paveletskaya_city: № 208 -> Длина записи: 1088687; Маркер выборки: 1; Число нарезок: 7
# [1850-1900]=> Paveletskaya_turbo: № 209 -> Длина записи: 3261359; Маркер выборки: 0; Число нарезок: 23
# [1850-1900]=> Paveletskaya_city: № 210 -> Длина записи: 2401391; Маркер выборки: 1; Число нарезок: 17
# [1850-1900]=> Paveletskaya_turbo: № 211 -> Длина записи: 6720239; Маркер выборки: 0; Число нарезок: 48
# [1850-1900]=> Paveletskaya_city: № 212 -> Длина записи: 1247663; Маркер выборки: 1; Число нарезок: 9
# [1850-1900]=> Paveletskaya_turbo: № 213 -> Длина записи: 96239; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 214 -> Длина записи: 3259631; Маркер выборки: 1; Число нарезок: 23
# [1850-1900]=> Paveletskaya_turbo: № 215 -> Длина записи: 277679; Маркер выборки: 0; Число нарезок: 2
# [1850-1900]=> Paveletskaya_city: № 216 -> Длина записи: 3104111; Маркер выборки: 1; Число нарезок: 22
# [1850-1900]=> Paveletskaya_turbo: № 217 -> Длина записи: 2545391; Маркер выборки: 0; Число нарезок: 18
# [1850-1900]=> Paveletskaya_city: № 218 -> Длина записи: 2523503; Маркер выборки: 1; Число нарезок: 18
# [1850-1900]=> Paveletskaya_turbo: № 219 -> Длина записи: 479855; Маркер выборки: 0; Число нарезок: 3
# [1850-1900]=> Paveletskaya_city: № 220 -> Длина записи: 859439; Маркер выборки: 1; Число нарезок: 6
# [1850-1900]=> Paveletskaya_turbo: № 221 -> Длина записи: 4876463; Маркер выборки: 0; Число нарезок: 35
# [1850-1900]=> Paveletskaya_city: № 222 -> Длина записи: 4756079; Маркер выборки: 1; Число нарезок: 34
# [1850-1900]=> Paveletskaya_turbo: № 223 -> Длина записи: 360047; Маркер выборки: 0; Число нарезок: 2
# [1850-1900]=> Paveletskaya_city: № 224 -> Длина записи: 2902511; Маркер выборки: 1; Число нарезок: 21
# [1850-1900]=> Paveletskaya_turbo: № 225 -> Длина записи: 136559; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 226 -> Длина записи: 2039663; Маркер выборки: 1; Число нарезок: 14
# [1850-1900]=> Paveletskaya_turbo: № 227 -> Длина записи: 6523823; Маркер выборки: 0; Число нарезок: 47
# [1850-1900]=> Paveletskaya_city: № 228 -> Длина записи: 5770415; Маркер выборки: 1; Число нарезок: 41
# [1850-1900]=> Paveletskaya_turbo: № 229 -> Длина записи: 1116911; Маркер выборки: 0; Число нарезок: 8
# [1850-1900]=> Paveletskaya_city: № 230 -> Длина записи: 6542831; Маркер выборки: 1; Число нарезок: 47
# [1850-1900]=> Paveletskaya_turbo: № 231 -> Длина записи: 362351; Маркер выборки: 0; Число нарезок: 2
# [1850-1900]=> Paveletskaya_city: № 232 -> Длина записи: 2160623; Маркер выборки: 1; Число нарезок: 15
# [1850-1900]=> Paveletskaya_turbo: № 233 -> Длина записи: 4012463; Маркер выборки: 0; Число нарезок: 29
# [1850-1900]=> Paveletskaya_city: № 234 -> Длина записи: 3602927; Маркер выборки: 1; Число нарезок: 26
# [1850-1900]=> Paveletskaya_turbo: № 235 -> Длина записи: 533423; Маркер выборки: 0; Число нарезок: 3
# [1850-1900]=> Paveletskaya_city: № 236 -> Длина записи: 4741679; Маркер выборки: 1; Число нарезок: 34
# [1850-1900]=> Paveletskaya_turbo: № 237 -> Длина записи: 510959; Маркер выборки: 0; Число нарезок: 3
# [1850-1900]=> Paveletskaya_city: № 238 -> Длина записи: 2253935; Маркер выборки: 1; Число нарезок: 16
# [1850-1900]=> Paveletskaya_turbo: № 239 -> Длина записи: 462575; Маркер выборки: 0; Число нарезок: 3
# [1850-1900]=> Paveletskaya_city: № 240 -> Длина записи: 2755055; Маркер выборки: 1; Число нарезок: 19
# [1850-1900]=> Paveletskaya_turbo: № 241 -> Длина записи: 15599; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 242 -> Длина записи: 2703791; Маркер выборки: 1; Число нарезок: 19
# [1850-1900]=> Paveletskaya_turbo: № 243 -> Длина записи: 118703; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 244 -> Длина записи: 2570159; Маркер выборки: 1; Число нарезок: 18
# [1850-1900]=> Paveletskaya_turbo: № 245 -> Длина записи: 338735; Маркер выборки: 0; Число нарезок: 2
# [1850-1900]=> Paveletskaya_city: № 246 -> Длина записи: 1735535; Маркер выборки: 1; Число нарезок: 12
# [1850-1900]=> Paveletskaya_turbo: № 247 -> Длина записи: 15023; Маркер выборки: 0; Число нарезок: 0
# [1850-1900]=> Paveletskaya_city: № 248 -> Длина записи: 5296367; Маркер выборки: 1; Число нарезок: 38
# [1850-1900]=> Paveletskaya_turbo: № 249 -> Длина записи: 654383; Маркер выборки: 0; Число нарезок: 4
# [1850-1900]=> Paveletskaya_city: № 250 -> Длина записи: 2581103; Маркер выборки: 1; Число нарезок: 18
#
# XTrain1.shape:  (1559, 137781, 1)
# YTrain1.shape:  (1559, 2)
# XTrain1V.shape:  (164, 137781, 1)
# YTrain1V.shape:  (164, 2)
# Обучающая выборка X_Train1 - Целевых: 4961; Нецелевых: 2155
# Валидационная выборка X_Train1V - Целевых: 532; Нецелевых: 217
# Epoch 1/20
# 49/49 [==============================] - 16s 316ms/step - loss: 0.7140 - accuracy: 0.6357 - val_loss: 0.6433 - val_accuracy: 0.6585
# Epoch 2/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.6516 - accuracy: 0.6434 - val_loss: 0.6422 - val_accuracy: 0.6585
# Epoch 3/20
# 49/49 [==============================] - 14s 295ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 0.6422 - val_accuracy: 0.6646
# Epoch 4/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 1.7053 - val_accuracy: 0.6646
# Epoch 5/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.6521 - accuracy: 0.6434 - val_loss: 1.0136 - val_accuracy: 0.6646
# Epoch 6/20
# 49/49 [==============================] - 14s 290ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 0.8429 - val_accuracy: 0.6646
# Epoch 7/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.6517 - accuracy: 0.6434 - val_loss: 1.0696 - val_accuracy: 0.6707
# Epoch 8/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.6522 - accuracy: 0.6434 - val_loss: 1.8480 - val_accuracy: 0.6707
# Epoch 9/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.6516 - accuracy: 0.6434 - val_loss: 2.9925 - val_accuracy: 0.6707
# Epoch 10/20
# 49/49 [==============================] - 14s 293ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 4.0189 - val_accuracy: 0.6707
# Epoch 11/20
# 49/49 [==============================] - 14s 292ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 4.3975 - val_accuracy: 0.6707
# Epoch 12/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.6528 - accuracy: 0.6434 - val_loss: 2.8128 - val_accuracy: 0.6646
# Epoch 13/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.6523 - accuracy: 0.6434 - val_loss: 19.7299 - val_accuracy: 0.6646
# Epoch 14/20
# 49/49 [==============================] - 14s 293ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 3.1111 - val_accuracy: 0.6707
# Epoch 15/20
# 49/49 [==============================] - 14s 292ms/step - loss: 0.6519 - accuracy: 0.6434 - val_loss: 4.1859 - val_accuracy: 0.6707
# Epoch 16/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.6522 - accuracy: 0.6434 - val_loss: 4.1784 - val_accuracy: 0.6707
# Epoch 17/20
# 49/49 [==============================] - 14s 290ms/step - loss: 0.6523 - accuracy: 0.6434 - val_loss: 5.8678 - val_accuracy: 0.6707
# Epoch 18/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.6520 - accuracy: 0.6434 - val_loss: 4.1725 - val_accuracy: 0.6707
# Epoch 19/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.6519 - accuracy: 0.6434 - val_loss: 4.6598 - val_accuracy: 0.6707
# Epoch 20/20
# 49/49 [==============================] - 14s 288ms/step - loss: 0.6519 - accuracy: 0.6434 - val_loss: 3.7138 - val_accuracy: 0.6707
# Завершён блок [1850_1900] - 5-й из 50
#
# Запущен блок [1900_1950] - 6-й из 50
# [1900-1950]=> Paveletskaya_turbo: № 251 -> Длина записи: 2524079; Маркер выборки: 0; Число нарезок: 18
# [1900-1950]=> Paveletskaya_city: № 252 -> Длина записи: 7539887; Маркер выборки: 1; Число нарезок: 54
# [1900-1950]=> Paveletskaya_turbo: № 253 -> Длина записи: 3076463; Маркер выборки: 0; Число нарезок: 22
# [1900-1950]=> Paveletskaya_city: № 254 -> Длина записи: 823151; Маркер выборки: 1; Число нарезок: 5
# [1900-1950]=> Paveletskaya_turbo: № 255 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 256 -> Длина записи: 2191151; Маркер выборки: 1; Число нарезок: 15
# [1900-1950]=> Paveletskaya_turbo: № 257 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 258 -> Длина записи: 876719; Маркер выборки: 1; Число нарезок: 6
# [1900-1950]=> Paveletskaya_turbo: № 259 -> Длина записи: 307631; Маркер выборки: 0; Число нарезок: 2
# [1900-1950]=> Paveletskaya_city: № 260 -> Длина записи: 965423; Маркер выборки: 1; Число нарезок: 7
# [1900-1950]=> Paveletskaya_turbo: № 261 -> Длина записи: 1748783; Маркер выборки: 0; Число нарезок: 12
# [1900-1950]=> Paveletskaya_city: № 262 -> Длина записи: 1258607; Маркер выборки: 1; Число нарезок: 9
# [1900-1950]=> Paveletskaya_turbo: № 263 -> Длина записи: 710255; Маркер выборки: 0; Число нарезок: 5
# [1900-1950]=> Paveletskaya_city: № 264 -> Длина записи: 4436975; Маркер выборки: 1; Число нарезок: 32
# [1900-1950]=> Paveletskaya_turbo: № 265 -> Длина записи: 240239; Маркер выборки: 0; Число нарезок: 1
# [1900-1950]=> Paveletskaya_city: № 266 -> Длина записи: 6424175; Маркер выборки: 1; Число нарезок: 46
# [1900-1950]=> Paveletskaya_turbo: № 267 -> Длина записи: 579503; Маркер выборки: 0; Число нарезок: 4
# [1900-1950]=> Paveletskaya_city: № 268 -> Длина записи: 3842543; Маркер выборки: 1; Число нарезок: 27
# [1900-1950]=> Paveletskaya_turbo: № 269 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 270 -> Длина записи: 3948527; Маркер выборки: 1; Число нарезок: 28
# [1900-1950]=> Paveletskaya_turbo: № 271 -> Длина записи: 103727; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 272 -> Длина записи: 6357935; Маркер выборки: 1; Число нарезок: 46
# [1900-1950]=> Paveletskaya_turbo: № 273 -> Длина записи: 698735; Маркер выборки: 0; Число нарезок: 5
# [1900-1950]=> Paveletskaya_city: № 274 -> Длина записи: 3901295; Маркер выборки: 1; Число нарезок: 28
# [1900-1950]=> Paveletskaya_turbo: № 275 -> Длина записи: 1495919; Маркер выборки: 0; Число нарезок: 10
# [1900-1950]=> Paveletskaya_city: № 276 -> Длина записи: 1194095; Маркер выборки: 1; Число нарезок: 8
# [1900-1950]=> Paveletskaya_turbo: № 277 -> Длина записи: 588719; Маркер выборки: 0; Число нарезок: 4
# [1900-1950]=> Paveletskaya_city: № 278 -> Длина записи: 4193903; Маркер выборки: 1; Число нарезок: 30
# [1900-1950]=> Paveletskaya_turbo: № 279 -> Длина записи: 2785583; Маркер выборки: 0; Число нарезок: 20
# [1900-1950]=> Paveletskaya_city: № 280 -> Длина записи: 1023599; Маркер выборки: 1; Число нарезок: 7
# [1900-1950]=> Paveletskaya_turbo: № 281 -> Длина записи: 2230319; Маркер выборки: 0; Число нарезок: 16
# [1900-1950]=> Paveletskaya_city: № 282 -> Длина записи: 1457327; Маркер выборки: 1; Число нарезок: 10
# [1900-1950]=> Paveletskaya_turbo: № 283 -> Длина записи: 1451567; Маркер выборки: 0; Число нарезок: 10
# [1900-1950]=> Paveletskaya_city: № 284 -> Длина записи: 2321903; Маркер выборки: 1; Число нарезок: 16
# [1900-1950]=> Paveletskaya_turbo: № 285 -> Длина записи: 166511; Маркер выборки: 0; Число нарезок: 1
# [1900-1950]=> Paveletskaya_city: № 286 -> Длина записи: 8614127; Маркер выборки: 1; Число нарезок: 62
# [1900-1950]=> Paveletskaya_turbo: № 287 -> Длина записи: 24239; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 288 -> Длина записи: 5116655; Маркер выборки: 1; Число нарезок: 37
# [1900-1950]=> Paveletskaya_turbo: № 289 -> Длина записи: 338159; Маркер выборки: 0; Число нарезок: 2
# [1900-1950]=> Paveletskaya_city: № 290 -> Длина записи: 986159; Маркер выборки: 1; Число нарезок: 7
# [1900-1950]=> Paveletskaya_turbo: № 291 -> Длина записи: 161327; Маркер выборки: 0; Число нарезок: 1
# [1900-1950]=> Paveletskaya_city: № 292 -> Длина записи: 623279; Маркер выборки: 1; Число нарезок: 4
# [1900-1950]=> Paveletskaya_turbo: № 293 -> Длина записи: 3720431; Маркер выборки: 0; Число нарезок: 27
# [1900-1950]=> Paveletskaya_city: № 294 -> Длина записи: 1420463; Маркер выборки: 1; Число нарезок: 10
# [1900-1950]=> Paveletskaya_turbo: № 295 -> Длина записи: 1391087; Маркер выборки: 0; Число нарезок: 10
# [1900-1950]=> Paveletskaya_city: № 296 -> Длина записи: 2031599; Маркер выборки: 1; Число нарезок: 14
# [1900-1950]=> Paveletskaya_turbo: № 297 -> Длина записи: 1276463; Маркер выборки: 0; Число нарезок: 9
# [1900-1950]=> Paveletskaya_city: № 298 -> Длина записи: 1089263; Маркер выборки: 1; Число нарезок: 7
# [1900-1950]=> Paveletskaya_turbo: № 299 -> Длина записи: 18479; Маркер выборки: 0; Число нарезок: 0
# [1900-1950]=> Paveletskaya_city: № 300 -> Длина записи: 5673071; Маркер выборки: 1; Число нарезок: 41
#
# XTrain1.shape:  (1345, 137781, 1)
# YTrain1.shape:  (1345, 2)
# XTrain1V.shape:  (138, 137781, 1)
# YTrain1V.shape:  (138, 2)
# Обучающая выборка X_Train1 - Целевых: 5984; Нецелевых: 2477
# Валидационная выборка X_Train1V - Целевых: 642; Нецелевых: 245
# Epoch 1/20
# 43/43 [==============================] - 13s 307ms/step - loss: 0.5605 - accuracy: 0.7606 - val_loss: 10.2205 - val_accuracy: 0.7899
# Epoch 2/20
# 43/43 [==============================] - 13s 294ms/step - loss: 0.5513 - accuracy: 0.7606 - val_loss: 11.3604 - val_accuracy: 0.7826
# Epoch 3/20
# 43/43 [==============================] - 13s 294ms/step - loss: 0.5510 - accuracy: 0.7606 - val_loss: 10.1849 - val_accuracy: 0.7826
# Epoch 4/20
# 43/43 [==============================] - 13s 291ms/step - loss: 0.5510 - accuracy: 0.7606 - val_loss: 5.9589 - val_accuracy: 0.7899
# Epoch 5/20
# 43/43 [==============================] - 12s 288ms/step - loss: 0.5522 - accuracy: 0.7606 - val_loss: 5.1828 - val_accuracy: 0.7899
# Epoch 6/20
# 43/43 [==============================] - 12s 287ms/step - loss: 0.5506 - accuracy: 0.7606 - val_loss: 10.8347 - val_accuracy: 0.7754
# Epoch 7/20
# 43/43 [==============================] - 12s 288ms/step - loss: 0.5513 - accuracy: 0.7606 - val_loss: 9.9314 - val_accuracy: 0.7899
# Epoch 8/20
# 43/43 [==============================] - 12s 289ms/step - loss: 0.5524 - accuracy: 0.7606 - val_loss: 18.6302 - val_accuracy: 0.7826
# Epoch 9/20
# 43/43 [==============================] - 12s 290ms/step - loss: 0.5514 - accuracy: 0.7606 - val_loss: 18.4850 - val_accuracy: 0.7899
# Epoch 10/20
# ...
# [3850-3900]=> Primavera: № 2257 -> Длина записи: 171119; Маркер выборки: 0; Число нарезок: 1
# [3850-3900]=> Primavera: № 2258 -> Длина записи: 9985583; Маркер выборки: 1; Число нарезок: 72
# [3850-3900]=> Primavera: № 2259 -> Длина записи: 172271; Маркер выборки: 0; Число нарезок: 1
# [3850-3900]=> Primavera: № 2260 -> Длина записи: 4817711; Маркер выборки: 1; Число нарезок: 34
#
# XTrain1.shape:  (1383, 137781, 1)
# YTrain1.shape:  (1383, 2)
# XTrain1V.shape:  (152, 137781, 1)
# YTrain1V.shape:  (152, 2)
# Обучающая выборка X_Train1 - Целевых: 47099; Нецелевых: 10302
# Валидационная выборка X_Train1V - Целевых: 5051; Нецелевых: 983
# Epoch 1/20
# 44/44 [==============================] - 14s 310ms/step - loss: 0.0798 - accuracy: 0.9928 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 2/20
# 44/44 [==============================] - 13s 294ms/step - loss: 0.0546 - accuracy: 0.9928 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 3/20
# 44/44 [==============================] - 13s 290ms/step - loss: 0.0484 - accuracy: 0.9928 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 4/20
# 44/44 [==============================] - 13s 287ms/step - loss: 0.0459 - accuracy: 0.9928 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 5/20
# 44/44 [==============================] - 13s 290ms/step - loss: 0.0448 - accuracy: 0.9928 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 6/20
# 44/44 [==============================] - 12s 284ms/step - loss: 0.0440 - accuracy: 0.9928 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 7/20
# 44/44 [==============================] - 13s 287ms/step - loss: 0.0436 - accuracy: 0.9928 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 8/20
# 44/44 [==============================] - 13s 291ms/step - loss: 0.0434 - accuracy: 0.9928 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 9/20
# 44/44 [==============================] - 13s 292ms/step - loss: 0.0432 - accuracy: 0.9928 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 10/20
# 44/44 [==============================] - 13s 291ms/step - loss: 0.0432 - accuracy: 0.9928 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 11/20
# 44/44 [==============================] - 13s 286ms/step - loss: 0.0430 - accuracy: 0.9928 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 12/20
# 44/44 [==============================] - 13s 291ms/step - loss: 0.0430 - accuracy: 0.9928 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 13/20
# 44/44 [==============================] - 13s 290ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 14/20
# 44/44 [==============================] - 13s 286ms/step - loss: 0.0430 - accuracy: 0.9928 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 15/20
# 44/44 [==============================] - 13s 287ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 16/20
# 44/44 [==============================] - 13s 286ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 17/20
# 44/44 [==============================] - 13s 289ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 18/20
# 44/44 [==============================] - 13s 287ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 19/20
# 44/44 [==============================] - 13s 286ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 20/20
# 44/44 [==============================] - 13s 289ms/step - loss: 0.0429 - accuracy: 0.9928 - val_loss: 0.0074 - val_accuracy: 1.0000
# Завершён блок [3850_3900] - 45-й из 50
#
# Запущен блок [3900_3950] - 46-й из 50
# [3900-3950]=> Primavera: № 2261 -> Длина записи: 176303; Маркер выборки: 0; Число нарезок: 1
# [3900-3950]=> Primavera: № 2262 -> Длина записи: 2889263; Маркер выборки: 1; Число нарезок: 20
# [3900-3950]=> Primavera: № 2263 -> Длина записи: 356591; Маркер выборки: 0; Число нарезок: 2
# [3900-3950]=> Primavera: № 2264 -> Длина записи: 4676591; Маркер выборки: 1; Число нарезок: 33
# [3900-3950]=> Primavera: № 2265 -> Длина записи: 4079; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2266 -> Длина записи: 798959; Маркер выборки: 1; Число нарезок: 5
# [3900-3950]=> Primavera: № 2267 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2268 -> Длина записи: 3205487; Маркер выборки: 1; Число нарезок: 23
# [3900-3950]=> Primavera: № 2269 -> Длина записи: 59375; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2270 -> Длина записи: 703919; Маркер выборки: 1; Число нарезок: 5
# [3900-3950]=> Primavera: № 2271 -> Длина записи: 54191; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2272 -> Длина записи: 4709423; Маркер выборки: 1; Число нарезок: 34
# [3900-3950]=> Primavera: № 2273 -> Длина записи: 92783; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2274 -> Длина записи: 807023; Маркер выборки: 1; Число нарезок: 5
# [3900-3950]=> Primavera: № 2275 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2276 -> Длина записи: 525359; Маркер выборки: 1; Число нарезок: 3
# [3900-3950]=> Primavera: № 2277 -> Длина записи: 142895; Маркер выборки: 0; Число нарезок: 1
# [3900-3950]=> Primavera: № 2278 -> Длина записи: 798383; Маркер выборки: 1; Число нарезок: 5
# [3900-3950]=> Primavera: № 2279 -> Длина записи: 1077167; Маркер выборки: 0; Число нарезок: 7
# [3900-3950]=> Primavera: № 2280 -> Длина записи: 1222895; Маркер выборки: 1; Число нарезок: 8
# [3900-3950]=> Primavera: № 2281 -> Длина записи: 126191; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2282 -> Длина записи: 1205615; Маркер выборки: 1; Число нарезок: 8
# [3900-3950]=> Primavera: № 2283 -> Длина записи: 56495; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2284 -> Длина записи: 1867439; Маркер выборки: 1; Число нарезок: 13
# [3900-3950]=> Primavera: № 2285 -> Длина записи: 116975; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2286 -> Длина записи: 3729071; Маркер выборки: 1; Число нарезок: 27
# [3900-3950]=> Primavera: № 2287 -> Длина записи: 31151; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2288 -> Длина записи: 805295; Маркер выборки: 1; Число нарезок: 5
# [3900-3950]=> Primavera: № 2289 -> Длина записи: 339887; Маркер выборки: 0; Число нарезок: 2
# [3900-3950]=> Primavera: № 2290 -> Длина записи: 5404079; Маркер выборки: 1; Число нарезок: 39
# [3900-3950]=> Primavera: № 2291 -> Длина записи: 4794671; Маркер выборки: 0; Число нарезок: 34
# [3900-3950]=> Primavera: № 2292 -> Длина записи: 3403055; Маркер выборки: 1; Число нарезок: 24
# [3900-3950]=> Primavera: № 2293 -> Длина записи: 123311; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2294 -> Длина записи: 4883375; Маркер выборки: 1; Число нарезок: 35
# [3900-3950]=> Primavera: № 2295 -> Длина записи: 181487; Маркер выборки: 0; Число нарезок: 1
# [3900-3950]=> Primavera: № 2296 -> Длина записи: 5112047; Маркер выборки: 1; Число нарезок: 37
# [3900-3950]=> Primavera: № 2297 -> Длина записи: 114671; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2298 -> Длина записи: 6355055; Маркер выборки: 1; Число нарезок: 46
# [3900-3950]=> Primavera: № 2299 -> Длина записи: 733295; Маркер выборки: 0; Число нарезок: 5
# [3900-3950]=> Primavera: № 2300 -> Длина записи: 2535023; Маркер выборки: 1; Число нарезок: 18
# [3900-3950]=> Primavera: № 2301 -> Длина записи: 50735; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2302 -> Длина записи: 11473967; Маркер выборки: 1; Число нарезок: 83
# [3900-3950]=> Primavera: № 2303 -> Длина записи: 17327; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2304 -> Длина записи: 6639023; Маркер выборки: 1; Число нарезок: 48
# [3900-3950]=> Primavera: № 2305 -> Длина записи: 336431; Маркер выборки: 0; Число нарезок: 2
# [3900-3950]=> Primavera: № 2306 -> Длина записи: 1188911; Маркер выборки: 1; Число нарезок: 8
# [3900-3950]=> Primavera: № 2307 -> Длина записи: 104879; Маркер выборки: 0; Число нарезок: 0
# [3900-3950]=> Primavera: № 2308 -> Длина записи: 1129583; Маркер выборки: 1; Число нарезок: 8
# [3900-3950]=> Primavera: № 2309 -> Длина записи: 155567; Маркер выборки: 0; Число нарезок: 1
# [3900-3950]=> Primavera: № 2310 -> Длина записи: 2295983; Маркер выборки: 1; Число нарезок: 16
#
# XTrain1.shape:  (1121, 137781, 1)
# YTrain1.shape:  (1121, 2)
# XTrain1V.shape:  (117, 137781, 1)
# YTrain1V.shape:  (117, 2)
# Обучающая выборка X_Train1 - Целевых: 48121; Нецелевых: 10401
# Валидационная выборка X_Train1V - Целевых: 5160; Нецелевых: 991
# Epoch 1/20
# 36/36 [==============================] - 10s 285ms/step - loss: 0.4043 - accuracy: 0.9117 - val_loss: 0.2768 - val_accuracy: 0.9316
# Epoch 2/20
# 36/36 [==============================] - 11s 294ms/step - loss: 0.3190 - accuracy: 0.9117 - val_loss: 0.2488 - val_accuracy: 0.9316
# Epoch 3/20
# 36/36 [==============================] - 11s 295ms/step - loss: 0.3006 - accuracy: 0.9117 - val_loss: 0.2502 - val_accuracy: 0.9316
# Epoch 4/20
# 36/36 [==============================] - 10s 287ms/step - loss: 0.2991 - accuracy: 0.9117 - val_loss: 0.2506 - val_accuracy: 0.9316
# Epoch 5/20
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2990 - accuracy: 0.9117 - val_loss: 0.2499 - val_accuracy: 0.9316
# Epoch 6/20
# 36/36 [==============================] - 10s 284ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 0.2505 - val_accuracy: 0.9316
# Epoch 7/20
# 36/36 [==============================] - 10s 290ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 0.2499 - val_accuracy: 0.9316
# Epoch 8/20
# 36/36 [==============================] - 10s 285ms/step - loss: 0.2987 - accuracy: 0.9117 - val_loss: 0.3826 - val_accuracy: 0.9231
# Epoch 9/20
# 36/36 [==============================] - 10s 285ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 0.6789 - val_accuracy: 0.9231
# Epoch 10/20
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 0.7141 - val_accuracy: 0.9231
# Epoch 11/20
# 36/36 [==============================] - 10s 284ms/step - loss: 0.2990 - accuracy: 0.9117 - val_loss: 1.0958 - val_accuracy: 0.9231
# Epoch 12/20
# 36/36 [==============================] - 11s 294ms/step - loss: 0.2993 - accuracy: 0.9117 - val_loss: 1.1932 - val_accuracy: 0.9231
# Epoch 13/20
# 36/36 [==============================] - 10s 286ms/step - loss: 0.2996 - accuracy: 0.9117 - val_loss: 0.7962 - val_accuracy: 0.9231
# Epoch 14/20
# 36/36 [==============================] - 10s 292ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 0.9301 - val_accuracy: 0.9231
# Epoch 15/20
# 36/36 [==============================] - 10s 292ms/step - loss: 0.2991 - accuracy: 0.9117 - val_loss: 1.5724 - val_accuracy: 0.9231
# Epoch 16/20
# 36/36 [==============================] - 10s 292ms/step - loss: 0.2995 - accuracy: 0.9117 - val_loss: 2.1914 - val_accuracy: 0.9231
# Epoch 17/20
# 36/36 [==============================] - 10s 284ms/step - loss: 0.2989 - accuracy: 0.9117 - val_loss: 2.3344 - val_accuracy: 0.9231
# Epoch 18/20
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2988 - accuracy: 0.9117 - val_loss: 2.3291 - val_accuracy: 0.9231
# Epoch 19/20
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2992 - accuracy: 0.9117 - val_loss: 2.6570 - val_accuracy: 0.9231
# Epoch 20/20
# 36/36 [==============================] - 10s 285ms/step - loss: 0.2990 - accuracy: 0.9117 - val_loss: 2.5726 - val_accuracy: 0.9231
# Завершён блок [3900_3950] - 46-й из 50
#
# Запущен блок [3950_4000] - 47-й из 50
# [3950-4000]=> Primavera: № 2311 -> Длина записи: 174575; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 2312 -> Длина записи: 273071; Маркер выборки: 1; Число нарезок: 1
# [3950-4000]=> Primavera: № 2313 -> Длина записи: 116975; Маркер выборки: 0; Число нарезок: 0
# Время обработки: 13385.07 с
# <ipython-input-23-77f2e8e634bd>:76: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path_[data_number_]+'/'+au_name_, mono=True, sr=SR) #Загружаем аудиофайл
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         try:
# --> 175             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     176
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     207         # Otherwise, create the soundfile object
# --> 208         context = sf.SoundFile(path)
#     209
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     657                                          format, subtype, endian)
# --> 658         self._file = self._open(file, mode_int, closefd)
#     659         if set(mode).issuperset('r+') and self.seekable():
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1215             err = _snd.sf_error(file_ptr)
# -> 1216             raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217         if mode_int == _snd.SFM_WRITE:
#
# LibsndfileError: Error opening '/content/drive/MyDrive/st108/Audio/Записи звонков_primavera//2023-05-18_16-00-58.258151_from_79277985777_to_0111639_session_2961173168_talk.mp3': File does not exist or is not a regular file (possibly a pipe?).
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-c578aae35c6e> in <cell line: 1>()
#       1 with timex():
# ----> 2   neuro_au()
#
# <ipython-input-23-77f2e8e634bd> in neuro_au()
#      74       data_number_ = df_pre_train_.loc[i]['DataNumber']
#      75
# ---> 76       y, sr = librosa.load(audio_path_[data_number_]+'/'+au_name_, mono=True, sr=SR) #Загружаем аудиофайл
#      77
#      78       au_len_ = len(y) # Количество сигналов
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     181                     "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     182                 )
# --> 183                 y, sr_native = __audioread_load(path, offset, duration, dtype)
#     184             else:
#     185                 raise exc
#
# <decorator-gen-119> in __audioread_load(path, offset, duration, dtype)
#
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py in __wrapper(func, *args, **kwargs)
#      57             stacklevel=3,  # Would be 2, but the decorator adds a level
#      58         )
# ---> 59         return func(*args, **kwargs)
#      60
#      61     return decorator(__wrapper)
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     237     else:
#     238         # If the input was not an audioread object, try to open it
# --> 239         reader = audioread.audio_open(path)
#     240
#     241     with reader as input_file:
#
# /usr/local/lib/python3.10/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     125     for BackendClass in backends:
#     126         try:
# --> 127             return BackendClass(path)
#     128         except DecodeError:
#     129             pass
#
# /usr/local/lib/python3.10/dist-packages/audioread/rawread.py in __init__(self, filename)
#      57     """
#      58     def __init__(self, filename):
# ---> 59         self._fh = open(filename, 'rb')
#      60
#      61         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/st108/Audio/Записи звонков_primavera//2023-05-18_16-00-58.258151_from_79277985777_to_0111639_session_2961173168_talk.mp3'

# %%
with timex():
  neuro_au()
# Out:
# Запущен блок [3950_4000] - 1-й из 4
# [3950-4000]=> Primavera: № 1 -> Длина записи: 174575; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 2 -> Длина записи: 273071; Маркер выборки: 1; Число нарезок: 1
# [3950-4000]=> Primavera: № 3 -> Длина записи: 116975; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 4 -> Длина записи: 2246447; Маркер выборки: 1; Число нарезок: 16
# [3950-4000]=> Primavera: № 5 -> Длина записи: 4655; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 6 -> Длина записи: 4796399; Маркер выборки: 1; Число нарезок: 34
# [3950-4000]=> Primavera: № 7 -> Длина записи: 110063; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 8 -> Длина записи: 894575; Маркер выборки: 1; Число нарезок: 6
# [3950-4000]=> Primavera: № 9 -> Длина записи: 121583; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 10 -> Длина записи: 4737647; Маркер выборки: 1; Число нарезок: 34
# [3950-4000]=> Primavera: № 11 -> Длина записи: 133679; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 12 -> Длина записи: 1516655; Маркер выборки: 1; Число нарезок: 11
# [3950-4000]=> Primavera: № 13 -> Длина записи: 35759; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 14 -> Длина записи: 2373743; Маркер выборки: 1; Число нарезок: 17
# [3950-4000]=> Primavera: № 15 -> Длина записи: 4655; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 16 -> Длина записи: 445295; Маркер выборки: 1; Число нарезок: 3
# [3950-4000]=> Primavera: № 17 -> Длина записи: 81839; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 18 -> Длина записи: 2237231; Маркер выборки: 1; Число нарезок: 16
# [3950-4000]=> Primavera: № 19 -> Длина записи: 202223; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 20 -> Длина записи: 1162991; Маркер выборки: 1; Число нарезок: 8
# [3950-4000]=> Primavera: № 21 -> Длина записи: 97391; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 22 -> Длина записи: 23493359; Маркер выборки: 1; Число нарезок: 170
# [3950-4000]=> Primavera: № 23 -> Длина записи: 970607; Маркер выборки: 0; Число нарезок: 7
# [3950-4000]=> Primavera: № 24 -> Длина записи: 3491759; Маркер выборки: 1; Число нарезок: 25
# [3950-4000]=> Primavera: № 25 -> Длина записи: 150383; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 26 -> Длина записи: 1210799; Маркер выборки: 1; Число нарезок: 8
# [3950-4000]=> Primavera: № 27 -> Длина записи: 3503; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 28 -> Длина записи: 5315951; Маркер выборки: 1; Число нарезок: 38
# [3950-4000]=> Primavera: № 29 -> Длина записи: 2112815; Маркер выборки: 0; Число нарезок: 15
# [3950-4000]=> Primavera: № 30 -> Длина записи: 3418607; Маркер выборки: 1; Число нарезок: 24
# [3950-4000]=> Primavera: № 31 -> Длина записи: 262703; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 32 -> Длина записи: 7182191; Маркер выборки: 1; Число нарезок: 52
# [3950-4000]=> Primavera: № 33 -> Длина записи: 157295; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 34 -> Длина записи: 1770671; Маркер выборки: 1; Число нарезок: 12
# [3950-4000]=> Primavera: № 35 -> Длина записи: 160751; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 36 -> Длина записи: 4604591; Маркер выборки: 1; Число нарезок: 33
# [3950-4000]=> Primavera: № 37 -> Длина записи: 16175; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 38 -> Длина записи: 7186223; Маркер выборки: 1; Число нарезок: 52
# [3950-4000]=> Primavera: № 39 -> Длина записи: 5807; Маркер выборки: 0; Число нарезок: 0
# [3950-4000]=> Primavera: № 40 -> Длина записи: 3741167; Маркер выборки: 1; Число нарезок: 27
# [3950-4000]=> Primavera: № 41 -> Длина записи: 141743; Маркер выборки: 0; Число нарезок: 1
# [3950-4000]=> Primavera: № 42 -> Длина записи: 3229103; Маркер выборки: 1; Число нарезок: 23
# [3950-4000]=> Primavera: № 43 -> Длина записи: 285743; Маркер выборки: 0; Число нарезок: 2
# [3950-4000]=> Primavera: № 44 -> Длина записи: 3436463; Маркер выборки: 1; Число нарезок: 24
# [3950-4000]=> Primavera: № 45 -> Длина записи: 301295; Маркер выборки: 0; Число нарезок: 2
# [3950-4000]=> Primavera: № 46 -> Длина записи: 14943791; Маркер выборки: 1; Число нарезок: 108
# [3950-4000]=> Primavera: № 47 -> Длина записи: 557039; Маркер выборки: 0; Число нарезок: 4
# [3950-4000]=> Primavera: № 48 -> Длина записи: 4203695; Маркер выборки: 1; Число нарезок: 30
# [3950-4000]=> Primavera: № 49 -> Длина записи: 323759; Маркер выборки: 0; Число нарезок: 2
# [3950-4000]=> Primavera: № 50 -> Длина записи: 5896559; Маркер выборки: 1; Число нарезок: 42
#
# XTrain1.shape:  (1555, 137781, 1)
# YTrain1.shape:  (1555, 2)
# XTrain1V.shape:  (170, 137781, 1)
# YTrain1V.shape:  (170, 2)
# Обучающая выборка X_Train1 - Целевых: 1492; Нецелевых: 63
# Валидационная выборка X_Train1V - Целевых: 166; Нецелевых: 4
# Epoch 1/20
# 49/49 [==============================] - 30s 321ms/step - loss: 0.8650 - accuracy: 0.9408 - val_loss: 2.5194 - val_accuracy: 0.9765
# Epoch 2/20
# 49/49 [==============================] - 14s 279ms/step - loss: 0.1999 - accuracy: 0.9595 - val_loss: 5.0650 - val_accuracy: 0.9765
# Epoch 3/20
# 49/49 [==============================] - 14s 283ms/step - loss: 0.1749 - accuracy: 0.9595 - val_loss: 0.1189 - val_accuracy: 0.9765
# Epoch 4/20
# 49/49 [==============================] - 14s 283ms/step - loss: 0.1614 - accuracy: 0.9595 - val_loss: 0.1139 - val_accuracy: 0.9765
# Epoch 5/20
# 49/49 [==============================] - 14s 286ms/step - loss: 0.1617 - accuracy: 0.9595 - val_loss: 0.1286 - val_accuracy: 0.9765
# Epoch 6/20
# 49/49 [==============================] - 14s 293ms/step - loss: 0.1556 - accuracy: 0.9595 - val_loss: 0.0984 - val_accuracy: 0.9765
# Epoch 7/20
# 49/49 [==============================] - 14s 293ms/step - loss: 0.1526 - accuracy: 0.9595 - val_loss: 0.1442 - val_accuracy: 0.9765
# Epoch 8/20
# 49/49 [==============================] - 14s 292ms/step - loss: 0.1511 - accuracy: 0.9595 - val_loss: 0.0937 - val_accuracy: 0.9765
# Epoch 9/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.1529 - accuracy: 0.9595 - val_loss: 0.0902 - val_accuracy: 0.9765
# Epoch 10/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.1437 - accuracy: 0.9595 - val_loss: 0.1331 - val_accuracy: 0.9765
# Epoch 11/20
# 49/49 [==============================] - 14s 289ms/step - loss: 0.1546 - accuracy: 0.9595 - val_loss: 0.1182 - val_accuracy: 0.9765
# Epoch 12/20
# 49/49 [==============================] - 14s 293ms/step - loss: 0.1526 - accuracy: 0.9595 - val_loss: 0.0966 - val_accuracy: 0.9765
# Epoch 13/20
# 49/49 [==============================] - 14s 292ms/step - loss: 0.1482 - accuracy: 0.9595 - val_loss: 0.2026 - val_accuracy: 0.9765
# Epoch 14/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.1403 - accuracy: 0.9595 - val_loss: 773.7111 - val_accuracy: 0.9765
# Epoch 15/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.1422 - accuracy: 0.9595 - val_loss: 0.1543 - val_accuracy: 0.9765
# Epoch 16/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.1452 - accuracy: 0.9595 - val_loss: 7.3402 - val_accuracy: 0.6765
# Epoch 17/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.1409 - accuracy: 0.9595 - val_loss: 9.2509 - val_accuracy: 0.9706
# Epoch 18/20
# 49/49 [==============================] - 14s 291ms/step - loss: 0.1390 - accuracy: 0.9595 - val_loss: 294701.8438 - val_accuracy: 0.9765
# Epoch 19/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.1359 - accuracy: 0.9595 - val_loss: 0.2415 - val_accuracy: 0.9765
# Epoch 20/20
# 49/49 [==============================] - 14s 294ms/step - loss: 0.1354 - accuracy: 0.9595 - val_loss: 46.9974 - val_accuracy: 0.9765
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Завершён блок [3950_4000] - 1-й из 4
#
# Запущен блок [4000_4050] - 2-й из 4
# [4000-4050]=> Primavera: № 51 -> Длина записи: 5807; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 52 -> Длина записи: 5809583; Маркер выборки: 1; Число нарезок: 42
# [4000-4050]=> Primavera: № 53 -> Длина записи: 6383; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 54 -> Длина записи: 1278767; Маркер выборки: 1; Число нарезок: 9
# [4000-4050]=> Primavera: № 55 -> Длина записи: 9839; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 56 -> Длина записи: 4807919; Маркер выборки: 1; Число нарезок: 34
# [4000-4050]=> Primavera: № 57 -> Длина записи: 9263; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 58 -> Длина записи: 2912879; Маркер выборки: 1; Число нарезок: 21
# [4000-4050]=> Primavera: № 59 -> Длина записи: 269039; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 60 -> Длина записи: 1183151; Маркер выборки: 1; Число нарезок: 8
# [4000-4050]=> Primavera: № 61 -> Длина записи: 1740143; Маркер выборки: 0; Число нарезок: 12
# [4000-4050]=> Primavera: № 62 -> Длина записи: 630191; Маркер выборки: 1; Число нарезок: 4
# [4000-4050]=> Primavera: № 63 -> Длина записи: 55919; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 64 -> Длина записи: 4965743; Маркер выборки: 1; Число нарезок: 36
# [4000-4050]=> Primavera: № 65 -> Длина записи: 93359; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 66 -> Длина записи: 1847855; Маркер выборки: 1; Число нарезок: 13
# [4000-4050]=> Primavera: № 67 -> Длина записи: 217775; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 68 -> Длина записи: 2160623; Маркер выборки: 1; Число нарезок: 15
# [4000-4050]=> Primavera: № 69 -> Длина записи: 872687; Маркер выборки: 0; Число нарезок: 6
# [4000-4050]=> Primavera: № 70 -> Длина записи: 2230319; Маркер выборки: 1; Число нарезок: 16
# [4000-4050]=> Primavera: № 71 -> Длина записи: 80111; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 72 -> Длина записи: 2275823; Маркер выборки: 1; Число нарезок: 16
# [4000-4050]=> Primavera: № 73 -> Длина записи: 29999; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 74 -> Длина записи: 6245039; Маркер выборки: 1; Число нарезок: 45
# [4000-4050]=> Primavera: № 75 -> Длина записи: 101423; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 76 -> Длина записи: 2392175; Маркер выборки: 1; Число нарезок: 17
# [4000-4050]=> Primavera: № 77 -> Длина записи: 53039; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 78 -> Длина записи: 7069871; Маркер выборки: 1; Число нарезок: 51
# [4000-4050]=> Primavera: № 79 -> Длина записи: 226991; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 80 -> Длина записи: 8691311; Маркер выборки: 1; Число нарезок: 63
# [4000-4050]=> Primavera: № 81 -> Длина записи: 2351; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 82 -> Длина записи: 744815; Маркер выборки: 1; Число нарезок: 5
# [4000-4050]=> Primavera: № 83 -> Длина записи: 36335; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 84 -> Длина записи: 2376047; Маркер выборки: 1; Число нарезок: 17
# [4000-4050]=> Primavera: № 85 -> Длина записи: 451055; Маркер выборки: 0; Число нарезок: 3
# [4000-4050]=> Primavera: № 86 -> Длина записи: 450479; Маркер выборки: 1; Число нарезок: 3
# [4000-4050]=> Primavera: № 87 -> Длина записи: 140591; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 88 -> Длина записи: 2068463; Маркер выборки: 1; Число нарезок: 15
# [4000-4050]=> Primavera: № 89 -> Длина записи: 188975; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 90 -> Длина записи: 2978543; Маркер выборки: 1; Число нарезок: 21
# [4000-4050]=> Primavera: № 91 -> Длина записи: 134831; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 92 -> Длина записи: 857711; Маркер выборки: 1; Число нарезок: 6
# [4000-4050]=> Primavera: № 93 -> Длина записи: 17903; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 94 -> Длина записи: 3388655; Маркер выборки: 1; Число нарезок: 24
# [4000-4050]=> Primavera: № 95 -> Длина записи: 32303; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 96 -> Длина записи: 6874031; Маркер выборки: 1; Число нарезок: 49
# [4000-4050]=> Primavera: № 97 -> Длина записи: 160751; Маркер выборки: 0; Число нарезок: 1
# [4000-4050]=> Primavera: № 98 -> Длина записи: 608879; Маркер выборки: 1; Число нарезок: 4
# [4000-4050]=> Primavera: № 99 -> Длина записи: 44399; Маркер выборки: 0; Число нарезок: 0
# [4000-4050]=> Primavera: № 100 -> Длина записи: 6674159; Маркер выборки: 1; Число нарезок: 48
#
# XTrain1.shape:  (1109, 137781, 1)
# YTrain1.shape:  (1109, 2)
# XTrain1V.shape:  (115, 137781, 1)
# YTrain1V.shape:  (115, 2)
# Обучающая выборка X_Train1 - Целевых: 2555; Нецелевых: 109
# Валидационная выборка X_Train1V - Целевых: 278; Нецелевых: 7
# Epoch 1/20
# 35/35 [==============================] - 12s 348ms/step - loss: 0.1596 - accuracy: 0.9585 - val_loss: 55.2620 - val_accuracy: 0.9739
# Epoch 2/20
# 35/35 [==============================] - 11s 304ms/step - loss: 0.1602 - accuracy: 0.9585 - val_loss: 0.9447 - val_accuracy: 0.9739
# Epoch 3/20
# 35/35 [==============================] - 10s 294ms/step - loss: 0.1529 - accuracy: 0.9585 - val_loss: 0.1071 - val_accuracy: 0.9739
# Epoch 4/20
# 35/35 [==============================] - 11s 301ms/step - loss: 0.1435 - accuracy: 0.9585 - val_loss: 0.1227 - val_accuracy: 0.9739
# Epoch 5/20
# 35/35 [==============================] - 10s 298ms/step - loss: 0.1499 - accuracy: 0.9585 - val_loss: 0.5520 - val_accuracy: 0.9739
# Epoch 6/20
# 35/35 [==============================] - 10s 297ms/step - loss: 0.1444 - accuracy: 0.9585 - val_loss: 0.0851 - val_accuracy: 0.9739
# Epoch 7/20
# 35/35 [==============================] - 10s 297ms/step - loss: 0.1455 - accuracy: 0.9558 - val_loss: 0.0868 - val_accuracy: 0.9739
# Epoch 8/20
# 35/35 [==============================] - 10s 290ms/step - loss: 0.1435 - accuracy: 0.9585 - val_loss: 0.1451 - val_accuracy: 0.9739
# Epoch 9/20
# 35/35 [==============================] - 10s 299ms/step - loss: 0.1478 - accuracy: 0.9585 - val_loss: 0.1207 - val_accuracy: 0.9739
# Epoch 10/20
# 35/35 [==============================] - 10s 300ms/step - loss: 0.1350 - accuracy: 0.9585 - val_loss: 0.2043 - val_accuracy: 0.9739
# Epoch 11/20
# 35/35 [==============================] - 10s 292ms/step - loss: 0.1317 - accuracy: 0.9585 - val_loss: 0.0967 - val_accuracy: 0.9739
# Epoch 12/20
# 35/35 [==============================] - 10s 292ms/step - loss: 0.1255 - accuracy: 0.9585 - val_loss: 0.4119 - val_accuracy: 0.9739
# Epoch 13/20
# 35/35 [==============================] - 10s 300ms/step - loss: 0.1251 - accuracy: 0.9585 - val_loss: 0.1043 - val_accuracy: 0.9739
# Epoch 14/20
# 35/35 [==============================] - 10s 299ms/step - loss: 0.1233 - accuracy: 0.9585 - val_loss: 1760.0365 - val_accuracy: 0.9739
# Epoch 15/20
# 35/35 [==============================] - 10s 291ms/step - loss: 0.1366 - accuracy: 0.9585 - val_loss: 0.0934 - val_accuracy: 0.9739
# Epoch 16/20
# 35/35 [==============================] - 11s 301ms/step - loss: 0.1389 - accuracy: 0.9585 - val_loss: 0.3964 - val_accuracy: 0.9739
# Epoch 17/20
# 35/35 [==============================] - 10s 301ms/step - loss: 0.1338 - accuracy: 0.9585 - val_loss: 0.7898 - val_accuracy: 0.9739
# Epoch 18/20
# 35/35 [==============================] - 10s 299ms/step - loss: 0.1253 - accuracy: 0.9585 - val_loss: 4.8356 - val_accuracy: 0.9652
# Epoch 19/20
# 35/35 [==============================] - 10s 291ms/step - loss: 0.1242 - accuracy: 0.9585 - val_loss: 0.4012 - val_accuracy: 0.9739
# Epoch 20/20
# 35/35 [==============================] - 10s 290ms/step - loss: 0.1181 - accuracy: 0.9585 - val_loss: 67.8099 - val_accuracy: 0.9739
# Завершён блок [4000_4050] - 2-й из 4
#
# Запущен блок [4050_4100] - 3-й из 4
# [4050-4100]=> Primavera: № 101 -> Длина записи: 156719; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 102 -> Длина записи: 141743; Маркер выборки: 1; Число нарезок: 1
# [4050-4100]=> Primavera: № 103 -> Длина записи: 2927; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 104 -> Длина записи: 8479343; Маркер выборки: 1; Число нарезок: 61
# [4050-4100]=> Primavera: № 105 -> Длина записи: 9839; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 106 -> Длина записи: 2581679; Маркер выборки: 1; Число нарезок: 18
# [4050-4100]=> Primavera: № 107 -> Длина записи: 152111; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 108 -> Длина записи: 748271; Маркер выборки: 1; Число нарезок: 5
# [4050-4100]=> Primavera: № 109 -> Длина записи: 78959; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 110 -> Длина записи: 3386351; Маркер выборки: 1; Число нарезок: 24
# [4050-4100]=> Primavera: № 111 -> Длина записи: 533999; Маркер выборки: 0; Число нарезок: 3
# [4050-4100]=> Primavera: № 112 -> Длина записи: 1773551; Маркер выборки: 1; Число нарезок: 12
# [4050-4100]=> Primavera: № 113 -> Длина записи: 448751; Маркер выборки: 0; Число нарезок: 3
# [4050-4100]=> Primavera: № 114 -> Длина записи: 6138479; Маркер выборки: 1; Число нарезок: 44
# [4050-4100]=> Primavera: № 115 -> Длина записи: 251759; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 116 -> Длина записи: 3524591; Маркер выборки: 1; Число нарезок: 25
# [4050-4100]=> Primavera: № 117 -> Длина записи: 206831; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 118 -> Длина записи: 4772207; Маркер выборки: 1; Число нарезок: 34
# [4050-4100]=> Primavera: № 119 -> Длина записи: 1456751; Маркер выборки: 0; Число нарезок: 10
# [4050-4100]=> Primavera: № 120 -> Длина записи: 3375407; Маркер выборки: 1; Число нарезок: 24
# [4050-4100]=> Primavera: № 121 -> Длина записи: 200495; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 122 -> Длина записи: 5207087; Маркер выборки: 1; Число нарезок: 37
# [4050-4100]=> Primavera: № 123 -> Длина записи: 935471; Маркер выборки: 0; Число нарезок: 6
# [4050-4100]=> Primavera: № 124 -> Длина записи: 618671; Маркер выборки: 1; Число нарезок: 4
# [4050-4100]=> Primavera: № 125 -> Длина записи: 105455; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 126 -> Длина записи: 1249967; Маркер выборки: 1; Число нарезок: 9
# [4050-4100]=> Primavera: № 127 -> Длина записи: 205679; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 128 -> Длина записи: 2630063; Маркер выборки: 1; Число нарезок: 19
# [4050-4100]=> Primavera: № 129 -> Длина записи: 4655; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 130 -> Длина записи: 2356463; Маркер выборки: 1; Число нарезок: 17
# [4050-4100]=> Primavera: № 131 -> Длина записи: 126191; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 132 -> Длина записи: 11277551; Маркер выборки: 1; Число нарезок: 81
# [4050-4100]=> Primavera: № 133 -> Длина записи: 88751; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 134 -> Длина записи: 1396847; Маркер выборки: 1; Число нарезок: 10
# [4050-4100]=> Primavera: № 135 -> Длина записи: 121007; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 136 -> Длина записи: 297839; Маркер выборки: 1; Число нарезок: 2
# [4050-4100]=> Primavera: № 137 -> Длина записи: 141167; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 138 -> Длина записи: 1850735; Маркер выборки: 1; Число нарезок: 13
# [4050-4100]=> Primavera: № 139 -> Длина записи: 61103; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 140 -> Длина записи: 419375; Маркер выборки: 1; Число нарезок: 3
# [4050-4100]=> Primavera: № 141 -> Длина записи: 123311; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 142 -> Длина записи: 1824815; Маркер выборки: 1; Число нарезок: 13
# [4050-4100]=> Primavera: № 143 -> Длина записи: 111215; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 144 -> Длина записи: 2303471; Маркер выборки: 1; Число нарезок: 16
# [4050-4100]=> Primavera: № 145 -> Длина записи: 266159; Маркер выборки: 0; Число нарезок: 1
# [4050-4100]=> Primavera: № 146 -> Длина записи: 1541999; Маркер выборки: 1; Число нарезок: 11
# [4050-4100]=> Primavera: № 147 -> Длина записи: 57647; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 148 -> Длина записи: 13565423; Маркер выборки: 1; Число нарезок: 98
# [4050-4100]=> Primavera: № 149 -> Длина записи: 21935; Маркер выборки: 0; Число нарезок: 0
# [4050-4100]=> Primavera: № 150 -> Длина записи: 4203119; Маркер выборки: 1; Число нарезок: 30
#
# XTrain1.shape:  (1171, 137781, 1)
# YTrain1.shape:  (1171, 2)
# XTrain1V.shape:  (123, 137781, 1)
# YTrain1V.shape:  (123, 2)
# Обучающая выборка X_Train1 - Целевых: 3674; Нецелевых: 161
# Валидационная выборка X_Train1V - Целевых: 398; Нецелевых: 10
# Epoch 1/20
# 37/37 [==============================] - 12s 319ms/step - loss: 0.2159 - accuracy: 0.9496 - val_loss: 0.2892 - val_accuracy: 0.9756
# Epoch 2/20
# 37/37 [==============================] - 11s 304ms/step - loss: 0.2189 - accuracy: 0.9539 - val_loss: 0.1119 - val_accuracy: 0.9756
# Epoch 3/20
# 37/37 [==============================] - 11s 302ms/step - loss: 0.1736 - accuracy: 0.9556 - val_loss: 0.1459 - val_accuracy: 0.9756
# Epoch 4/20
# 37/37 [==============================] - 11s 299ms/step - loss: 0.1669 - accuracy: 0.9556 - val_loss: 3.6223 - val_accuracy: 0.9756
# Epoch 5/20
# 37/37 [==============================] - 11s 288ms/step - loss: 0.1912 - accuracy: 0.9556 - val_loss: 0.1138 - val_accuracy: 0.9756
# Epoch 6/20
# 37/37 [==============================] - 11s 296ms/step - loss: 0.1615 - accuracy: 0.9556 - val_loss: 0.0899 - val_accuracy: 0.9756
# Epoch 7/20
# 37/37 [==============================] - 11s 297ms/step - loss: 0.1508 - accuracy: 0.9556 - val_loss: 0.1622 - val_accuracy: 0.9756
# Epoch 8/20
# 37/37 [==============================] - 11s 297ms/step - loss: 0.1501 - accuracy: 0.9556 - val_loss: 0.1843 - val_accuracy: 0.9756
# Epoch 9/20
# 37/37 [==============================] - 11s 292ms/step - loss: 0.1578 - accuracy: 0.9556 - val_loss: 0.0966 - val_accuracy: 0.9756
# Epoch 10/20
# 37/37 [==============================] - 11s 292ms/step - loss: 0.1509 - accuracy: 0.9556 - val_loss: 0.1729 - val_accuracy: 0.9756
# Epoch 11/20
# 37/37 [==============================] - 11s 291ms/step - loss: 0.1493 - accuracy: 0.9556 - val_loss: 0.2086 - val_accuracy: 0.9756
# Epoch 12/20
# 37/37 [==============================] - 11s 298ms/step - loss: 0.1495 - accuracy: 0.9556 - val_loss: 4064.9382 - val_accuracy: 0.9756
# Epoch 13/20
# 37/37 [==============================] - 11s 298ms/step - loss: 0.1474 - accuracy: 0.9556 - val_loss: 3906.3992 - val_accuracy: 0.9756
# Epoch 14/20
# 37/37 [==============================] - 11s 297ms/step - loss: 0.1435 - accuracy: 0.9556 - val_loss: 499.2642 - val_accuracy: 0.9756
# Epoch 15/20
# 37/37 [==============================] - 11s 290ms/step - loss: 0.1687 - accuracy: 0.9556 - val_loss: 63.8530 - val_accuracy: 0.9756
# Epoch 16/20
# 37/37 [==============================] - 11s 291ms/step - loss: 0.1483 - accuracy: 0.9556 - val_loss: 8.1549 - val_accuracy: 0.9756
# Epoch 17/20
# 37/37 [==============================] - 11s 300ms/step - loss: 0.1375 - accuracy: 0.9556 - val_loss: 6.4352 - val_accuracy: 0.9756
# Epoch 18/20
# 37/37 [==============================] - 11s 291ms/step - loss: 0.1349 - accuracy: 0.9556 - val_loss: 38.6441 - val_accuracy: 0.9756
# Epoch 19/20
# 37/37 [==============================] - 11s 299ms/step - loss: 0.1364 - accuracy: 0.9556 - val_loss: 0.0560 - val_accuracy: 0.9756
# Epoch 20/20
# 37/37 [==============================] - 11s 290ms/step - loss: 0.1238 - accuracy: 0.9556 - val_loss: 0.1332 - val_accuracy: 0.9756
# Завершён блок [4050_4100] - 3-й из 4
#
# Запущен блок [4100_4174] - 4-й из 4
# [4100-4174]=> Primavera: № 151 -> Длина записи: 4211183; Маркер выборки: 0; Число нарезок: 30
# [4100-4174]=> Primavera: № 152 -> Длина записи: 4443887; Маркер выборки: 1; Число нарезок: 32
# [4100-4174]=> Primavera: № 153 -> Длина записи: 225263; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 154 -> Длина записи: 2890991; Маркер выборки: 1; Число нарезок: 20
# [4100-4174]=> Primavera: № 155 -> Длина записи: 788591; Маркер выборки: 0; Число нарезок: 5
# [4100-4174]=> Primavera: № 156 -> Длина записи: 1202735; Маркер выборки: 1; Число нарезок: 8
# [4100-4174]=> Primavera: № 157 -> Длина записи: 335279; Маркер выборки: 0; Число нарезок: 2
# [4100-4174]=> Primavera: № 158 -> Длина записи: 6044591; Маркер выборки: 1; Число нарезок: 43
# [4100-4174]=> Primavera: № 159 -> Длина записи: 64559; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 160 -> Длина записи: 2718767; Маркер выборки: 1; Число нарезок: 19
# [4100-4174]=> Primavera: № 161 -> Длина записи: 133103; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 162 -> Длина записи: 7288751; Маркер выборки: 1; Число нарезок: 52
# [4100-4174]=> Primavera: № 163 -> Длина записи: 317423; Маркер выборки: 0; Число нарезок: 2
# [4100-4174]=> Primavera: № 164 -> Длина записи: 3193967; Маркер выборки: 1; Число нарезок: 23
# [4100-4174]=> Primavera: № 165 -> Длина записи: 2505071; Маркер выборки: 0; Число нарезок: 18
# [4100-4174]=> Primavera: № 166 -> Длина записи: 3928943; Маркер выборки: 1; Число нарезок: 28
# [4100-4174]=> Primavera: № 167 -> Длина записи: 583535; Маркер выборки: 0; Число нарезок: 4
# [4100-4174]=> Primavera: № 168 -> Длина записи: 2740655; Маркер выборки: 1; Число нарезок: 19
# [4100-4174]=> Primavera: № 169 -> Длина записи: 391151; Маркер выборки: 0; Число нарезок: 2
# [4100-4174]=> Primavera: № 170 -> Длина записи: 2482607; Маркер выборки: 1; Число нарезок: 18
# [4100-4174]=> Primavera: № 171 -> Длина записи: 146351; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 172 -> Длина записи: 13113263; Маркер выборки: 1; Число нарезок: 95
# [4100-4174]=> Primavera: № 173 -> Длина записи: 147503; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 174 -> Длина записи: 5029679; Маркер выборки: 1; Число нарезок: 36
# [4100-4174]=> Primavera: № 175 -> Длина записи: 7535; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 176 -> Длина записи: 5045231; Маркер выборки: 1; Число нарезок: 36
# [4100-4174]=> Primavera: № 177 -> Длина записи: 141743; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 178 -> Длина записи: 266159; Маркер выборки: 1; Число нарезок: 1
# [4100-4174]=> Primavera: № 179 -> Длина записи: 25967; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 180 -> Длина записи: 1050671; Маркер выборки: 1; Число нарезок: 7
# [4100-4174]=> Primavera: № 181 -> Длина записи: 25967; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 182 -> Длина записи: 1281071; Маркер выборки: 1; Число нарезок: 9
# [4100-4174]=> Primavera: № 183 -> Длина записи: 71471; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 184 -> Длина записи: 3944495; Маркер выборки: 1; Число нарезок: 28
# [4100-4174]=> Primavera: № 185 -> Длина записи: 217775; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 186 -> Длина записи: 4255535; Маркер выборки: 1; Число нарезок: 30
# [4100-4174]=> Primavera: № 187 -> Длина записи: 39791; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 188 -> Длина записи: 1500527; Маркер выборки: 1; Число нарезок: 10
# [4100-4174]=> Primavera: № 189 -> Длина записи: 8687; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 190 -> Длина записи: 879599; Маркер выборки: 1; Число нарезок: 6
# [4100-4174]=> Primavera: № 191 -> Длина записи: 110639; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 192 -> Длина записи: 974063; Маркер выборки: 1; Число нарезок: 7
# [4100-4174]=> Primavera: № 193 -> Длина записи: 86447; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 194 -> Длина записи: 1320239; Маркер выборки: 1; Число нарезок: 9
# [4100-4174]=> Primavera: № 195 -> Длина записи: 25967; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 196 -> Длина записи: 406703; Маркер выборки: 1; Число нарезок: 2
# [4100-4174]=> Primavera: № 197 -> Длина записи: 1717679; Маркер выборки: 0; Число нарезок: 12
# [4100-4174]=> Primavera: № 198 -> Длина записи: 3600623; Маркер выборки: 1; Число нарезок: 26
# [4100-4174]=> Primavera: № 199 -> Длина записи: 9263; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 200 -> Длина записи: 1995311; Маркер выборки: 1; Число нарезок: 14
# [4100-4174]=> Primavera: № 201 -> Длина записи: 154991; Маркер выборки: 0; Число нарезок: 1
# [4100-4174]=> Primavera: № 202 -> Длина записи: 2954927; Маркер выборки: 1; Число нарезок: 21
# [4100-4174]=> Primavera: № 203 -> Длина записи: 124463; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 204 -> Длина записи: 597935; Маркер выборки: 1; Число нарезок: 4
# [4100-4174]=> Primavera: № 205 -> Длина записи: 40367; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 206 -> Длина записи: 299567; Маркер выборки: 1; Число нарезок: 2
# [4100-4174]=> Primavera: № 207 -> Длина записи: 19055; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 208 -> Длина записи: 3998639; Маркер выборки: 1; Число нарезок: 29
# [4100-4174]=> Primavera: № 209 -> Длина записи: 300143; Маркер выборки: 0; Число нарезок: 2
# [4100-4174]=> Primavera: № 210 -> Длина записи: 4463471; Маркер выборки: 1; Число нарезок: 32
# [4100-4174]=> Primavera: № 211 -> Длина записи: 41519; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 212 -> Длина записи: 2127791; Маркер выборки: 1; Число нарезок: 15
# [4100-4174]=> Primavera: № 213 -> Длина записи: 61103; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 214 -> Длина записи: 3784943; Маркер выборки: 1; Число нарезок: 27
# [4100-4174]=> Primavera: № 215 -> Длина записи: 412463; Маркер выборки: 0; Число нарезок: 2
# [4100-4174]=> Primavera: № 216 -> Длина записи: 4138607; Маркер выборки: 1; Число нарезок: 30
# [4100-4174]=> Primavera: № 217 -> Длина записи: 27119; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 218 -> Длина записи: 2251055; Маркер выборки: 1; Число нарезок: 16
# [4100-4174]=> Primavera: № 219 -> Длина записи: 23663; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 220 -> Длина записи: 9370991; Маркер выборки: 1; Число нарезок: 68
# [4100-4174]=> Primavera: № 221 -> Длина записи: 21359; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 222 -> Длина записи: 1880111; Маркер выборки: 1; Число нарезок: 13
# [4100-4174]=> Primavera: № 223 -> Длина записи: 42095; Маркер выборки: 0; Число нарезок: 0
# [4100-4174]=> Primavera: № 224 -> Длина записи: 4527983; Маркер выборки: 1; Число нарезок: 32
#
# XTrain1.shape:  (1744, 137781, 1)
# YTrain1.shape:  (1744, 2)
# XTrain1V.shape:  (180, 137781, 1)
# YTrain1V.shape:  (180, 2)
# Обучающая выборка X_Train1 - Целевых: 5267; Нецелевых: 312
# Валидационная выборка X_Train1V - Целевых: 566; Нецелевых: 22
# Epoch 1/20
# 55/55 [==============================] - 20s 360ms/step - loss: 0.3409 - accuracy: 0.9071 - val_loss: 0.2025 - val_accuracy: 0.9333
# Epoch 2/20
# 55/55 [==============================] - 16s 295ms/step - loss: 0.2805 - accuracy: 0.9134 - val_loss: 0.1958 - val_accuracy: 0.9333
# Epoch 3/20
# 55/55 [==============================] - 16s 292ms/step - loss: 0.2765 - accuracy: 0.9134 - val_loss: 815.7940 - val_accuracy: 0.9333
# Epoch 4/20
# 55/55 [==============================] - 16s 289ms/step - loss: 0.2725 - accuracy: 0.9134 - val_loss: 0.2502 - val_accuracy: 0.9333
# Epoch 5/20
# 55/55 [==============================] - 16s 290ms/step - loss: 0.2627 - accuracy: 0.9134 - val_loss: 0.1845 - val_accuracy: 0.9333
# Epoch 6/20
# 55/55 [==============================] - 16s 294ms/step - loss: 0.2686 - accuracy: 0.9134 - val_loss: 0.2411 - val_accuracy: 0.9333
# Epoch 7/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2665 - accuracy: 0.9134 - val_loss: 0.2584 - val_accuracy: 0.9333
# Epoch 8/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2613 - accuracy: 0.9134 - val_loss: 0.1939 - val_accuracy: 0.9333
# Epoch 9/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2549 - accuracy: 0.9134 - val_loss: 0.4148 - val_accuracy: 0.9333
# Epoch 10/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2622 - accuracy: 0.9134 - val_loss: 0.5663 - val_accuracy: 0.9333
# Epoch 11/20
# 55/55 [==============================] - 16s 294ms/step - loss: 0.2675 - accuracy: 0.9134 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 12/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2566 - accuracy: 0.9134 - val_loss: 1.3500 - val_accuracy: 0.9333
# Epoch 13/20
# 55/55 [==============================] - 16s 291ms/step - loss: 0.2582 - accuracy: 0.9134 - val_loss: 0.1896 - val_accuracy: 0.9333
# Epoch 14/20
# 55/55 [==============================] - 16s 292ms/step - loss: 0.2606 - accuracy: 0.9134 - val_loss: 0.2338 - val_accuracy: 0.9333
# Epoch 15/20
# 55/55 [==============================] - 16s 290ms/step - loss: 0.2589 - accuracy: 0.9134 - val_loss: 99.7112 - val_accuracy: 0.9333
# Epoch 16/20
# 55/55 [==============================] - 16s 292ms/step - loss: 0.2569 - accuracy: 0.9134 - val_loss: 849.8341 - val_accuracy: 0.9333
# Epoch 17/20
# 55/55 [==============================] - 16s 292ms/step - loss: 0.2572 - accuracy: 0.9134 - val_loss: 0.1805 - val_accuracy: 0.9333
# Epoch 18/20
# 55/55 [==============================] - 16s 293ms/step - loss: 0.2614 - accuracy: 0.9134 - val_loss: 3.8424 - val_accuracy: 0.9333
# Epoch 19/20
# 55/55 [==============================] - 16s 294ms/step - loss: 0.2572 - accuracy: 0.9134 - val_loss: 0.2218 - val_accuracy: 0.9333
# Epoch 20/20
# 55/55 [==============================] - 16s 294ms/step - loss: 0.2619 - accuracy: 0.9134 - val_loss: 0.2474 - val_accuracy: 0.9333
# Завершён блок [4100_4174] - 4-й из 4
# Завершено обучение всех запущенных блоков.
# Время обработки: 1394.62 с

# %% [markdown]
# # Проверка

# %%
def neuro_test_au(): # Формирование тестового набора
  #
  # Параметры настройки нарезки обучения и слоёв модели
  #
  name_list_ = ['Headliner','Paveletskaya_city', 'Paveletskaya_turbo', 'Primavera']
  audio_path_ = [WAV_HEADL, WAV_PAVEL, WAV_PAVEL, WAV_PRIMA]

  pull_size = PULL_SIZE
  sections = SECTIONS
  conv_pull_blocks = len(sections)
  strider = CONV_STRIDE_1
  audio_slicing_size = strider * (pull_size ** conv_pull_blocks)
  df_pre_train_ = df_pre_train
  a_files_count_ = 0
  XT_Marker_0 = 0
  XT_Marker_1 = 0

  #####
  ##### Основной цикл: создания блока тестовых выборок, запуска тестирования
  #####

#  X_tests = pd.DataFrame(columns=['test_array'])
  X_tests = []

  for tr_block_ in TR_BLOCKS_TEST:
    print('Вошли в основной цикл подготовки тестовых данных...')
    Y_test1 = []
    predict_count_= 0
    last_marker_ = 1

    for i in range(tr_block_[0], tr_block_[1]):
#      print(f'файл {i}')

      X_test1 = list()

      start_time = time.time()
      a_files_count_ +=1

      training_marker_ = df_pre_train_.loc[i]['Tags']
      au_name_ = df_pre_train_.loc[i]['AudioFile']
      data_number_ = df_pre_train_.loc[i]['DataNumber']

      try:
        y, sr = librosa.load(audio_path_[data_number_]+'/'+au_name_, mono=True, sr=SR) #Загружаем аудиофайл
      except LibsndfileError:
        print(f'Ошибка обработки файла: {audio_path_[data_number_]+"/"+au_name_}')
        continue
      except FileNotFoundError:
        print(f'Не найден файл: {audio_path_[data_number_]+"/"+au_name_}')
        continue

      au_len_ = len(y) # Количество сигналов

      # Не попадёт в выборку - файл меньше длины нарезки
      if au_len_ < audio_slicing_size:
        continue

      counter = 0 # Счетчик обработанных аудиоданных
      pos = 0 # Указатель на начало вырезки аудио

      ohe_marker_ = lambda training_marker_: [1, 0] if training_marker_ == 0 else [0, 1]

      while (pos + audio_slicing_size < len(y)):  # Пробегаем по файлу
        counter+=1
        if counter % 10 != 0: # ~ 80% - 90% уже отрезано в обучение
          if counter % 12 == 0: # Отстегнём в тестовую выборку
            X_test1.append(y[pos: pos + audio_slicing_size]) # Вырезаем часть размером нарезки и добавляем в тестовую выборку
            Y_test1.append(ohe_marker_(training_marker_)) # Соответствующий маркер в Ytest
        pos += audio_slicing_size // CUTTING_PART_PREDICT # CUTTING_PART_TRAIN # Шаг сдвига нарезки

      # Пропускаем, если случайно длина нарезки меньше размера файла
      if len(X_test1) == 0:
        continue

      X_test1 = np.array(X_test1)

      # !!! Регулятор объёма тестовых выборок !!!
      # !!! В тестовую выборку набираем только с количеством нарезок больше заданного
      if X_test1.shape[0] < 10:
        continue

      # Чередуем в тестоую выборку по маркерам
      print(f'last_marker_ = {last_marker_}; training_marker_ = {training_marker_}')
      if last_marker_ != training_marker_:
        last_marker_ = training_marker_
      else:
        continue

      if training_marker_ == 0: # Счётчик маркеров в тестовой выборке
        XT_Marker_0 += 1
      else:
        XT_Marker_1 += 1

      X_test1 = np.expand_dims(X_test1, axis=2)
      print(f'файл {i}: X_test1.shape = {X_test1.shape}, Маркер:{training_marker_}')

      X_tests.append(X_test1)

      # !!!  Задаём предельный объём тестовой выборки
      print(f'predict_count_ = {predict_count_}')
      if predict_count_== 20:
        break
      else:
        predict_count_ += 1

    Y_test1 = np.array(Y_test1)

    print('Сохраняем...\n')
    with open(DUMP+'/X_tests.pkl', 'wb') as pickle_out:
      pkl.dump(X_tests, pickle_out)
    with open(DUMP+'/Y_test1.pkl', 'wb') as pickle_out:
      pkl.dump(Y_test1, pickle_out)

#    print('Тестируем...\n')
#    print(f'В тестовой выборке - Целевых: {XT_Marker_1}; Нецелевых: {XT_Marker_0}')

#    if 'model_au' not in locals():
#      model_au = load_model(DUMP + '/model_au.h5')

#    checkModel(model_au, X_tests, Y_test)

#  print('Тестирование завершено.')
  print('Подготовка тестовых данных завершена.')

# %%
#Проверяем работу модели
# def checkModel(model, X_tests, Y_test):
def checkModel():
  print('Запуск тестирования...')
  validations = 0
  validation_errors = 0

  print('Чтение тестовых данных и модели с диска...')
  with open(DUMP+'/X_tests.pkl', 'rb') as pickle_in:
    X_tests = pkl.load(pickle_in)
  with open(DUMP+'/Y_test1.pkl', 'rb') as pickle_in:
    Y_test1 = pkl.load(pickle_in)
  model = load_model(DUMP + '/model_au.h5')

  # По всем тестовым аудиофайлам
  for i in range(len(X_tests)):
    validations += 1

    predictions = np.sum(model.predict(X_tests[i]), axis = 0)
    predict_i = np.argmax(predictions)

    # Y_test1[i][0] == 1 => == 0
    # Y_test1[i][1] == 1 => == 1
    if (Y_test1[i][0]==1 and predict_i==0) or (Y_test1[i][1]==1 and predict_i==1):
      if Y_test1[i][0]==1:
        true_ = 'Нецелевой'
      elif Y_test1[i][1]==1:
        true_ = 'Целевой'
      else:
        print('Ошибка в данных: невозможный ohe.')
      print(f'Ответ верный: звонок "{true_}"')
    else:
      if predict_i==0:
        true_ = 'Целевой'
        false_ = 'Нецелевой'
      elif predict_i==1:
        true_ = 'Нецелевой'
        false_ = 'Целевой'
      else:
        print('Ошибка в данных: невозможный ответ predict_i.')
      print(f'Распознано с ошибкой. Вместо "{true_}" распознано "{false_}"')
      validation_errors += 1
  # Итог
  trueValidations = validations - validation_errors
  print("Итого распознаваний проведено: ", validations)
  print("Итого распознаваний ВЕРНЫХ: ", trueValidations, "(", 100*trueValidations/validations,"%)")

# %%
with timex():
  neuro_test_au()
# Out:
# Вошли в основной цикл подготовки тестовых данных...
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3110: X_test1.shape = (11, 137781, 1), Маркер:0
# predict_count_ = 0
# last_marker_ = 0; training_marker_ = 1
# файл 3117: X_test1.shape = (20, 137781, 1), Маркер:1
# predict_count_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3236: X_test1.shape = (12, 137781, 1), Маркер:0
# predict_count_ = 2
# last_marker_ = 0; training_marker_ = 1
# файл 3237: X_test1.shape = (23, 137781, 1), Маркер:1
# predict_count_ = 3
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3276: X_test1.shape = (10, 137781, 1), Маркер:0
# predict_count_ = 4
# last_marker_ = 0; training_marker_ = 1
# файл 3279: X_test1.shape = (14, 137781, 1), Маркер:1
# predict_count_ = 5
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3386: X_test1.shape = (20, 137781, 1), Маркер:0
# predict_count_ = 6
# last_marker_ = 0; training_marker_ = 1
# файл 3389: X_test1.shape = (18, 137781, 1), Маркер:1
# predict_count_ = 7
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3396: X_test1.shape = (32, 137781, 1), Маркер:0
# predict_count_ = 8
# last_marker_ = 0; training_marker_ = 1
# файл 3397: X_test1.shape = (10, 137781, 1), Маркер:1
# predict_count_ = 9
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3446: X_test1.shape = (15, 137781, 1), Маркер:0
# predict_count_ = 10
# last_marker_ = 0; training_marker_ = 1
# файл 3447: X_test1.shape = (12, 137781, 1), Маркер:1
# predict_count_ = 11
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3514: X_test1.shape = (12, 137781, 1), Маркер:0
# predict_count_ = 12
# last_marker_ = 0; training_marker_ = 1
# файл 3515: X_test1.shape = (25, 137781, 1), Маркер:1
# predict_count_ = 13
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 3930: X_test1.shape = (16, 137781, 1), Маркер:0
# predict_count_ = 14
# last_marker_ = 0; training_marker_ = 1
# файл 3931: X_test1.shape = (11, 137781, 1), Маркер:1
# predict_count_ = 15
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 0
# файл 4100: X_test1.shape = (14, 137781, 1), Маркер:0
# predict_count_ = 16
# last_marker_ = 0; training_marker_ = 1
# файл 4101: X_test1.shape = (15, 137781, 1), Маркер:1
# predict_count_ = 17
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# last_marker_ = 1; training_marker_ = 1
# Сохраняем...
#
# Подготовка тестовых данных завершена.
# Время обработки: 751.48 с

# %%
with timex():
  checkModel()
# Out:
# Запуск тестирования...
# Чтение тестовых данных и модели с диска...
# 1/1 [==============================] - 1s 1s/step
# Распознано с ошибкой. Вместо "Нецелевой" распознано "Целевой"
# 1/1 [==============================] - 2s 2s/step
# Распознано с ошибкой. Вместо "Нецелевой" распознано "Целевой"
# 1/1 [==============================] - 1s 818ms/step
# Распознано с ошибкой. Вместо "Нецелевой" распознано "Целевой"
# 1/1 [==============================] - 2s 2s/step
# Распознано с ошибкой. Вместо "Нецелевой" распознано "Целевой"
# 1/1 [==============================] - 1s 738ms/step
# Распознано с ошибкой. Вместо "Нецелевой" распознано "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 4s 4s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 940ms/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 773ms/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 764ms/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 2s 2s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 694ms/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# 1/1 [==============================] - 1s 1s/step
# Ответ верный: звонок "Целевой"
# Итого распознаваний проведено:  18
# Итого распознаваний ВЕРНЫХ:  13 ( 72.22222222222223 %)
# Время обработки: 25.75 с
