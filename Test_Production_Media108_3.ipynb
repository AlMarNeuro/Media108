# %%
def count_chars(s):
  return {char: s.count(char) for char in set(s)}
print (count_chars('aaabbbbccccxyz_      -zzmmmfff~~~~~'))
# Out:
# {'f': 3, 'z': 3, 'b': 4, 'm': 3, 'c': 4, ' ': 6, '~': 5, '_': 1, 'x': 1, 'a': 3, '-': 1, 'y': 1}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# !openssl version
# Out:
# OpenSSL 3.0.2 15 Mar 2022 (Library: OpenSSL 3.0.2 15 Mar 2022)

# %%
import os
import requests
import json
import time

# %%
# !pip install --upgrade requests

# %%
# !openssl version
# Out:
# OpenSSL 3.0.2 15 Mar 2022 (Library: OpenSSL 3.0.2 15 Mar 2022)

# %%
# URL-адрес метода сервера
URL = 'https://85.193.89.6:5001'
#URL = 'http://learn.python.ru'
#time.sleep(2)

#response = requests.get(
#  URL
#)
response = requests.post(
  URL,
  data = {'key':'value'}
)

print(response)
#print(response.json())
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#
# ...

# %%
'''
# Определение тела запроса
request_body = {
  'config': {
    'specification': {
      'languageCode': LANGUAGE_CODE,
      'model': 'general:rc',
      'audioEncoding': 'LINEAR16_PCM',
      'sampleRateHertz': frame_rate,
      "audioChannelCount": 1
    }
  },
  "audio": {
    "uri": f"https://storage.yandexcloud.net/media108-audio-backet/{fname}"
  }
}

# Отправка запроса на сервер Yandex SpeechKit
print('Отправка запроса post на транскрибацию на сервер Yandex SpeechKit')
response = requests.post(
  URL,
  headers={'Authorization': f'Api-Key {API_KEY}'},
  json=request_body
)
'''

# ConnectionRefusedError
# NewConnectionError
# ConnectionError
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1007)
